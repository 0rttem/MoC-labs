# %%
import numpy as np
import re, textwrap
import math as m
import random

from collections import Counter
import nltk

import sys
import gzip
from base64 import b64encode, b64decode

# %% [markdown]
# **1. Предварительная обработка текста**

# %%
with open("Dreiser.txt", 'rb') as file: 
    TEXT = file.read().decode('utf-8')
    
pattern_1 = r'ґ'
pattern_2 = r'[^абвгдеєжзиіїйклмнопрстуфхцчшщьюя]'

TEXT = re.sub(pattern_1, 'г', TEXT.lower())
TEXT = re.sub(pattern_2, '', TEXT)

# %% [markdown]
# **2. Расчёт статистических данных текста**

# %%
ukr_clean_alphabet = 'абвгдеєжзиіїйклмнопрстуфхцчшщьюя'

# %%
def letter_counter(text):
    alphabet = dict.fromkeys(list(ukr_clean_alphabet), 0)
    
    for letter in text:
        alphabet[letter] += 1
    
    return alphabet

# %%
letter_counter(TEXT)
# Out:
# {'а': 115516,
#  'б': 28941,
#  'в': 84841,
#  'г': 24462,
#  'д': 52838,
#  'е': 74034,
#  'є': 5133,
#  'ж': 15228,
#  'з': 33899,
#  'и': 87619,
#  'і': 84161,
#  'ї': 10210,
#  'й': 23372,
#  'к': 45594,
#  'л': 52192,
#  'м': 43822,
#  'н': 90412,
#  'о': 137885,
#  'п': 39320,
#  'р': 57405,
#  'с': 56137,
#  'т': 70682,
#  'у': 48930,
#  'ф': 2513,
#  'х': 13910,
#  'ц': 10704,
#  'ч': 20649,
#  'ш': 11445,
#  'щ': 10298,
#  'ь': 21038,
#  'ю': 11669,
#  'я': 32091}

# %%
N = 1416950

# %% [markdown]
# 1) Частота букв в тексте

# %%
def dictionary_sorting(dictionary):
    return [(i, round(dictionary[i]/N, 5)) for i in sorted(dictionary.keys(), key=dictionary.get, reverse=True)]

dictionary_sorting(letter_counter(TEXT))
# Out:
# [('о', 0.09731),
#  ('а', 0.08152),
#  ('н', 0.06381),
#  ('и', 0.06184),
#  ('в', 0.05988),
#  ('і', 0.0594),
#  ('е', 0.05225),
#  ('т', 0.04988),
#  ('р', 0.04051),
#  ('с', 0.03962),
#  ('д', 0.03729),
#  ('л', 0.03683),
#  ('у', 0.03453),
#  ('к', 0.03218),
#  ('м', 0.03093),
#  ('п', 0.02775),
#  ('з', 0.02392),
#  ('я', 0.02265),
#  ('б', 0.02042),
#  ('г', 0.01726),
#  ('й', 0.01649),
#  ('ь', 0.01485),
#  ('ч', 0.01457),
#  ('ж', 0.01075),
#  ('х', 0.00982),
#  ('ю', 0.00824),
#  ('ш', 0.00808),
#  ('ц', 0.00755),
#  ('щ', 0.00727),
#  ('ї', 0.00721),
#  ('є', 0.00362),
#  ('ф', 0.00177)]

# %%
def letter_frequency(dictionary):
    return [(i, round(dictionary[i]/N, 5)) for i in dictionary.keys()]

letter_frequency(letter_counter(TEXT))
# Out:
# [('а', 0.08152),
#  ('б', 0.02042),
#  ('в', 0.05988),
#  ('г', 0.01726),
#  ('д', 0.03729),
#  ('е', 0.05225),
#  ('є', 0.00362),
#  ('ж', 0.01075),
#  ('з', 0.02392),
#  ('и', 0.06184),
#  ('і', 0.0594),
#  ('ї', 0.00721),
#  ('й', 0.01649),
#  ('к', 0.03218),
#  ('л', 0.03683),
#  ('м', 0.03093),
#  ('н', 0.06381),
#  ('о', 0.09731),
#  ('п', 0.02775),
#  ('р', 0.04051),
#  ('с', 0.03962),
#  ('т', 0.04988),
#  ('у', 0.03453),
#  ('ф', 0.00177),
#  ('х', 0.00982),
#  ('ц', 0.00755),
#  ('ч', 0.01457),
#  ('ш', 0.00808),
#  ('щ', 0.00727),
#  ('ь', 0.01485),
#  ('ю', 0.00824),
#  ('я', 0.02265)]

# %% [markdown]
# 2) Частоты биграмм в тексте

# %%
def bigrams_counter(text):
    cnt = Counter(list(nltk.ngrams(text, n=2)))
    sort_dict = sorted(dict(cnt).items(), key = lambda x: x[1], reverse = True)
    
    return sort_dict

bigrams_counter(TEXT)
# Out:
# [(('н', 'а'), 19855),
#  (('о', 'в'), 16670),
#  (('в', 'і'), 15719),
#  (('н', 'е'), 15150),
#  (('т', 'и'), 15028),
#  (('п', 'о'), 14106),
#  (('р', 'о'), 13916),
#  (('а', 'в'), 13369),
#  (('г', 'о'), 12906),
#  (('е', 'р'), 12255),
#  (('с', 'т'), 12069),
#  (('о', 'г'), 12050),
#  (('л', 'а'), 11945),
#  (('л', 'и'), 11648),
#  (('т', 'а'), 11432),
#  (('і', 'н'), 11229),
#  (('в', 'и'), 10998),
#  (('о', 'н'), 10875),
#  (('в', 'о'), 10742),
#  (('о', 'м'), 10737),
#  (('и', 'в'), 10702),
#  (('в', 'а'), 10571),
#  (('п', 'р'), 10526),
#  (('а', 'т'), 10353),
#  (('а', 'л'), 10295),
#  (('н', 'о'), 10004),
#  (('н', 'і'), 9966),
#  (('р', 'а'), 9660),
#  (('е', 'н'), 9624),
#  (('о', 'д'), 9594),
#  (('о', 'б'), 9551),
#  (('і', 'д'), 9465),
#  (('д', 'о'), 9339),
#  (('і', 'в'), 8883),
#  (('к', 'о'), 8864),
#  (('о', 'с'), 8803),
#  (('и', 'н'), 8754),
#  (('н', 'и'), 8679),
#  (('з', 'а'), 8646),
#  (('а', 'н'), 8513),
#  (('и', 'т'), 8497),
#  (('т', 'о'), 8434),
#  (('с', 'я'), 8251),
#  (('щ', 'о'), 7913),
#  (('у', 'в'), 7758),
#  (('и', 'с'), 7744),
#  (('я', 'к'), 7687),
#  (('к', 'а'), 7409),
#  (('а', 'й'), 7354),
#  (('р', 'и'), 7145),
#  (('т', 'ь'), 7074),
#  (('а', 'с'), 7063),
#  (('м', 'о'), 6777),
#  (('л', 'о'), 6776),
#  (('и', 'й'), 6737),
#  (('а', 'к'), 6562),
#  (('б', 'у'), 6490),
#  (('к', 'и'), 6488),
#  (('и', 'м'), 6347),
#  (('р', 'е'), 6275),
#  (('о', 'т'), 6269),
#  (('о', 'з'), 6258),
#  (('і', 'л'), 6130),
#  (('о', 'р'), 6088),
#  (('т', 'е'), 6060),
#  (('в', 'с'), 6053),
#  (('м', 'і'), 6033),
#  (('о', 'л'), 5959),
#  (('т', 'і'), 5932),
#  (('м', 'у'), 5915),
#  (('м', 'а'), 5869),
#  (('ч', 'и'), 5850),
#  (('а', 'м'), 5811),
#  (('і', 'с'), 5763),
#  (('д', 'а'), 5708),
#  (('а', 'д'), 5512),
#  (('а', 'з'), 5439),
#  (('е', 'в'), 5307),
#  (('і', 'т'), 5226),
#  (('р', 'і'), 5216),
#  (('ж', 'е'), 5160),
#  (('а', 'п'), 4996),
#  (('д', 'и'), 4941),
#  (('з', 'н'), 4904),
#  (('н', 'у'), 4898),
#  (('о', 'п'), 4889),
#  (('а', 'р'), 4750),
#  (('у', 'т'), 4720),
#  (('о', 'к'), 4652),
#  (('л', 'е'), 4638),
#  (('й', 'о'), 4621),
#  (('д', 'у'), 4617),
#  (('е', 'з'), 4457),
#  (('к', 'л'), 4455),
#  (('и', 'л'), 4454),
#  (('п', 'е'), 4451),
#  (('й', 'д'), 4447),
#  (('е', 'п'), 4382),
#  (('л', 'ь'), 4360),
#  (('д', 'і'), 4337),
#  (('н', 'н'), 4298),
#  (('т', 'р'), 4291),
#  (('о', 'ч'), 4239),
#  (('б', 'е'), 4227),
#  (('у', 'д'), 4076),
#  (('с', 'ь'), 4067),
#  (('в', 'е'), 3992),
#  (('м', 'и'), 3992),
#  (('д', 'н'), 3972),
#  (('е', 'с'), 3855),
#  (('у', 'м'), 3801),
#  (('ц', 'е'), 3763),
#  (('ч', 'а'), 3759),
#  (('к', 'у'), 3743),
#  (('е', 'м'), 3736),
#  (('к', 'і'), 3731),
#  (('і', 'м'), 3705),
#  (('е', 'т'), 3678),
#  (('л', 'і'), 3652),
#  (('с', 'е'), 3650),
#  (('о', 'ж'), 3607),
#  (('д', 'е'), 3602),
#  (('е', 'б'), 3583),
#  (('в', 'н'), 3569),
#  (('ь', 'к'), 3554),
#  (('л', 'я'), 3551),
#  (('у', 'л'), 3534),
#  (('у', 'с'), 3514),
#  (('с', 'п'), 3505),
#  (('б', 'а'), 3482),
#  (('х', 'о'), 3470),
#  (('и', 'п'), 3461),
#  (('и', 'к'), 3409),
#  (('п', 'і'), 3408),
#  (('и', 'х'), 3404),
#  (('е', 'д'), 3402),
#  (('ь', 'о'), 3399),
#  (('т', 'у'), 3386),
#  (('і', 'к'), 3376),
#  (('с', 'і'), 3331),
#  (('н', 'я'), 3330),
#  (('а', 'б'), 3312),
#  (('г', 'а'), 3293),
#  (('м', 'е'), 3283),
#  (('і', 'п'), 3190),
#  (('я', 'т'), 3168),
#  (('р', 'у'), 3147),
#  (('я', 'в'), 3105),
#  (('с', 'о'), 3079),
#  (('і', 'з'), 3076),
#  (('и', 'з'), 3071),
#  (('ч', 'е'), 3068),
#  (('б', 'о'), 2996),
#  (('б', 'і'), 2961),
#  (('р', 'т'), 2959),
#  (('о', 'ю'), 2951),
#  (('ц', 'і'), 2943),
#  (('о', 'ї'), 2889),
#  (('е', 'л'), 2825),
#  (('а', 'г'), 2813),
#  (('і', 'й'), 2798),
#  (('и', 'д'), 2792),
#  (('а', 'ч'), 2631),
#  (('ш', 'и'), 2611),
#  (('с', 'к'), 2562),
#  (('н', 'ь'), 2492),
#  (('з', 'в'), 2491),
#  (('б', 'и'), 2483),
#  (('з', 'у'), 2414),
#  (('с', 'в'), 2385),
#  (('я', 'н'), 2383),
#  (('і', 'р'), 2353),
#  (('е', 'й'), 2351),
#  (('к', 'р'), 2326),
#  (('у', 'ж'), 2308),
#  (('в', 'у'), 2298),
#  (('ш', 'е'), 2295),
#  (('м', 'н'), 2295),
#  (('и', 'ч'), 2294),
#  (('й', 'н'), 2280),
#  (('у', 'п'), 2262),
#  (('і', 'ш'), 2257),
#  (('а', 'є'), 2185),
#  (('с', 'а'), 2164),
#  (('а', 'ж'), 2143),
#  (('ь', 'н'), 2130),
#  (('ь', 'с'), 2085),
#  (('ч', 'о'), 2066),
#  (('и', 'р'), 2040),
#  (('в', 'д'), 2020),
#  (('с', 'и'), 2001),
#  (('с', 'у'), 2001),
#  (('д', 'р'), 1997),
#  (('с', 'л'), 1988),
#  (('л', 'ю'), 1974),
#  (('а', 'х'), 1972),
#  (('я', 'д'), 1967),
#  (('і', 'б'), 1964),
#  (('я', 'з'), 1962),
#  (('з', 'д'), 1956),
#  (('ї', 'ї'), 1913),
#  (('е', 'к'), 1866),
#  (('г', 'р'), 1849),
#  (('у', 'к'), 1846),
#  (('а', 'ю'), 1840),
#  (('і', 'я'), 1839),
#  (('п', 'а'), 1837),
#  (('у', 'н'), 1826),
#  (('п', 'и'), 1822),
#  (('д', 'в'), 1813),
#  (('в', 'т'), 1807),
#  (('і', 'г'), 1786),
#  (('ж', 'н'), 1780),
#  (('у', 'р'), 1758),
#  (('б', 'л'), 1750),
#  (('ч', 'у'), 1747),
#  (('о', 'я'), 1744),
#  (('р', 'н'), 1738),
#  (('и', 'щ'), 1697),
#  (('и', 'б'), 1691),
#  (('й', 'с'), 1687),
#  (('с', 'н'), 1669),
#  (('о', 'х'), 1661),
#  (('г', 'л'), 1629),
#  (('в', 'п'), 1624),
#  (('х', 'а'), 1624),
#  (('и', 'і'), 1608),
#  (('і', 'ч'), 1601),
#  (('ж', 'а'), 1560),
#  (('ю', 'ч'), 1550),
#  (('б', 'р'), 1531),
#  (('ж', 'и'), 1512),
#  (('з', 'р'), 1506),
#  (('е', 'ч'), 1467),
#  (('а', 'і'), 1459),
#  (('и', 'ц'), 1457),
#  (('щ', 'е'), 1455),
#  (('в', 'л'), 1411),
#  (('ю', 'в'), 1401),
#  (('у', 'з'), 1397),
#  (('т', 'н'), 1395),
#  (('ц', 'ь'), 1381),
#  (('ч', 'н'), 1372),
#  (('е', 'ж'), 1347),
#  (('я', 'м'), 1340),
#  (('д', 'ж'), 1335),
#  (('в', 'ч'), 1333),
#  (('о', 'і'), 1328),
#  (('н', 'д'), 1319),
#  (('ц', 'я'), 1314),
#  (('в', 'к'), 1307),
#  (('я', 'п'), 1297),
#  (('в', 'ж'), 1293),
#  (('л', 'у'), 1289),
#  (('и', 'г'), 1289),
#  (('т', 'я'), 1286),
#  (('и', 'ї'), 1282),
#  (('в', 'в'), 1277),
#  (('т', 'в'), 1276),
#  (('з', 'і'), 1263),
#  (('д', 'ь'), 1262),
#  (('ї', 'х'), 1261),
#  (('у', 'б'), 1257),
#  (('а', 'щ'), 1231),
#  (('о', 'й'), 1228),
#  (('о', 'ц'), 1221),
#  (('н', 'з'), 1218),
#  (('у', 'ч'), 1208),
#  (('з', 'о'), 1205),
#  (('я', 'с'), 1199),
#  (('є', 'т'), 1196),
#  (('п', 'л'), 1196),
#  (('н', 'т'), 1184),
#  (('е', 'г'), 1181),
#  (('і', 'і'), 1177),
#  (('х', 'в'), 1169),
#  (('и', 'я'), 1164),
#  (('ш', 'о'), 1159),
#  (('і', 'х'), 1157),
#  (('д', 'п'), 1148),
#  (('д', 'к'), 1140),
#  (('а', 'я'), 1136),
#  (('з', 'м'), 1122),
#  (('д', 'л'), 1120),
#  (('м', 'п'), 1114),
#  (('ю', 'т'), 1111),
#  (('й', 'т'), 1100),
#  (('у', 'і'), 1097),
#  (('ю', 'д'), 1096),
#  (('к', 'н'), 1095),
#  (('ж', 'у'), 1095),
#  (('н', 'п'), 1091),
#  (('в', 'з'), 1091),
#  (('н', 'к'), 1079),
#  (('е', 'щ'), 1067),
#  (('г', 'у'), 1037),
#  (('в', 'я'), 1026),
#  (('в', 'ш'), 1011),
#  (('а', 'ш'), 1010),
#  (('а', 'ц'), 1005),
#  (('ч', 'і'), 999),
#  (('е', 'ц'), 981),
#  (('г', 'і'), 979),
#  (('к', 'в'), 976),
#  (('е', 'я'), 967),
#  (('з', 'п'), 966),
#  (('ь', 'п'), 961),
#  (('в', 'р'), 954),
#  (('х', 'і'), 937),
#  (('ф', 'і'), 935),
#  (('м', 'с'), 932),
#  (('к', 'е'), 920),
#  (('о', 'щ'), 920),
#  (('р', 'я'), 919),
#  (('я', 'і'), 919),
#  (('и', 'ш'), 918),
#  (('й', 'п'), 917),
#  (('і', 'о'), 908),
#  (('с', 'м'), 907),
#  (('о', 'о'), 905),
#  (('х', 'т'), 904),
#  (('о', 'ш'), 900),
#  (('м', 'в'), 895),
#  (('т', 'с'), 892),
#  (('н', 'ш'), 890),
#  (('й', 'в'), 878),
#  (('і', 'є'), 878),
#  (('е', 'о'), 876),
#  (('ї', 'й'), 866),
#  (('м', 'к'), 864),
#  (('а', 'о'), 862),
#  (('ь', 'в'), 857),
#  (('к', 'щ'), 841),
#  (('д', 'я'), 840),
#  (('т', 'т'), 834),
#  (('е', 'ї'), 823),
#  (('е', 'х'), 822),
#  (('у', 'г'), 818),
#  (('і', 'ж'), 817),
#  (('і', 'ф'), 816),
#  (('з', 'е'), 813),
#  (('н', 'с'), 811),
#  (('і', 'щ'), 807),
#  (('ь', 'д'), 806),
#  (('в', 'щ'), 802),
#  (('й', 'ш'), 798),
#  (('ш', 'у'), 795),
#  (('н', 'ц'), 793),
#  (('к', 'т'), 791),
#  (('у', 'х'), 790),
#  (('ш', 'т'), 784),
#  (('и', 'а'), 781),
#  (('т', 'к'), 776),
#  (('в', 'б'), 771),
#  (('м', 'я'), 763),
#  (('х', 'и'), 755),
#  (('д', 'с'), 754),
#  (('б', 'н'), 750),
#  (('і', 'ц'), 743),
#  (('я', 'г'), 742),
#  (('д', 'т'), 737),
#  (('й', 'м'), 734),
#  (('і', 'а'), 733),
#  (('ь', 'т'), 730),
#  (('х', 'н'), 728),
#  (('м', 'з'), 726),
#  (('р', 'к'), 724),
#  (('з', 'г'), 722),
#  (('й', 'б'), 722),
#  (('е', 'ш'), 718),
#  (('д', 'ч'), 717),
#  (('з', 'б'), 711),
#  (('я', 'л'), 707),
#  (('н', 'в'), 702),
#  (('ь', 'з'), 701),
#  (('в', 'г'), 697),
#  (('е', 'і'), 696),
#  (('к', 'с'), 695),
#  (('з', 'с'), 691),
#  (('з', 'л'), 690),
#  (('в', 'м'), 688),
#  (('ь', 'і'), 687),
#  (('і', 'ї'), 683),
#  (('ь', 'ш'), 682),
#  (('и', 'о'), 676),
#  (('ц', 'ю'), 675),
#  (('з', 'к'), 675),
#  (('у', 'ш'), 672),
#  (('є', 'м'), 671),
#  (('й', 'з'), 664),
#  (('о', 'є'), 662),
#  (('м', 'т'), 658),
#  (('ш', 'н'), 657),
#  (('й', 'і'), 656),
#  (('в', 'ц'), 655),
#  (('ж', 'д'), 653),
#  (('ю', 'н'), 649),
#  (('а', 'а'), 637),
#  (('ї', 'з'), 636),
#  (('р', 'в'), 633),
#  (('у', 'я'), 629),
#  (('д', 'ц'), 623),
#  (('у', 'а'), 619),
#  (('т', 'ю'), 616),
#  (('ю', 'с'), 616),
#  (('е', 'ю'), 613),
#  (('д', 'з'), 612),
#  (('я', 'ч'), 608),
#  (('и', 'ж'), 608),
#  (('ш', 'і'), 606),
#  (('я', 'б'), 602),
#  (('ш', 'а'), 601),
#  (('з', 'я'), 601),
#  (('м', 'р'), 596),
#  (('ш', 'л'), 594),
#  (('п', 'у'), 593),
#  (('г', 'н'), 590),
#  (('о', 'а'), 586),
#  (('я', 'щ'), 581),
#  (('й', 'к'), 573),
#  (('ї', 'в'), 571),
#  (('ю', 'б'), 568),
#  (('р', 'ш'), 563),
#  (('ю', 'п'), 562),
#  (('у', 'щ'), 561),
#  (('ь', 'м'), 559),
#  (('л', 'л'), 557),
#  (('ї', 'м'), 555),
#  (('р', 'д'), 554),
#  (('х', 'л'), 550),
#  (('ь', 'у'), 546),
#  (('р', 'с'), 542),
#  (('ю', 'і'), 536),
#  (('з', 'и'), 535),
#  (('д', 'д'), 531),
#  (('ї', 'п'), 527),
#  (('з', 'т'), 518),
#  (('с', 'х'), 514),
#  (('ї', 'д'), 513),
#  (('щ', 'а'), 509),
#  (('р', 'г'), 497),
#  (('в', 'ї'), 497),
#  (('м', 'д'), 495),
#  (('у', 'ю'), 491),
#  (('б', 'в'), 491),
#  (('н', 'б'), 490),
#  (('ш', 'к'), 487),
#  (('і', 'ю'), 478),
#  (('д', 'б'), 475),
#  (('є', 'ї'), 474),
#  (('й', 'ч'), 473),
#  (('г', 'и'), 470),
#  (('у', 'о'), 461),
#  (('у', 'є'), 459),
#  (('к', 'б'), 455),
#  (('к', 'п'), 454),
#  (('ж', 'і'), 451),
#  (('ї', 'с'), 451),
#  (('с', 'с'), 449),
#  (('с', 'ц'), 449),
#  (('я', 'х'), 445),
#  (('я', 'я'), 444),
#  (('а', 'у'), 440),
#  (('я', 'ц'), 436),
#  (('й', 'ж'), 435),
#  (('м', 'б'), 432),
#  (('д', 'м'), 431),
#  (('н', 'ч'), 429),
#  (('ю', 'р'), 428),
#  (('х', 'у'), 428),
#  (('ж', 'л'), 419),
#  (('ч', 'к'), 418),
#  (('к', 'з'), 417),
#  (('х', 'п'), 415),
#  (('ц', 'и'), 407),
#  (('н', 'ю'), 404),
#  (('ї', 'н'), 404),
#  (('я', 'р'), 396),
#  (('е', 'а'), 395),
#  (('е', 'ф'), 395),
#  (('ф', 'а'), 391),
#  (('ж', 'к'), 391),
#  (('р', 'м'), 389),
#  (('ь', 'я'), 388),
#  (('а', 'ї'), 386),
#  (('у', 'ц'), 384),
#  (('р', 'з'), 382),
#  (('й', 'р'), 380),
#  (('о', 'у'), 378),
#  (('н', 'м'), 378),
#  (('ж', 'о'), 372),
#  (('х', 'м'), 362),
#  (('ф', 'о'), 358),
#  (('ь', 'щ'), 357),
#  (('т', 'л'), 356),
#  (('я', 'а'), 356),
#  (('ь', 'б'), 356),
#  (('в', 'й'), 356),
#  (('п', 'я'), 354),
#  (('к', 'м'), 353),
#  (('з', 'ь'), 351),
#  (('м', 'ч'), 350),
#  (('а', 'ф'), 350),
#  (('ь', 'ц'), 346),
#  (('л', 'к'), 337),
#  (('ї', 'і'), 334),
#  (('ю', 'м'), 333),
#  (('х', 'д'), 332),
#  (('и', 'у'), 330),
#  (('ю', 'а'), 324),
#  (('ж', 'в'), 323),
#  (('я', 'о'), 321),
#  (('м', 'л'), 320),
#  (('ю', 'з'), 320),
#  (('р', 'п'), 318),
#  (('ш', 'в'), 314),
#  (('л', 'б'), 313),
#  (('х', 'с'), 312),
#  (('я', 'ж'), 312),
#  (('г', 'б'), 311),
#  (('я', 'й'), 309),
#  (('ь', 'ч'), 307),
#  (('є', 'ю'), 304),
#  (('ї', 'т'), 296),
#  (('є', 'в'), 290),
#  (('л', 'н'), 289),
#  (('ч', 'ч'), 288),
#  (('м', 'м'), 287),
#  (('з', 'ц'), 285),
#  (('р', 'л'), 285),
#  (('л', 'д'), 285),
#  (('ч', 'я'), 284),
#  (('п', 'н'), 282),
#  (('є', 'н'), 281),
#  (('у', 'й'), 280),
#  (('е', 'у'), 280),
#  (('с', 'ю'), 279),
#  (('к', 'я'), 278),
#  (('г', 'е'), 272),
#  (('х', 'е'), 272),
#  (('ж', 'б'), 272),
#  (('г', 'т'), 272),
#  (('ф', 'с'), 272),
#  (('к', 'д'), 271),
#  (('п', 'т'), 271),
#  (('х', 'з'), 269),
#  (('й', 'у'), 268),
#  (('й', 'а'), 266),
#  (('і', 'у'), 256),
#  (('ю', 'к'), 256),
#  (('й', 'г'), 252),
#  (('р', 'б'), 252),
#  (('ь', 'а'), 252),
#  (('б', 'с'), 251),
#  (('ь', 'й'), 251),
#  (('х', 'р'), 244),
#  (('б', 'п'), 244),
#  (('и', 'є'), 241),
#  (('р', 'ц'), 240),
#  (('ж', 'ч'), 238),
#  (('м', 'щ'), 237),
#  (('ь', 'р'), 236),
#  (('ю', 'х'), 235),
#  (('й', 'х'), 235),
#  (('є', 'п'), 233),
#  (('т', 'п'), 230),
#  (('г', 'к'), 230),
#  (('щ', 'и'), 228),
#  (('о', 'ф'), 223),
#  (('х', 'к'), 217),
#  (('й', 'л'), 216),
#  (('ю', 'я'), 216),
#  (('я', 'ї'), 216),
#  (('в', 'х'), 214),
#  (('з', 'з'), 211),
#  (('й', 'я'), 208),
#  (('т', 'ж'), 205),
#  (('ї', 'р'), 204),
#  (('д', 'г'), 204),
#  (('ї', 'к'), 203),
#  (('т', 'з'), 202),
#  (('й', 'щ'), 199),
#  (('ї', 'б'), 194),
#  (('ю', 'щ'), 194),
#  (('є', 'д'), 193),
#  (('ж', 'п'), 191),
#  (('б', 'т'), 189),
#  (('к', 'ш'), 189),
#  (('я', 'ю'), 188),
#  (('є', 'с'), 188),
#  (('н', 'р'), 188),
#  (('ч', 'л'), 187),
#  (('ф', 'е'), 185),
#  (('ї', 'о'), 185),
#  (('т', 'д'), 184),
#  (('р', 'ю'), 180),
#  (('б', 'м'), 179),
#  (('х', 'б'), 177),
#  (('є', 'ш'), 177),
#  (('ї', 'г'), 176),
#  (('р', 'х'), 176),
#  (('р', 'ж'), 176),
#  (('м', 'ц'), 170),
#  (('ю', 'ю'), 170),
#  (('я', 'є'), 169),
#  (('ї', 'ж'), 168),
#  (('к', 'ц'), 165),
#  (('д', 'ш'), 160),
#  (('ь', 'ї'), 160),
#  (('ь', 'г'), 157),
#  (('с', 'г'), 155),
#  (('к', 'к'), 155),
#  (('ю', 'г'), 153),
#  (('ї', 'а'), 153),
#  (('щ', 'і'), 153),
#  (('д', 'х'), 151),
#  (('й', 'ц'), 148),
#  (('ф', 'р'), 147),
#  (('у', 'ї'), 146),
#  (('п', 'ч'), 145),
#  (('с', 'з'), 145),
#  (('н', 'є'), 144),
#  (('з', 'ч'), 144),
#  (('н', 'г'), 142),
#  (('ь', 'л'), 140),
#  (('ж', 'з'), 138),
#  (('є', 'щ'), 138),
#  (('м', 'х'), 136),
#  (('ь', 'ю'), 136),
#  (('р', 'р'), 136),
#  (('ю', 'о'), 134),
#  (('я', 'у'), 134),
#  (('ї', 'л'), 133),
#  (('р', 'й'), 133),
#  (('м', 'г'), 133),
#  (('т', 'м'), 133),
#  (('ч', 'в'), 132),
#  (('с', 'б'), 129),
#  (('б', 'з'), 129),
#  (('є', 'з'), 129),
#  (('з', 'ї'), 129),
#  (('ь', 'х'), 128),
#  (('м', 'ю'), 128),
#  (('ж', 'т'), 128),
#  (('б', 'д'), 127),
#  (('б', 'я'), 126),
#  (('с', 'д'), 123),
#  (('н', 'л'), 122),
#  (('м', 'ї'), 122),
#  (('к', 'ч'), 121),
#  (('н', 'щ'), 121),
#  (('х', 'г'), 120),
#  (('ю', 'є'), 119),
#  (('у', 'ф'), 119),
#  (('ю', 'е'), 116),
#  (('т', 'щ'), 114),
#  (('л', 'с'), 113),
#  (('т', 'б'), 113),
#  (('є', 'і'), 112),
#  (('ї', 'ч'), 112),
#  (('ю', 'й'), 111),
#  (('г', 'п'), 110),
#  (('б', 'к'), 109),
#  (('н', 'х'), 108),
#  (('ю', 'л'), 108),
#  (('х', 'я'), 106),
#  (('м', 'ш'), 105),
#  (('и', 'ф'), 104),
#  (('ж', 'с'), 104),
#  (('д', 'ї'), 103),
#  (('ю', 'ц'), 102),
#  (('х', 'х'), 100),
#  (('ф', 'у'), 99),
#  (('б', 'х'), 99),
#  (('г', 'с'), 97),
#  (('є', 'й'), 96),
#  (('к', 'г'), 95),
#  (('ї', 'я'), 92),
#  (('ч', 'б'), 92),
#  (('т', 'ч'), 91),
#  (('ш', 'п'), 90),
#  (('х', 'ч'), 90),
#  (('у', 'у'), 90),
#  (('з', 'ш'), 90),
#  (('г', 'в'), 89),
#  (('є', 'р'), 87),
#  (('а', 'е'), 86),
#  (('г', 'з'), 86),
#  (('ж', 'я'), 86),
#  (('п', 'с'), 85),
#  (('р', 'ч'), 84),
#  (('ж', 'м'), 83),
#  (('є', 'к'), 83),
#  (('х', 'щ'), 82),
#  (('ц', 'н'), 79),
#  (('т', 'ц'), 79),
#  (('к', 'х'), 78),
#  (('л', 'п'), 78),
#  (('ч', 'т'), 77),
#  (('ю', 'у'), 77),
#  (('к', 'й'), 76),
#  (('л', 'г'), 76),
#  (('л', 'т'), 76),
#  (('к', 'ж'), 74),
#  (('ї', 'у'), 74),
#  (('т', 'х'), 74),
#  (('ш', 'с'), 72),
#  (('ш', 'м'), 70),
#  (('д', 'щ'), 69),
#  (('ї', 'щ'), 68),
#  (('з', 'й'), 67),
#  (('і', 'е'), 67),
#  (('є', 'я'), 67),
#  (('ш', 'з'), 67),
#  (('п', 'ц'), 67),
#  (('м', 'й'), 66),
#  (('є', 'б'), 65),
#  (('г', 'ш'), 65),
#  (('є', 'а'), 65),
#  (('з', 'ж'), 63),
#  (('х', 'ц'), 63),
#  (('й', 'ф'), 62),
#  (('ю', 'ш'), 61),
#  (('т', 'г'), 60),
#  (('ш', 'я'), 59),
#  (('ж', 'ц'), 58),
#  (('ь', 'ф'), 58),
#  (('к', 'ї'), 58),
#  (('е', 'є'), 57),
#  (('ї', 'ц'), 56),
#  (('ц', 'т'), 56),
#  (('с', 'р'), 56),
#  (('з', 'х'), 54),
#  (('л', 'м'), 53),
#  (('г', 'д'), 53),
#  (('ч', 'з'), 53),
#  (('м', 'ж'), 52),
#  (('б', 'б'), 52),
#  (('д', 'й'), 52),
#  (('с', 'ф'), 52),
#  (('р', 'щ'), 52),
#  (('й', 'й'), 52),
#  (('ю', 'ж'), 52),
#  (('р', 'ь'), 51),
#  (('я', 'ш'), 50),
#  (('є', 'о'), 50),
#  (('л', 'ц'), 49),
#  (('у', 'е'), 49),
#  (('о', 'е'), 48),
#  (('ю', 'ї'), 48),
#  (('п', 'к'), 47),
#  (('ь', 'ж'), 47),
#  (('є', 'ч'), 46),
#  (('л', 'в'), 46),
#  (('н', 'ї'), 46),
#  (('м', 'ф'), 43),
#  (('н', 'ж'), 43),
#  (('с', 'щ'), 42),
#  (('й', 'ї'), 42),
#  (('х', 'ж'), 41),
#  (('ч', 'с'), 41),
#  (('є', 'ж'), 41),
#  (('б', 'й'), 40),
#  (('ф', 'л'), 40),
#  (('є', 'ц'), 40),
#  (('ж', 'р'), 39),
#  (('щ', 'у'), 39),
#  (('б', 'ї'), 39),
#  (('є', 'г'), 39),
#  (('д', 'ю'), 38),
#  (('в', 'ф'), 38),
#  (('с', 'ч'), 38),
#  (('т', 'є'), 38),
#  (('ш', 'д'), 35),
#  (('т', 'ф'), 35),
#  (('м', 'є'), 34),
#  (('и', 'е'), 34),
#  (('ц', 'а'), 34),
#  (('б', 'ц'), 34),
#  (('б', 'ю'), 33),
#  (('ч', 'п'), 33),
#  (('и', 'ю'), 32),
#  (('ч', 'ц'), 31),
#  (('б', 'г'), 31),
#  (('х', 'ї'), 30),
#  (('б', 'є'), 29),
#  (('ж', 'х'), 29),
#  (('л', 'з'), 28),
#  (('х', 'ю'), 28),
#  (('ч', 'м'), 28),
#  (('ж', 'ї'), 28),
#  (('й', 'ю'), 28),
#  (('ж', 'г'), 28),
#  (('є', 'х'), 27),
#  (('х', 'ш'), 27),
#  (('х', 'ф'), 27),
#  (('е', 'е'), 27),
#  (('п', 'п'), 27),
#  (('я', 'ф'), 26),
#  (('з', 'ф'), 26),
#  (('р', 'є'), 26),
#  (('ж', 'й'), 25),
#  (('ч', 'д'), 25),
#  (('с', 'й'), 25),
#  (('ж', 'ж'), 24),
#  (('ш', 'щ'), 24),
#  (('ф', 'и'), 24),
#  (('й', 'е'), 23),
#  (('ф', 'т'), 23),
#  (('ї', 'ш'), 23),
#  (('х', 'й'), 23),
#  (('ю', 'ф'), 23),
#  (('ш', 'б'), 22),
#  (('є', 'л'), 22),
#  (('я', 'е'), 22),
#  (('т', 'й'), 22),
#  (('б', 'ш'), 22),
#  (('п', 'в'), 22),
#  (('ш', 'р'), 21),
#  (('н', 'й'), 21),
#  (('с', 'ї'), 21),
#  (('ч', 'г'), 21),
#  (('г', 'я'), 21),
#  (('г', 'м'), 20),
#  (('з', 'ю'), 20),
#  (('ш', 'ч'), 19),
#  (('в', 'ю'), 19),
#  (('р', 'ф'), 19),
#  (('б', 'щ'), 19),
#  (('ж', 'щ'), 18),
#  (('р', 'ї'), 18),
#  (('т', 'ї'), 18),
#  (('з', 'щ'), 17),
#  (('н', 'ф'), 17),
#  (('т', 'ш'), 16),
#  (('ч', 'ю'), 16),
#  (('ї', 'е'), 15),
#  (('ф', 'ф'), 15),
#  (('п', 'ш'), 15),
#  (('п', 'з'), 15),
#  (('с', 'є'), 14),
#  (('ц', 'в'), 14),
#  (('ш', 'ц'), 14),
#  (('ц', 'у'), 14),
#  (('б', 'ж'), 13),
#  (('г', 'ї'), 13),
#  (('г', 'щ'), 13),
#  (('к', 'ф'), 13),
#  (('б', 'ч'), 13),
#  (('ч', 'й'), 13),
#  (('ч', 'р'), 13),
#  (('з', 'є'), 13),
#  (('л', 'щ'), 12),
#  (('ь', 'е'), 12),
#  (('ч', 'ї'), 12),
#  (('є', 'у'), 12),
#  (('ї', 'ф'), 12),
#  (('ш', 'ш'), 11),
#  (('г', 'х'), 11),
#  (('л', 'х'), 11),
#  (('г', 'ч'), 10),
#  (('ї', 'є'), 10),
#  (('г', 'г'), 10),
#  (('ь', 'є'), 10),
#  (('д', 'ф'), 10),
#  (('г', 'ц'), 10),
#  (('л', 'ф'), 10),
#  (('с', 'ш'), 9),
#  (('с', 'ж'), 8),
#  (('п', 'ю'), 8),
#  (('ч', 'щ'), 8),
#  (('й', 'є'), 8),
#  (('г', 'й'), 8),
#  (('ф', 'к'), 8),
#  (('ч', 'х'), 8),
#  (('л', 'р'), 8),
#  (('ш', 'г'), 8),
#  (('х', 'є'), 8),
#  (('в', 'є'), 8),
#  (('п', 'д'), 7),
#  (('к', 'є'), 7),
#  (('ж', 'ю'), 7),
#  (('ж', 'ф'), 7),
#  (('ш', 'ї'), 7),
#  (('л', 'ї'), 6),
#  (('ч', 'ж'), 5),
#  (('п', 'м'), 5),
#  (('ї', 'ю'), 5),
#  (('ш', 'х'), 5),
#  (('ш', 'ж'), 5),
#  (('ц', 'о'), 5),
#  (('п', 'є'), 5),
#  (('п', 'г'), 5),
#  (('ж', 'є'), 5),
#  (('ш', 'й'), 5),
#  (('п', 'щ'), 5),
#  (('п', 'х'), 5),
#  (('п', 'б'), 5),
#  (('ц', 'м'), 4),
#  (('ш', 'ю'), 4),
#  (('ш', 'ф'), 4),
#  (('є', 'е'), 4),
#  (('ф', 'п'), 4),
#  (('ж', 'ш'), 4),
#  (('л', 'й'), 4),
#  (('є', 'ф'), 3),
#  (('ф', 'д'), 3),
#  (('л', 'ж'), 3),
#  (('ц', 'с'), 3),
#  (('п', 'й'), 3),
#  (('г', 'ю'), 3),
#  (('г', 'є'), 2),
#  (('ч', 'ф'), 2),
#  (('б', 'ф'), 2),
#  (('ф', 'в'), 2),
#  (('ц', 'р'), 2),
#  (('ц', 'щ'), 2),
#  (('л', 'є'), 2),
#  (('ц', 'д'), 2),
#  (('ф', 'б'), 2),
#  (('л', 'ч'), 2),
#  (('г', 'ж'), 2),
#  (('ц', 'б'), 2),
#  (('ф', 'я'), 2),
#  (('ф', 'н'), 1),
#  (('ф', 'г'), 1),
#  (('ц', 'к'), 1),
#  (('е', 'и'), 1),
#  (('п', 'ф'), 1),
#  (('ф', 'м'), 1),
#  (('щ', 'н'), 1),
#  (('ч', 'ш'), 1),
#  (('ц', 'ч'), 1),
#  (('л', 'ш'), 1),
#  (('ц', 'г'), 1),
#  (('ц', 'п'), 1),
#  (('п', 'ж'), 1),
#  (('и', 'и'), 1),
#  (('п', 'ї'), 1),
#  (('к', 'ю'), 1),
#  (('г', 'ф'), 1)]

# %% [markdown]
# 3) H1, H2

# %%
def entropy_letter(text):
    x = len(letter_frequency(letter_counter(text)))
    H1 = 0
    for i in range(x):
        H1 += (letter_frequency(letter_counter(text))[i][1] * m.log2(letter_frequency(letter_counter(text))[i][1])) * (-1)
    
    return H1
        
def entropy_bigrams(text):
    l = []
    for i in range(941):
        l.append(bigrams_counter(text)[i][1])
    
    x = 941 
    N_bigrams = 1416949
    
    H2 = 0
    for i in range(x):
        H2 += (((l[i]) / N_bigrams) * m.log2(((l[i]) / N_bigrams))) * (-1)
    
    return H2 * 0.5

# %%
entropy_letter(TEXT)
# Out:
# 4.592872413230112

# %%
entropy_bigrams(TEXT)
# Out:
# 4.216828505470758

# %% [markdown]
# 4) I1, I2

# %%
def conformity_index_letter(text):
    L = len(text)
    return (1/(L * (L-1))) * sum(letter_counter(text)[i] * (letter_counter(text)[i] - 1) for i in ukr_clean_alphabet)

def conformity_index_bigrams(text):
    L = len(text)
    
    l = []
    cnt = Counter(list(nltk.ngrams(text, n = 2)))
    for i in range(len(cnt)):
        l.append(bigrams_counter(text)[i][1])
    
    I2 = 0
    for i in range(len(cnt)):
        I2 += l[i] * (l[i] - 1)
    
    return I2 / (L * (L - 1))

# %%
conformity_index_letter(TEXT)
# Out:
# 0.04928235830845431

# %%
conformity_index_bigrams(TEXT)
# Out:
# 0.004381493632890787

# %% [markdown]
# **3. Вспомогательные функции**

# %%
#char ---> int
def text_to_array_of_num(text):
    return [ukr_clean_alphabet.find(i) for i in text]

#int ---> char
def array_of_numbers_to_text(num):
    return ''.join([ukr_clean_alphabet[i] for i in num])

# %%
def disjoint_bigrams(text):
    bigram = {}
    for i in range(m.ceil((len(text) - 1) / 2)):
        if ''.join(text[2*i : 2*i + 2]) in bigram:
            bigram[''.join(text[2*i : 2*i + 2])] += 1
        else:
            bigram[''.join(text[2*i : 2*i + 2])] = 1
            
    for i, j in bigram.items():
        bigram[i] = j / sum(bigram.values())
    
    
    return bigram

# %%
disjoint_bigrams(TEXT)
# Out:
# {'те': 0.00429796393662444,
#  'од': 0.00688657977460801,
#  'ор': 0.0043079083260792765,
#  'др': 0.001426412833847082,
#  'ай': 0.005248657918709924,
#  'зе': 0.0006032590227308033,
#  'ра': 0.006837693010390672,
#  'ме': 0.0023555069869240722,
#  'ри': 0.005242446522423644,
#  'ка': 0.005412192228993554,
#  'нс': 0.0005730371643025026,
#  'ьк': 0.002701746456344744,
#  'ат': 0.007741454389585696,
#  'ге': 0.0001951207731173077,
#  'ді': 0.0031821321310542346,
#  'ят': 0.002370305516660705,
#  'ео': 0.0006202005063038667,
#  'до': 0.006911882240566761,
#  'рд': 0.00045433889095735763,
#  'йз': 0.0005360917606223507,
#  'ер': 0.009210614833614883,
#  'ам': 0.004404123621040376,
#  'ик': 0.002496702661775823,
#  'ан': 0.006469285793326917,
#  'сь': 0.0031003769902233787,
#  'тр': 0.003409238403227999,
#  'аг': 0.002207484580872557,
#  'ед': 0.002686335908206299,
#  'ія': 0.0014241693853444548,
#  'ро': 0.010830357068508479,
#  'ма': 0.004641982442046147,
#  'нп': 0.0008522694042582722,
#  'ек': 0.0015038835533649165,
#  'ла': 0.009518221767192268,
#  'дз': 0.00047308246792541347,
#  'гл': 0.0012846887471140128,
#  'ій': 0.002189036936593127,
#  'ко': 0.007161479914598911,
#  'їі': 0.0002733604653086959,
#  'бу': 0.005310827948407592,
#  'ше': 0.001840815602186243,
#  'лс': 9.01613996798877e-05,
#  'мі': 0.004852760131882512,
#  'ля': 0.0029588033382778396,
#  'ий': 0.005525389920108038,
#  'ще': 0.0011979487078252514,
#  'нк': 0.0008949644981600131,
#  'оз': 0.005218087722691308,
#  'ав': 0.011259158360878355,
#  'ид': 0.0024308404676740367,
#  'ня': 0.0028100842075398013,
#  'мт': 0.0005666636507377928,
#  'дя': 0.0007185214554283813,
#  'пи': 0.0014994159407298725,
#  'нн': 0.0037422238200577125,
#  'ве': 0.0034873631467885104,
#  'рс': 0.0004589314796934003,
#  'фа': 0.00033532856875229637,
#  'йл': 0.000159979578420367,
#  'уб': 0.0010374529149458705,
#  'ул': 0.003003643303397335,
#  'зм': 0.0009552860461961839,
#  'іс': 0.005068030201129721,
#  'тк': 0.0006830028819973581,
#  'ни': 0.00744338495127788,
#  'га': 0.002827970974416438,
#  'пе': 0.0039218909836637025,
#  'рш': 0.0005397956184482127,
#  'ак': 0.005732689797989804,
#  'уг': 0.000717167535101544,
#  'ет': 0.003149630193995706,
#  'як': 0.006759330711203551,
#  'ар': 0.004322183028049372,
#  'лі': 0.0032885949657001303,
#  'тн': 0.0013360494323979752,
#  'чі': 0.0009504253637283699,
#  'рп': 0.00031167367452689045,
#  'см': 0.000846494096913028,
#  'кт': 0.000705707019638891,
#  'го': 0.01186933382615296,
#  'ви': 0.010080962551458636,
#  'йц': 0.00013919659767375604,
#  'ен': 0.008932097021956195,
#  'ст': 0.011310698458259502,
#  'ад': 0.005182993255397396,
#  'ем': 0.003648520997782771,
#  'шя': 6.306998276566872e-05,
#  'кч': 0.0001165912609313028,
#  'от': 0.0061016836129825554,
#  'ир': 0.002000221915214886,
#  'ис': 0.0075216469871715146,
#  'та': 0.011048558321316296,
#  'ти': 0.01469833669543226,
#  'ся': 0.00809049648816692,
#  'чж': 4.017973586743048e-06,
#  'ит': 0.00873109168521794,
#  'ел': 0.0027968322641804735,
#  'ів': 0.00905422726079935,
#  'со': 0.0031051290940527837,
#  'кі': 0.003804007216325533,
#  'ди': 0.005008081295028268,
#  'ті': 0.0061561786707349025,
#  'ли': 0.012219460156168172,
#  'не': 0.01584437574867093,
#  'дь': 0.0013298060359902882,
#  'мо': 0.007367771309728274,
#  'жл': 0.0004897738819297487,
#  'ив': 0.011747323839821655,
#  'ос': 0.009662271587741002,
#  'зд': 0.002246397211909747,
#  'ян': 0.002597832533805288,
#  'ей': 0.0025756588433565905,
#  'ві': 0.017681123289854134,
#  'рн': 0.0019971532081674093,
#  'им': 0.007185015670747213,
#  'що': 0.008913267394312505,
#  'ну': 0.005888416352014351,
#  'ва': 0.012365605839357514,
#  'аі': 0.001715579088921082,
#  'на': 0.023620308625993246,
#  'ши': 0.003239747066774106,
#  'йв': 0.001055127273079197,
#  'иц': 0.0017215526288469607,
#  'іт': 0.006304597554443058,
#  'еп': 0.00539241840058481,
#  'йж': 0.000575881558174343,
#  'ез': 0.005449402682442001,
#  'их': 0.00419919890740888,
#  'йг': 0.0003107979431531991,
#  'ру': 0.004031680761783366,
#  'па': 0.002240010406559757,
#  'оч': 0.005265956185707779,
#  'ол': 0.007611143279115942,
#  'ов': 0.021150119068974352,
#  'ік': 0.004522418555888454,
#  'вп': 0.0020529200161573656,
#  'де': 0.004554916467312273,
#  'ку': 0.005049835490802098,
#  'це': 0.005088628205204416,
#  'нь': 0.003191036515149118,
#  'ки': 0.008733099851057406,
#  'йт': 0.0014219241620604113,
#  'зб': 0.0008795767241222658,
#  'уй': 0.00036233961242889296,
#  'но': 0.01347854938734959,
#  'юг': 0.0002122889998902183,
#  'во': 0.014634717850517141,
#  'юв': 0.0018150692086056192,
#  'би': 0.0032714047877342254,
#  'єт': 0.0017077134630994707,
#  'ьс': 0.002973444756491094,
#  'яз': 0.002700541135704613,
#  'пі': 0.004817070474400307,
#  'дк': 0.0015347568200383438,
#  'ог': 0.016660534744312207,
#  'фе': 0.0002519376985592732,
#  'ок': 0.006769668250143875,
#  'ап': 0.007230985058621875,
#  'юх': 0.0003426918027339117,
#  'то': 0.012137772654148392,
#  'по': 0.020780108026080903,
#  'зн': 0.007391039567036051,
#  'ао': 0.0013010205848902792,
#  'ба': 0.005216920899038966,
#  'ре': 0.009584058396750502,
#  'ні': 0.015423843192234879,
#  'му': 0.009088217815737706,
#  'че': 0.004989208439218099,
#  'зп': 0.0015204220975664387,
#  'ле': 0.007353552180647566,
#  'чк': 0.0006583492789481142,
#  'нч': 0.0007483263054696254,
#  'из': 0.004960574396259833,
#  'ча': 0.006139965089988401,
#  'йн': 0.003731333309211284,
#  'ту': 0.0054831572754191265,
#  'ют': 0.001708235721621629,
#  'яв': 0.005107301811050385,
#  'ич': 0.0037753242447653252,
#  'пр': 0.01751218986472919,
#  'оп': 0.008030189120952411,
#  'ід': 0.016183615474649138,
#  'йс': 0.0028954183744122767,
#  'жі': 0.0008183196129292318,
#  'пя': 0.0006876749848152333,
#  'ть': 0.012282926763260088,
#  'ло': 0.011700455556479705,
#  'дш': 0.0002727711519185649,
#  'аз': 0.00991102696404434,
#  'ьо': 0.006173636454033464,
#  'ря': 0.0017069459560422947,
#  'дн': 0.007084755398003316,
#  'аа': 0.0011407772077827666,
#  'кр': 0.004124582134571126,
#  'яг': 0.0013659458563094885,
#  'ду': 0.008272715888235992,
#  'же': 0.009296855477434515,
#  'ев': 0.009961065289941236,
#  'дл': 0.002094221347737356,
#  'об': 0.018039811195862968,
#  'чч': 0.0005294964122806436,
#  'ям': 0.0026181729250644007,
#  'за': 0.016323781390537924,
#  'хл': 0.0010173576282229047,
#  'чи': 0.011327671404822595,
#  'вс': 0.012059647212175185,
#  'иі': 0.0031920690494292477,
#  'се': 0.007285614191457367,
#  'бі': 0.006050387618550327,
#  'бл': 0.0036082970413744116,
#  'ію': 0.0010884551518023544,
#  'кн': 0.002191571531150048,
#  'иж': 0.0012316177830117622,
#  'еч': 0.0029184231201846607,
#  'пс': 0.00018551187938076804,
#  'ал': 0.021391426796926537,
#  'мз': 0.0015715911042226477,
#  'хи': 0.0015360847624108595,
#  'дд': 0.0011115709008903448,
#  'ут': 0.009960265032749206,
#  'ьд': 0.0018078074003539503,
#  'ця': 0.002868616044467695,
#  'кд': 0.0005796675619269276,
#  'дц': 0.0012760082936798568,
#  'вч': 0.0028219895556778262,
#  'ин': 0.01849406364883566,
#  'вд': 0.004535922187924226,
#  'сі': 0.007280831037007498,
#  'сл': 0.004549980220385211,
#  'ух': 0.0017469929966825101,
#  'да': 0.012836686151467254,
#  'яб': 0.0014010164128464026,
#  'жа': 0.003482482840269132,
#  'яй': 0.0007062205897120968,
#  'ми': 0.009219272309603142,
#  'сп': 0.007961300672299878,
#  'ає': 0.005227971467977259,
#  'иє': 0.000568912593807208,
#  'мн': 0.005431075523933647,
#  'уз': 0.003335550851206649,
#  'гу': 0.0025088586870227756,
#  'ву': 0.005223812248866766,
#  'цю': 0.0014800253049936272,
#  'ою': 0.007111800856761694,
#  'йш': 0.0018086278868459898,
#  'дп': 0.0029000065725886155,
#  'мк': 0.002038312391456656,
#  'ом': 0.025954854708889932,
#  'ін': 0.02785810842928508,
#  'ша': 0.0015414334598369544,
#  'бн': 0.00200746658211953,
#  'оу': 0.0010006469532961417,
#  'юр': 0.0011243001734584463,
#  'вр': 0.002251131281272612,
#  'із': 0.007978779993108386,
#  'бо': 0.007433011476948114,
#  'мв': 0.0023226348182665505,
#  'аї': 0.0009343486876311654,
#  'іб': 0.005067965540682951,
#  'рв': 0.0016069039546703023,
#  'юч': 0.0041236612616205376,
#  'ув': 0.020450166366553977,
#  'ль': 0.011657102181384028,
#  'ці': 0.008030360651301756,
#  'чн': 0.003519725665028426,
#  'ум': 0.010276371666871792,
#  'ас': 0.019689916776349695,
#  'яп': 0.003663266479152268,
#  'йд': 0.012828608908799315,
#  'уж': 0.006639353434818365,
#  'іл': 0.01825216884870286,
#  'зу': 0.007163806873149169,
#  'рі': 0.015368769672551786,
#  'вм': 0.002262739199437086,
#  'аш': 0.003179883141742843,
#  'юд': 0.0034340061130571685,
#  'бв': 0.001505641939676317,
#  'он': 0.0336950972475748,
#  'сн': 0.005290451677595428,
#  'иї': 0.004279104770994154,
#  'їд': 0.0017676726771930838,
#  'шо': 0.0036570928567906955,
#  'вш': 0.0032068720389878407,
#  'уд': 0.013224068392783768,
#  'еш': 0.002376486126745397,
#  'хї': 6.562389062054862e-05,
#  'мп': 0.0036489277737682024,
#  'іш': 0.007423385061748797,
#  'зь': 0.001181228765571548,
#  'йп': 0.0032023909615875213,
#  'хі': 0.0031460260535436926,
#  'дм': 0.001424191423214404,
#  'іж': 0.0026448729405924025,
#  'дв': 0.006028846440352491,
#  'яд': 0.006328833611173424,
#  'йч': 0.0015701941692333435,
#  'жо': 0.0011437553015039876,
#  'кж': 0.00019766002401608703,
#  'тя': 0.00436983185222695,
#  'чо': 0.0072785002370414605,
#  'кп': 0.0015312078994154576,
#  'рг': 0.0018582278583375888,
#  'лю': 0.006844642057939969,
#  'аж': 0.0073029532746231906,
#  'ил': 0.01555572451067572,
#  'пю': 3.5653264859738165e-05,
#  'ір': 0.00832176871437131,
#  'иг': 0.004566124035698327,
#  'уп': 0.00776551053069118,
#  'са': 0.007687960151142668,
#  'лм': 0.0002274367359672223,
#  'уч': 0.0045277544827836275,
#  'оа': 0.002056708476100165,
#  'йх': 0.0009750717994405203,
#  'пч': 0.0005989235023963499,
#  'мм': 0.0009840069432273146,
#  'ск': 0.009442440626174739,
#  'ць': 0.005345648178157044,
#  'кц': 0.000563745891044639,
#  'еб': 0.013770679458978991,
#  'вн': 0.013391017605840272,
#  'тю': 0.0024270214100201334,
#  'іп': 0.012428068501924048,
#  'си': 0.007916289358318982,
#  'ур': 0.006927655042153573,
#  'ьт': 0.0028588784089597615,
#  'єв': 0.0011899559036116858,
#  'лу': 0.005341191594883441,
#  'ха': 0.006358636904804516,
#  'єм': 0.002653577048863843,
#  'ох': 0.006781380174239005,
#  'гі': 0.004010037465529965,
#  'ож': 0.014841935401225536,
#  'хт': 0.003820486568202366,
#  'єд': 0.0007519879493197573,
#  'сг': 0.0006522133418859687,
#  'ае': 0.0003514209990247268,
#  'ах': 0.008219446105657287,
#  'зо': 0.005181837823266768,
#  'ім': 0.015906440051183125,
#  'ої': 0.012241189358270526,
#  'ья': 0.001658203830460031,
#  'шб': 6.993507424686269e-05,
#  'йо': 0.02057983483683487,
#  'уо': 0.0021244340929873554,
#  'рт': 0.012961590423755925,
#  'ес': 0.01811626223326104,
#  'аю': 0.008297654666152239,
#  'ая': 0.005509802064404769,
#  'йб': 0.0035843675371644485,
#  'ьз': 0.00337184547005314,
#  'хр': 0.0011026201138286274,
#  'їт': 0.0015189554845419743,
#  'мл': 0.001436226473001697,
#  'хп': 0.001996576626238392,
#  'йі': 0.002948708740036323,
#  'уі': 0.0050590108153615865,
#  'пу': 0.0027621958866560718,
#  'еу': 0.001408883947663156,
#  'ню': 0.0019579443765171474,
#  'її': 0.009174231753252094,
#  'ял': 0.003299916249228376,
#  'ящ': 0.0029018553226806227,
#  'єї': 0.0024122289474284124,
#  'шу': 0.003651567023543588,
#  'їя': 0.00044215210882090174,
#  'кб': 0.002418167382189601,
#  'яо': 0.0016455806846708842,
#  'ип': 0.01689747134047735,
#  'ец': 0.005009791100894891,
#  'іа': 0.003662746544335647,
#  'зі': 0.006420710888327465,
#  'бр': 0.007654753948717878,
#  'жу': 0.005782782601233026,
#  'мя': 0.00412211459280707,
#  'бк': 0.00046682442594417117,
#  'ьн': 0.01084576357286706,
#  'ке': 0.004690156138343437,
#  'зс': 0.0036896867893721043,
#  'мб': 0.0021373624905900983,
#  'нш': 0.004835271726539046,
#  'зя': 0.003185900686189753,
#  'жц': 0.00032067722213935217,
#  'пк': 0.0002673167399227427,
#  'иа': 0.004353080164697962,
#  'бе': 0.022891820438544378,
#  'зл': 0.003660988429573233,
#  'жи': 0.008286800944064672,
#  'пд': 5.563279002730558e-05,
#  'ци': 0.002459106124619402,
#  'нт': 0.0065923727912962195,
#  'ац': 0.005850116010287137,
#  'яі': 0.0048454280872242805,
#  'чу': 0.00978343940778388,
#  'тт': 0.00475666051260368,
#  'їп': 0.0031210020007123775,
#  'ой': 0.006908495484068063,
#  'їб': 0.00116330338670446,
#  'іі': 0.006428913384320566,
#  'ук': 0.01066696602028478,
#  'св': 0.01422983817971273,
#  'ус': 0.02135839623116033,
#  'іє': 0.00528111808672694,
#  'їг': 0.0010865249533936604,
#  'йр': 0.0022495753431760407,
#  'ия': 0.007370962259615879,
#  'кщ': 0.005254148001981521,
#  'іх': 0.007364548761361655,
#  'ьш': 0.004411066911694777,
#  'кл': 0.028221337772520005,
#  'иб': 0.011391662246204094,
#  'оя': 0.012289358949053563,
#  'бт': 0.0011907113225405304,
#  'ьх': 0.0008840520444225125,
#  'вщ': 0.005456478019874013,
#  'вт': 0.012213000465862404,
#  'вз': 0.007341977905768696,
#  'ги': 0.0032719605153421097,
#  'йа': 0.0017654863792989754,
#  'іц': 0.004849856918966491,
#  'юш': 0.00034711483852533,
#  'юі': 0.003597358406267085,
#  'сс': 0.0028297305970531356,
#  'нз': 0.00851328174919836,
#  'шс': 0.00045117262349578756,
#  'еж': 0.009690484280248247,
#  'уц': 0.002663540708661612,
#  'зр': 0.01065405286757275,
#  'ощ': 0.006568091145814828,
#  'мс': 0.006800416000190375,
#  'жд': 0.004886518215812461,
#  'вж': 0.009453472972183102,
#  'ех': 0.006382251718883046,
#  'лк': 0.0025394227907537276,
#  'жн': 0.013238616454075945,
#  'аб': 0.025572783846242283,
#  'ио': 0.0050774554806256806,
#  'дч': 0.005682583719121667,
#  'уш': 0.005352948305942946,
#  'юн': 0.004922723975471744,
#  'дт': 0.0058219616269270524,
#  'бс': 0.0017600164732492513,
#  'яр': 0.0032858136938452823,
#  'їв': 0.004647466354171554,
#  'еа': 0.0035382259839356906,
#  'кг': 0.0007458278844220795,
#  'яч': 0.005127337342146272,
#  'їх': 0.01020966773905317,
#  'їл': 0.00102161129160821,
#  'рб': 0.0021772676796317204,
#  'сц': 0.003636697399156529,
#  'ях': 0.0037329249066637054,
#  'іг': 0.015254093505318157,
#  'мч': 0.0029763178034203732,
#  'ії': 0.005665100321663123,
#  'зв': 0.021151934778703,
#  'юо': 0.0011850096292722327,
#  'кв': 0.008618959796784786,
#  'гр': 0.016895010431551807,
#  'ош': 0.008145140802783507,
#  'сх': 0.0049452650490932355,
#  'оо': 0.008452358665458404,
#  'гн': 0.005707329442417521,
#  'вл': 0.012436860419775828,
#  'хв': 0.01024617529045119,
#  'нв': 0.006550147254062753,
#  'вв': 0.01197410037015866,
#  'їн': 0.0038543703736767377,
#  'мю': 0.0012320107431829487,
#  'ач': 0.025441565256485013,
#  'зг': 0.006842863732013512,
#  'мг': 0.0012545394295690872,
#  'дб': 0.004665570907365822,
#  'ея': 0.009535134471413275,
#  'км': 0.003862905450715466,
#  'ші': 0.006233040370017671,
#  'вї': 0.00488286656609232,
#  'мж': 0.0006159195126189136,
#  'хо': 0.03564263102101155,
#  'ьв': 0.009373129534482662,
#  'іщ': 0.00888120311604302,
#  'уу': 0.0007593884700849565,
#  'ьі': 0.006969969911298695,
#  'еі': 0.007434338638984917,
#  'зщ': 0.00015420631001718775,
#  'кй': 0.0009033476860881148,
#  'зй': 0.0008159532777837871,
#  'ещ': 0.012006515001775476,
#  'вх': 0.002457290807698377,
#  'су': 0.022976279673212162,
#  'мр': 0.006944958265088356,
#  'іф': 0.009809402423542854,
#  'дх': 0.0018880771785640016,
#  'іо': 0.010252268739350654,
#  'нд': 0.015950618849333107,
#  'уа': 0.007313303925184654,
#  'ащ': 0.015169146591450074,
#  'єх': 0.0004414811875325002,
#  'уя': 0.007974708705744463,
#  'хщ': 0.0012120058536409977,
#  'іч': 0.019688038032110777,
#  'дс': 0.009372268082461433,
#  'йм': 0.009435435097580314,
#  'єю': 0.003913099598532826,
#  'шт': 0.009666108008105781,
#  'мц': 0.0021399919622063376,
#  'ху': 0.005596833939169091,
#  'зк': 0.009284120981092875,
#  'гч': 0.00010618834353432332,
#  'ьп': 0.012690854637408211,
#  'иш': 0.012101025573820586,
#  'ую': 0.006696256708331316,
#  'оі': 0.01762080757017687,
#  'ун': 0.025384981964808696,
#  'оц': 0.017144659903258645,
#  'тз': 0.0029121398923409223,
#  'ьщ': 0.004994302901070828,
#  'ег': 0.01802276866121625,
#  'ьм': 0.00813055868789691,
#  'еї': 0.01217525969678755,
#  'тв': 0.018854077291685967,
#  'оє': 0.01016788680319386,
#  'ьу': 0.008858707863657877,
#  'хс': 0.005166223427034805,
#  'щи': 0.0039824011032595875,
#  'шн': 0.010075775280431588,
#  'жт': 0.0019710410107492836,
#  'юп': 0.010230803360045976,
#  'жк': 0.006607542196303024,
#  'шп': 0.0014488395724799278,
#  'хд': 0.005375079423938373,
#  'їз': 0.009946244305996868,
#  'вб': 0.013327909023523928,
#  'ищ': 0.029357699080289557,
#  'їч': 0.0020280293728756845,
#  'чц': 0.0005605932385254352,
#  'сб': 0.002278687403503748,
#  'йу': 0.0052705188365571665,
#  'зи': 0.009678489945996474,
#  'їс': 0.008203676275413277,
#  'чт': 0.0012227480336989363,
#  'юс': 0.01051410345580667,
#  'кс': 0.013245885714232497,
#  'юй': 0.0021020610140702195,
#  'йк': 0.011012871368447561,
#  'нг': 0.002727823990349264,
#  'хю': 0.0005620448810588308,
#  'дж': 0.026393473511871716,
#  'нц': 0.015287289113191226,
#  'фі': 0.01751895442070871,
#  'тс': 0.01695568284222754,
#  'юя': 0.004372764068797657,
#  'рк': 0.014233230707270048,
#  'юм': 0.007013098475686857,
#  'пл': 0.025425458400055223,
#  'дг': 0.003793952097014532,
#  'мщ': 0.005006548800546185,
#  'гп': 0.0026663918035863504,
#  'ьй': 0.005735131933008193,
#  'жб': 0.006115172081201412,
#  'гб': 0.006938259155435035,
#  'хз': 0.006107898488106557,
#  'мї': 0.0028295516623663844,
#  'їм': 0.011616344712105205,
#  'жз': 0.003229794681054569,
#  'ау': 0.009450757122240772,
#  'вг': 0.014220517077481176,
#  'ьл': 0.003226183243153182,
#  'кз': 0.00975611161468379,
#  'юб': 0.014381449244252486,
#  'ує': 0.011180333915317859,
#  'хн': 0.017391300878801405,
#  'шл': 0.014773625956687264,
#  'иу': 0.008363630325052407,
#  'юз': 0.007785385005903104,
#  'рх': 0.004627405234313247,
#  'вя': 0.02481106562419321,
#  'гє': 5.18172788219113e-05,
#  'жч': 0.0059074758791609,
#  'яя': 0.013084100932209132,
#  'тл': 0.009454591072062955,
#  'єй': 0.002399537956000872,
#  'яц': 0.011117874001409353,
#  'жя': 0.002432350398953164,
#  'яї': 0.006447898199481092,
#  'мд': 0.013143089163523436,
#  'шв': 0.009615572742575507,
#  'бй': 0.0013391619934930601,
#  'бб': 0.0016761970660200717,
#  'ущ': 0.01578270586773576,
#  'хм': 0.010065010661180726,
#  'ьї': 0.004308194584589968,
#  'їж': 0.005596039103222538,
#  'нб': 0.013575688900605946,
#  'нє': 0.004352247911218579,
#  'оф': 0.006025266328649175,
#  'мє': 0.000950868715077476,
#  'шк': 0.014930949496800966,
#  'їр': 0.0055556447369163,
#  'ое': 0.0012144957553499743,
#  'юю': 0.005107084328061083,
#  'кє': 0.0001222214029676689,
#  'ие': 0.0011001270775669947,
#  'пт': 0.008688337970259868,
#  'цт': 0.0019750945563096005,
#  'їю': 0.00018553153436011853,
#  'лщ': 0.0004948425615155387,
#  'рц': 0.007921400587943009,
#  'ьц': 0.01041746816111219,
#  'ьф': 0.0014498438843192905,
#  'тб': 0.0036614362324079355,
#  'аф': 0.01045443061369347,
#  'нщ': 0.003329535843941398,
#  'йя': 0.006809802789508911,
#  'єя': 0.0024579873906732793,
#  'тч': 0.0027882598484208093,
#  'ср': 0.0015605891007076764,
#  'юк': 0.00846640267876753,
#  'фу': 0.0034811582137286,
#  'яа': 0.011139071268150048,
#  'рч': 0.003132741756147226,
#  'зз': 0.00742185206702213,
#  'сщ': 0.001347269206870517,
#  'дю': 0.0013490866673561703,
#  'хк': 0.008105454226756752,
#  'щі': 0.005311595231383883,
#  'вк': 0.044088875660817546,
#  'бж': 0.0006445650879415907,
#  'рм': 0.014834558176148952,
#  'уе': 0.0013821279001722993,
#  'їй': 0.03132302596697077,
#  'цн': 0.0029327825429703047,
#  'зч': 0.005128609527510339,
#  'їа': 0.005761521720890408,
#  'яс': 0.045596765643840714,
#  'яу': 0.0056722807455747365,
#  'юл': 0.0050618605208284624,
#  'рз': 0.014293764884569876,
#  'єч': 0.0018843136387066582,
#  'ює': 0.005089042723501633,
#  'хб': 0.007672607105647456,
#  'нй': 0.0012470848779973119,
#  'ьа': 0.011237777198834533,
#  'єз': 0.0061457831594770125,
#  'шз': 0.0034730842522693924,
#  'ьг': 0.00663035685381897,
#  'нм': 0.016515376516083948,
#  'ею': 0.025754592512562367,
#  'хг': 0.005358520000615296,
#  'сю': 0.012301197661550039,
#  'зт': 0.021272457979445398,
#  'зц': 0.011981987423506006,
#  'хя': 0.004888517128957009,
#  'гт': 0.014076287476771374,
#  'нх': 0.004695199406446245,
#  'вц': 0.031288520482446826,
#  'чщ': 0.0005962894425737513,
#  'мф': 0.0015910538145026839,
#  'фр': 0.008067544557048265,
#  'мй': 0.003614734485694982,
#  'бм': 0.00886807013193429,
#  'сф': 0.0029485777619055954,
#  'ьр': 0.011931162526433798,
#  'гм': 0.0010320700203345769,
#  'ща': 0.026758227040389104,
#  'гк': 0.011464611724650815,
#  'яш': 0.003221544200714829,
#  'дї': 0.006140714440001758,
#  'ьб': 0.01734358368604445,
#  'ию': 0.0018752762517304379,
#  'рю': 0.011051759590992093,
#  'бх': 0.005140615985052957,
#  'рж': 0.009885031355929014,
#  'юа': 0.017811845450982553,
#  'хч': 0.004735845621546731,
#  'єщ': 0.007543769939768525,
#  'чл': 0.009939905579616524,
#  'єп': 0.0132287646467271,
#  'уї': 0.008737897754301503,
#  'бш': 0.0010867700142103286,
#  'тш': 0.0012088358058820153,
#  'юе': 0.006898702484007924,
#  'жв': 0.020230505458136754,
#  'кш': 0.010697248646534126,
#  'чя': 0.01785386237689342,
#  'шч': 0.001280167309141948,
#  'цм': 0.00025636160556188263,
#  'жї': 0.0011539230086650236,
#  'яж': 0.019896074076625102,
#  'їо': 0.01335865095241959,
#  'гї': 0.0003982204904297969,
#  'іу': 0.016200750558608562,
#  'пн': 0.01768231665553738,
#  'єб': 0.0045344935714966336,
#  'кк': 0.010076535120978971,
#  'иф': 0.0078086176997394,
#  'хф': 0.001686442167279998,
#  'бз': 0.007601807960568542,
#  'хж': 0.0025533432796946308,
#  'їе': 0.000853292867111858,
#  'єн': 0.018646135950679123,
#  'ьч': 0.01972557390943627,
#  'ца': 0.0029591828054329446,
#  'їц': 0.004155149956628629,
#  'ющ': 0.015348782942343226,
#  'йї': 0.0039348360070089955,
#  'мш': 0.008204630697319982,
#  'сї': 0.0016851374906715327,
#  'кх': 0.00506394460764867,
#  'ее': 0.0023135066753576998,
#  'тц': 0.0047923325123260955,
#  'тж': 0.01568890332621903,
#  'яе': 0.0015781117619111682,
#  'кя': 0.02102205635239768,
#  'йе': 0.00226035789757086,
#  'гд': 0.0045309557231483855,
#  'жм': 0.007965256901740048,
#  'хц': 0.005735143682449916,
#  'жр': 0.003131319336929791,
#  'фо': 0.030419593446764377,
#  'рл': 0.02301883117509336,
#  'гс': 0.006806536357769146,
#  'хх': 0.009137566131745146,
#  'уф': 0.011349927729995872,
#  'кї': 0.006098858433070743,
#  'гз': 0.006677712116115999,
#  'яє': 0.012173348738575115,
#  'сз': 0.013426920257028137,
#  'йщ': 0.01938905045667684,
#  'жщ': 0.001901187115246075,
#  'гй': 0.0007619231291362884,
#  'зї': 0.013534445785175576,
#  'рй': 0.01178769532630159,
#  'нл': 0.0121238205193372,
#  'єр': 0.008709574326522102,
#  'бд': 0.012979439636197925,
#  'жп': 0.01921935690796333,
#  'шд': 0.0026815443933367964,
#  'сє': 0.001447790031916836,
#  'чю': 0.0022783965791914346,
#  'шш': 0.0014531990100763311,
#  'зш': 0.008523978667690248,
#  'зх': 0.006710045795172294,
#  'бю': 0.004222103187126782,
#  'юї': 0.00593600158237291,
#  'єц': 0.004052048943462518,
#  'сч': 0.002997865179920474,
#  'рь': 0.00601375492584858,
#  'зж': 0.006266207228539462,
#  'чв': 0.015438121469832512,
#  'вю': 0.0013250823170457306,
#  'еф': 0.04555484347158344,
#  'фт': 0.0032436935090423826,
#  'тм': 0.014411664589140366,
#  'мх': 0.016509102557827945,
#  'лл': 0.06306800739497093,
#  'бц': 0.0043509811702920126,
#  'їу': 0.010796446001750528,
#  'лт': 0.008315619680768611,
#  'юц': 0.012577996173599603,
#  'бє': 0.003449922369918439,
#  'нр': 0.02742860175039726,
#  'їк': 0.026832909423115246,
#  'нж': 0.006471110743753868,
#  'йф': 0.0073628007607723445,
#  'пц': 0.009129105378188672,
#  'рр': 0.01813846694980236,
#  'жх': 0.0038119818591918287,
#  'єс': 0.02619724841961843,
#  'гв': 0.013299763303073711,
#  'сд': 0.019605783725029465,
#  'йю': 0.0065617567584439936,
#  'фф': 0.0022016947238775266,
#  'чс': 0.00756531890850852,
#  'хе': 0.04224396393573677,
#  'рщ': 0.008290716198615997,
#  'їш': 0.002340801016629169,
#  'вй': 0.055975808667844566,
#  'вф': 0.007101043056968976,
#  'фк': 0.0017879525846711208,
#  'чб': 0.017911539378007282,
#  'зю': 0.003282857046973674,
#  'іе': 0.010612922929402224,
#  'хй': 0.004068757058267524,
#  'тх': 0.011884722331102009,
#  'тщ': 0.021048324667232877,
#  'тд': 0.03532259247207725,
#  'єл': 0.005173922065710052,
#  'тп': 0.04280674917774801,
#  'бя': 0.023822971337161165,
#  'жж': 0.006422133338420601,
#  'бп': 0.052570823442321384,
#  'пш': 0.0031836539097124953,
#  'ью': 0.027831836420355246,
#  'шю': 0.0009386311358820432,
#  'єж': 0.011743907222143204,
#  'чх': 0.0019013438722915352,
#  'шж': 0.0014287231068958798,
#  'єш': 0.04339991116841311,
#  'жс': 0.02193614514097686,
#  'еє': 0.013762563414412602,
#  'шм': 0.019639688376371065,
#  'єі': 0.027413476926178786,
#  'лб': 0.08455721605757656,
#  'щу': 0.014801752483075815,
#  'дщ': 0.02283648362089349,
#  'тє': 0.011069928023504929,
#  'гщ': 0.0037312553335723986,
#  'гш': 0.01747769808935764,
#  'єк': 0.024776706108522603,
#  'лд': 0.09054879741698188,
#  'єо': 0.014324857604973396,
#  'тї': 0.00508651152707073,
#  'єа': 0.020449989631358183,
#  'фс': 0.09916386976691174,
#  'рф': 0.009103597985915915,
#  'лн': 0.12110353897366183,
#  'юу': 0.03420610627629366,
#  'лп': 0.029513677304229095,
#  'лв': 0.021287220180563605,
#  'лз': 0.012428424235543686,
#  'яю': 0.10067735887792925,
#  'ьє': 0.006995927817073661,
#  'сж': 0.007045157763715367,
#  'чї': 0.0059125708867811275,
#  'ьж': 0.029738477366923064,
#  'жй': 0.012259537235240201,
#  'чп': 0.023581869122887674,
#  'фл': 0.022879592005669677,
#  'жг': 0.022113815524139414,
#  'пг': 0.0053207599591296425,
#  'тг': 0.03610699080341726,
#  'їщ': 0.047168912393699566,
#  'бг': 0.030573875769439422,
#  'кф': 0.01802095441839912,
#  'їє': 0.006117054419775569,
#  'тф': 0.02615724186577131,
#  'цв': 0.0063196966284295225,
#  'бч': 0.011129694265068288,
#  'пє': 0.0016078224442296893,
#  'гц': 0.01288326024438726,
#  'шр': 0.022839478515745165,
#  'нї': 0.03338917368115999,
#  'дй': 0.03281350161651031,
#  'чй': 0.010713085133338232,
#  'фн': 0.0018048148003384573,
#  'йє': 0.007232288584689828,
#  'чд': 0.01821219919021567,
#  'хш': 0.02040435042343242,
#  'фг': 0.001893505020536209,
#  'чг': 0.017073813320278637,
#  'шц': 0.013509859814884475,
#  'лг': 0.07629800494380368,
#  'бї': 0.04446986527186008,
#  'йй': 0.055398670315056846,
#  'гх': 0.021110418925985495,
#  'жф': 0.011980327010931519,
#  'чм': 0.026675535321895275,
#  'жє': 0.007474036428151525,
#  'пп': 0.03514082614293517,
#  'пв': 0.031214871158165083,
#  'цу': 0.02684827816659547,
#  'цк': 0.002758695177115974,
#  'фд': 0.008298916554354796,
#  'юж': 0.08089232157968615,
#  'фи': 0.04247802706207848,
#  'яф': 0.03485152488816793,
#  'лх': 0.032823530120277396,
#  'дф': 0.010180109373918077,
#  'зф': 0.05485040498240306,
#  'гг': 0.02175825991249144,
#  'шй': 0.014826945236456427,
#  'тй': 0.05267238402916461,
#  'зє': 0.023824025903892276,
#  'єе': 0.012201548730570812,
#  'єф': 0.0041172149888866185,
#  'шщ': 0.03720749543654661,
#  'єу': 0.0171729868870486,
#  'сй': 0.052415222120640814,
#  'еи': 0.004608432084623501,
#  'пщ': 0.01388900783335781,
#  'юф': 0.04694570333953745,
#  'вє': 0.014774032291348686,
#  'сш': 0.029988940238542327,
#  'рє': 0.04636695632372988,
#  'чз': 0.09721841121396284,
#  'бф': 0.005979168579918978,
#  'фв': 0.012029835502178456,
#  'єг': 0.103491094149733,
#  'чр': 0.03392847650786954,
#  'лц': 0.1404467142683635,
#  'гя': 0.08160386952339649,
#  'цр': 0.017758076194390213,
#  'їф': 0.045190562533252675,
#  'пф': 0.00946183351941668,
#  'цщ': 0.019102703444358524,
#  'лф': 0.0681488552154028,
#  'лє': 0.010440105308595363,
#  'бщ': 0.05274544551675042,
#  'лї': 0.022259900818554352,
#  'лй': 0.022760917531792317,
#  'рї': 0.09313948435845619,
#  'лр': 0.03846853170243694,
#  'цд': 0.02665803343858927,
#  'шї': 0.041067229506642995,
#  'фп': 0.028533921107019525,
#  'ье': 0.05871943367096971,
#  'фм': 0.015581355786138184,
#  'шг': 0.04747222372391643,
#  'лч': 0.03319925205927854,
#  'цч': 0.017159863960441647,
#  'лш': 0.01745423669690374,
#  'цс': 0.053276377932792406,
#  'шф': 0.018739431869782445,
#  'хє': 0.05727141764619391,
#  'фб': 0.020226773852582505,
#  'цо': 0.020635725467776825,
#  'нф': 0.16849098847314734,
#  'цб': 0.050442920262605793,
#  'жш': 0.05305149830560941,
#  'пм': 0.055940504698209596,
#  'жю': 0.029578614183578714,
#  'пб': 0.12181088216036311,
#  'пз': 0.276246914236437,
#  'пй': 0.09418037599170007,
#  'пї': 0.05173298571902666,
#  'гю': 0.10880351087929856,
#  'пх': 0.12128148474669977,
#  'лж': 0.0684376282039583,
#  'фя': 0.07309790621405692,
#  'шх': 0.07841058416170445,
#  'чф': 0.08451805893967385}

# %%
def find_index(bigram):
    return ukr_clean_alphabet.find(bigram[0]) * len(ukr_clean_alphabet) + ukr_clean_alphabet.find(bigram[1])

# %%
find_index('до')
# Out:
# 145

# %%
def bigram(index):
    return ''.join([ukr_clean_alphabet[index // 32], ukr_clean_alphabet[index % 32]])

# %%
bigram(145)
# Out:
# 'до'

# %%
def conc(it, n):
    return zip(*([iter(it)] * n))

# %%
def text_coding_by_bigram(text):
    encode_text = []
    
    for bigram in conc(text, 2):
        encode_text.append(find_index(bigram))
    
    return encode_text

# %%
text_coding_by_bigram('арполдун')
# Out:
# [19, 593, 452, 720]

# %%
def text_decoding_by_bigram(text):
    decoding_text = ''
    
    for i in text:
        decoding_text += bigram(i)
    
    return decoding_text

# %%
text_decoding_by_bigram([12, 34, 456, 23])
# Out:
# 'айбвлзаф'

# %% [markdown]
# **4. Генерирование текстов**

# %%
def generate_text_samples(text, L, N):
    X = []
    end_of_random_number = len(text) - L - 1
    
    for i in range(N):
        pos_l = []
        position = np.random.randint(end_of_random_number)
        pos_l.append(position)
        pos_l.append(position + L)
        X.append(pos_l)
    
    text_list = []
    for i in range(len(X)):
        text_list.append(text[X[i][0]:X[i][1]])
    
    return text_list

# %%
texts_10_10000 = []
texts_10_10000  = generate_text_samples(TEXT, 10, 10000)

# %%
texts_100_10000 = []
texts_100_10000  = generate_text_samples(TEXT, 100, 10000)

# %%
texts_1000_10000 = []
texts_1000_10000 = generate_text_samples(TEXT, 1000, 10000)

# %%
texts_10000_1000 = []
texts_10000_1000  = generate_text_samples(TEXT, 10000, 1000)

# %% [markdown]
# **5. Изменение текста**

# %% [markdown]
# 1) l = 1 (функции для монограмм)

# %% [markdown]
# - VIGENERE_encryption_letter (r = 1, 5, 10) +
# - Afine_encryption_letter +
# - uniform_letter +
# - s_letter +

# %%
def mod(x, y, z):
    return (x + y) % z

def random_key(length):
    letters = 'абвгдеєжзиіїйклмнопрстуфхцчшщьюя'
    rand_string = ''.join(random.choice(letters) for i in range(length))
    
    return rand_string

def key_initialization():
    temp = []
    
    k1 = random_key(1)
    k5 = random_key(5)
    k10 = random_key(10)
    
    temp.append(text_to_array_of_num(k1))
    temp.append(text_to_array_of_num(k5))
    temp.append(text_to_array_of_num(k10))
                
    return temp

# %%
key_initialization()
# Out:
# [[9], [11, 20, 24, 11, 6], [21, 19, 4, 1, 9, 2, 20, 24, 6, 13]]

# %%
def VIGENERE_encryption_letter(text, key):
    text = text_to_array_of_num(text)
    cipher = []
    
    for i in range(len(text)):
        cipher.append(mod(text[i], key[i % len(key)], 32))
    
    return array_of_numbers_to_text(cipher)

# %%
VIGENERE_encryption_letter(texts_100_10000[0], key_initialization()[0])
# Out:
# 'кужзаькьлбдеяжбпєялкємлзбрпчьяплюролйблюжаюжпвнкрьояжифвйлбькяжкяжечйвеолюлшяжкмнлоплоіьдвілйрквюрбч'

# %%
def Afine_letter(text):
    encrypt_text = []
    a = np.random.randint(32)
    b = np.random.randint(32)
    
    new_text = text_to_array_of_num(text)
    
    for i in new_text:
        encrypt_text.append(mod(a * i, b, 32))
   
    return array_of_numbers_to_text(encrypt_text)

# %%
Afine_letter('апрлвлг')
# Out:
# 'ахсзхзс'

# %%
def uniform_letter(L):
    list_of_rand = []
    for i in range(L):
        list_of_rand.append(np.random.randint(32))
    
    return array_of_numbers_to_text(list_of_rand)

# %%
uniform_letter(100)
# Out:
# 'ьрубтсещхуіффахнньтиаіфрмюеурїїнчжчиившьіивжвоумюяикгбикптощмяййьянечтцлкиечлєфеоміофуьжнвеьвілифйдї'

# %%
def s_letter(L):
    m = 32
    s0 = np.random.randint(32)
    s1 = np.random.randint(32)
    
    Y = [s0, s1] + [0] * (L - 2)
    
    for i in range(2, L):
        Y[i] = (Y[i-1] + Y[i-2]) % m 
    
    return array_of_numbers_to_text(Y)

# %%
s_letter(10)
# Out:
# 'аїїубфхмжу'

# %% [markdown]
# 2) l = 2 (функции для биграмм)

# %% [markdown]
# - VIGENERE_encryption_bigram (r = 1, 5, 10)
# - Afine_bigram +
# - uniform_bigram +
# - s_bigram

# %%
def Afine_bigram(text):
    
    l = []
    
    a = np.random.randint(1024)
    b = np.random.randint(1024)
    
    encrypt_text = text_coding_by_bigram(text)
    
    for i in encrypt_text:
        l.append((a * i + b) % 1024)
    
    return text_decoding_by_bigram(l)

# %%
Afine_bigram('аолдукштив')
# Out:
# 'югетцїзшги'

# %%
def uniform_bigram(L):
    l = []
    
    for i in range(L // 2):
        l.append(np.random.randint(1024))
    
    return text_decoding_by_bigram(l)

# %%
uniform_bigram(10)
# Out:
# 'зсьїпляянж'

# %%
def s_bigram(L):
    m = 1024
    
    s0 = np.random.randint(1024)
    s1 = np.random.randint(1024)
    
    Y = [s0, s1] + [0] * (L // 2 - 2)
    
    for i in range(2, L // 2):
        Y[i] = (Y[i-1] + Y[i-2]) % m 
    
    return text_decoding_by_bigram(Y)

# %%
s_bigram(10)
# Out:
# 'длахеєеюїд'

# %% [markdown]
# **6. Реализация критериев (частые l-граммы)**

# %% [markdown]
# 1) l = 1

# %% [markdown]
# - criterion_20:
# > 1. criterion_20_vigenere_r1_letter +
# > 2. criterion_20_vigenere_r5_letter +
# > 3. criterion_20_vigenere_r10_letter +
# > 4. criterion_20_afine_letter +
# > 5. criterion_20_uniform_letter +
# > 6. criterion_20_s_letter +
#
# - criterion_21:
# > 1. criterion_21_vigenere_r1_letter +
# > 2. criterion_21_vigenere_r5_letter +
# > 3. criterion_21_vigenere_r10_letter +
# > 4. criterion_21_afine_letter +
# > 5. criterion_21_uniform_letter +
# > 6. criterion_21_s_letter +
#
# - criterion_22:
# > 1. criterion_22_vigenere_r1_letter +
# > 2. criterion_22_vigenere_r5_letter +
# > 3. criterion_22_vigenere_r10_letter +
# > 4. criterion_22_afine_letter +
# > 5. criterion_22_uniform_letter +
# > 6. criterion_22_s_letter +
#
# - criterion_23:
# > 1. criterion_23_vigenere_r1_letter +
# > 2. criterion_23_vigenere_r5_letter +
# > 3. criterion_23_vigenere_r10_letter +
# > 4. criterion_23_afine_letter +
# > 5. criterion_23_uniform_letter +
# > 6. criterion_23_s_letter +
#
# - criterion_conformity
# > 1. criterion_conformity_vigenere_r1_letter +
# > 2. criterion_conformity_vigenere_r5_letter +
# > 3. criterion_conformity_vigenere_r10_letter +
# > 4. criterion_conformity_afine_letter +
# > 5. criterion_conformity_uniform_letter +
# > 6. criterion_conformity_s_letter +
#
# - criterion_50
# > 1. criterion_50_vigenere_r1_letter +
# > 2. criterion_50_vigenere_r5_letter +
# > 3. criterion_50_vigenere_r10_letter +
# > 4. criterion_50_afine_letter +
# > 5. criterion_50_uniform_letter +
# > 6. criterion_50_s_letter +
#
#
# - criterion_structural
# > 1. criterion_structural_vigenere_r1_letter +
# > 2. criterion_structural_vigenere_r5_letter +
# > 3. criterion_structural_vigenere_r10_letter +
# > 4. criterion_structural_afine_letter +
# > 5. criterion_structural_uniform_letter +
# > 6. criterion_structural_s_letter +

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %%
A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']

# %% [markdown]
# criterion_20(1)

# %%
def criterion_20_vigenere_r1_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r1_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0013)

# %%
criterion_20_vigenere_r1_letter(texts_100_10000, 15)
# Out:
# (0.9422, 0.8131)

# %%
criterion_20_vigenere_r1_letter(texts_1000_10000, 12)
# Out:
# (0.1323, 1.0)

# %%
criterion_20_vigenere_r1_letter(texts_10000_1000, 11)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_20(2)

# %%
def criterion_20_vigenere_r5_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r5_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0013)

# %%
criterion_20_vigenere_r5_letter(texts_100_10000, 7)
# Out:
# (0.4045, 0.9852)

# %%
criterion_20_vigenere_r5_letter(texts_1000_10000, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r5_letter(texts_10000_1000, 11)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_20(3)

# %%
def criterion_20_vigenere_r10_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r10_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0013)

# %%
criterion_20_vigenere_r10_letter(texts_100_10000, 16)
# Out:
# (0.601, 0.7709)

# %%
criterion_20_vigenere_r10_letter(texts_1000_10000, 20)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r10_letter(texts_10000_1000, 30)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_20(4)

# %%
def criterion_20_afine_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_afine_letter(texts_10_10000, 6)
# Out:
# (1.0, 0.0077)

# %%
criterion_20_afine_letter(texts_100_10000, 9)
# Out:
# (0.9352, 0.9684)

# %%
criterion_20_afine_letter(texts_1000_10000, 25)
# Out:
# (0.6366, 0.999)

# %%
criterion_20_afine_letter(texts_10000_1000, 25)
# Out:
# (0.479, 1.0)

# %% [markdown]
# criterion_20(5)

# %%
def criterion_20_uniform_letter(open_texts, A_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_uniform_letter(texts_10_10000, 6, 10)
# Out:
# (0.9998, 0.0077)

# %%
criterion_20_uniform_letter(texts_100_10000, 9, 100)
# Out:
# (0.3236, 0.9684)

# %%
criterion_20_uniform_letter(texts_1000_10000, 9, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_20_uniform_letter(texts_10000_1000, 9, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_20(6)

# %%
def criterion_20_s_letter(open_texts, A_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in range(len(text_corrupt)):
        tmp = list(text_corrupt[i][0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_s_letter(texts_10_10000, 6, 10)
# Out:
# (1.0, 0.0077)

# %%
criterion_20_s_letter(texts_100_10000, 9, 100)
# Out:
# (1.0, 0.9684)

# %%
criterion_20_s_letter(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 1.0)

# %%
criterion_20_s_letter(texts_10000_1000, 25, 10000)
# Out:
# (1.0, 1.0)

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# criterion_21(1)

# %%
def criterion_21_vigenere_r1_letter(open_texts, A_frq_size, kf):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r1_letter(texts_10_10000, 7, 2)
# Out:
# (0.2492, 0.1643)

# %%
criterion_21_vigenere_r1_letter(texts_100_10000, 7, 2)
# Out:
# (0.9983, 0.0)

# %%
criterion_21_vigenere_r1_letter(texts_1000_10000, 7, 2)
# Out:
# (1.0, 0.0)

# %%
criterion_21_vigenere_r1_letter(texts_10000_1000, 7, 2)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_21(2)

# %%
def criterion_21_vigenere_r5_letter(open_texts, A_frq_size, kf):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r5_letter(texts_10_10000, 7, 2)
# Out:
# (0.2808, 0.1643)

# %%
criterion_21_vigenere_r5_letter(texts_100_10000, 6, 5)
# Out:
# (0.6495, 0.0057)

# %%
criterion_21_vigenere_r5_letter(texts_1000_10000, 10, 9)
# Out:
# (1.0, 0.0)

# %%
criterion_21_vigenere_r5_letter(texts_10000_1000, 6, 2)
# Out:
# (1.0, 0.0)

# %%
def criterion_21_vigenere_r10_letter(open_texts, A_frq_size, kf):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r10_letter(texts_10_10000, 7, 2)
# Out:
# (0.2851, 0.1643)

# %%
criterion_21_vigenere_r10_letter(texts_100_10000, 9, 8)
# Out:
# (0.6061, 0.0316)

# %%
criterion_21_vigenere_r10_letter(texts_1000_10000, 9, 8)
# Out:
# (1.0, 0.0)

# %%
criterion_21_vigenere_r10_letter(texts_10000_1000, 9, 8)
# Out:
# (1.0, 0.0)

# %%
def criterion_21_afine_letter(open_texts, A_frq_size, kf):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_afine_letter(texts_10_10000, 7, 2)
# Out:
# (0.177, 0.1643)

# %%
criterion_21_afine_letter(texts_100_10000, 7, 2)
# Out:
# (0.7639, 0.0)

# %%
criterion_21_afine_letter(texts_1000_10000, 10, 2)
# Out:
# (0.8133, 0.0)

# %%
criterion_21_afine_letter(texts_10000_1000, 10, 2)
# Out:
# (0.814, 0.0)

# %%
def criterion_21_uniform_letter(open_texts, A_frq_size, kf, L):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_uniform_letter(texts_10_10000, 7, 2, 10)
# Out:
# (0.2753, 0.1643)

# %%
criterion_21_uniform_letter(texts_100_10000, 10, 1, 100)
# Out:
# (1.0, 0.0)

# %%
criterion_21_uniform_letter(texts_1000_10000, 7, 2, 1000)
# Out:
# (1.0, 0.0)

# %%
criterion_21_uniform_letter(texts_10000_1000, 10, 5, 10000)
# Out:
# (1.0, 0.0)

# %%
def criterion_21_s_letter(open_texts, A_frq_size, kf, L):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_s_letter(texts_10_10000, 7, 2, 10)
# Out:
# (0.261, 0.1643)

# %%
criterion_21_s_letter(texts_100_10000, 7, 2, 100)
# Out:
# (0.8433, 0.0)

# %%
criterion_21_s_letter(texts_1000_10000, 7, 2, 1000)
# Out:
# (0.8451, 0.0)

# %%
criterion_21_s_letter(texts_10000_1000, 10, 2, 10000)
# Out:
# (0.853, 0.0)

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# criterion_22(1)

# %%
def criterion_22_vigenere_r1_letter(open_texts, A_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r1_letter(texts_10_10000, 10, 0.03)
# Out:
# (0.7364, 0.0)

# %%
criterion_22_vigenere_r1_letter(texts_100_10000, 10, 0.037)
# Out:
# (0.6487, 0.0)

# %%
criterion_22_vigenere_r1_letter(texts_1000_10000, 10, 0.04)
# Out:
# (0.6221, 0.0)

# %%
criterion_22_vigenere_r1_letter(texts_10000_1000, 10, 0.04)
# Out:
# (0.667, 0.0)

# %% [markdown]
# criterion_22(2)

# %%
def criterion_22_vigenere_r5_letter(open_texts, A_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r5_letter(texts_10_10000, 10, 0.03)
# Out:
# (0.7597, 0.0)

# %%
criterion_22_vigenere_r5_letter(texts_100_10000, 10, 0.03)
# Out:
# (0.666, 0.0)

# %%
criterion_22_vigenere_r5_letter(texts_1000_10000, 10, 0.03)
# Out:
# (0.6346, 0.0)

# %%
criterion_22_vigenere_r5_letter(texts_10000_1000, 10, 0.03)
# Out:
# (0.633, 0.0)

# %% [markdown]
# criterion_22(3)

# %%
def criterion_22_vigenere_r10_letter(open_texts, A_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r10_letter(texts_10_10000, 10, 0.03)
# Out:
# (0.7578, 0.0)

# %%
criterion_22_vigenere_r10_letter(texts_100_10000, 10, 0.03)
# Out:
# (0.673, 0.0)

# %%
criterion_22_vigenere_r10_letter(texts_1000_10000, 10, 0.03)
# Out:
# (0.6438, 0.0)

# %%
criterion_22_vigenere_r10_letter(texts_1000_10000, 10, 0.03)
# Out:
# (0.6403, 0.0)

# %% [markdown]
# criterion_22(4)

# %%
def criterion_22_afine_letter(open_texts, A_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_afine_letter(texts_10_10000, 9, 0.03)
# Out:
# (0.6809, 0.0)

# %%
criterion_22_afine_letter(texts_100_10000, 9, 0.03)
# Out:
# (0.6056, 0.0)

# %%
criterion_22_afine_letter(texts_1000_10000, 9, 0.03)
# Out:
# (0.5842, 0.0)

# %%
criterion_22_afine_letter(texts_10000_1000, 9, 0.03)
# Out:
# (0.595, 0.0)

# %% [markdown]
# criteriin_22(5)

# %%
def criterion_22_uniform_letter(open_texts, A_frq_size, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_uniform_letter(texts_10_10000, 9, 0.03, 10)
# Out:
# (0.7299, 0.0)

# %%
criterion_22_uniform_letter(texts_100_10000, 9, 0.03, 100)
# Out:
# (0.6368, 0.0)

# %%
criterion_22_uniform_letter(texts_1000_10000, 9, 0.03, 1000)
# Out:
# (0.5827, 0.0)

# %%
criterion_22_uniform_letter(texts_10000_1000, 9, 0.03, 10000)
# Out:
# (0.596, 0.0)

# %%
def criterion_22_s_letter(open_texts, A_frq_size, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_s_letter(texts_10_10000, 9, 0.03, 10)
# Out:
# (0.6015, 0.0)

# %%
criterion_22_s_letter(texts_100_10000, 9, 0.03, 100)
# Out:
# (0.4781, 0.0)

# %%
criterion_22_s_letter(texts_1000_10000, 9, 0.03, 1000)
# Out:
# (0.4167, 0.0)

# %%
criterion_22_s_letter(texts_10000_1000, 9, 0.03, 10000)
# Out:
# (0.485, 0.0)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# criterion_23(1)

# %%
def criterion_23_vigenere_r1_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r1_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r1_letter(texts_100_10000, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r1_letter(texts_1000_10000, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r1_letter(texts_10000_1000, 10)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(2)

# %%
def criterion_23_vigenere_r5_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r5_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r5_letter(texts_100_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r5_letter(texts_1000_10000, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r5_letter(texts_10000_1000, 10)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(3)

# %%
def criterion_23_vigenere_r10_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r10_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r10_letter(texts_100_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r10_letter(texts_1000_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r10_letter(texts_10000_1000, 7)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(4)

# %%
def criterion_23_afine_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_afine_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_afine_letter(texts_100_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_afine_letter(texts_1000_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_afine_letter(texts_10000_1000, 7)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(5)

# %%
def criterion_23_uniform_letter(open_texts, A_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_uniform_letter(texts_10_10000, 10, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_uniform_letter(texts_100_10000, 10, 100)
# Out:
# (1.0, 0.0)

# %%
criterion_23_uniform_letter(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 0.0)

# %%
criterion_23_uniform_letter(texts_10000_1000, 10, 10000)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(6)

# %%
def criterion_23_s_letter(open_texts, A_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_s_letter(texts_10_10000, 10, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_s_letter(texts_100_10000, 10, 100)
# Out:
# (1.0, 0.0)

# %%
criterion_23_s_letter(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 0.0)

# %%
criterion_23_s_letter(texts_10000_1000, 10, 10000)
# Out:
# (1.0, 0.0)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# criterion_conformity(1)

# %%
def criterion_conformity_vigenere_r1_letter(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r1_letter(texts_10_10000, 0.02)
# Out:
# (0.5682, 0.4318)

# %%
criterion_conformity_vigenere_r1_letter(texts_100_10000, 0.02)
# Out:
# (0.0015, 0.9985)

# %%
criterion_conformity_vigenere_r1_letter(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r1_letter(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_conformity(2)

# %%
def criterion_conformity_vigenere_r5_letter(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r5_letter(texts_10_10000, 0.02)
# Out:
# (0.6487, 0.4318)

# %%
criterion_conformity_vigenere_r5_letter(texts_100_10000, 0.02)
# Out:
# (0.0271, 0.9985)

# %%
criterion_conformity_vigenere_r5_letter(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r5_letter(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_conformity(3)

# %%
def criterion_conformity_vigenere_r10_letter(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r10_letter(texts_10_10000, 0.02)
# Out:
# (0.6628, 0.4318)

# %%
criterion_conformity_vigenere_r10_letter(texts_100_10000, 0.02)
# Out:
# (0.0868, 0.9985)

# %%
criterion_conformity_vigenere_r10_letter(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r10_letter(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_conformity(4)

# %%
def criterion_conformity_afine_letter(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_afine_letter(texts_10_10000, 0.02)
# Out:
# (0.659, 0.4318)

# %%
criterion_conformity_afine_letter(texts_100_10000, 0.02)
# Out:
# (0.4991, 0.9985)

# %%
criterion_conformity_afine_letter(texts_1000_10000, 0.02)
# Out:
# (0.5017, 1.0)

# %% [markdown]
# conformity_index(5)

# %%
def criterion_conformity_uniform_letter(open_texts, k_H, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_uniform_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.6707, 0.4318)

# %%
criterion_conformity_uniform_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.2097, 0.9985)

# %%
criterion_conformity_uniform_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_uniform_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_conformity(6)

# %%
def criterion_conformity_s_letter(open_texts, k_H, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_s_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.699, 0.4318)

# %%
criterion_conformity_s_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.2511, 0.9985)

# %%
criterion_conformity_s_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.2483, 1.0)

# %%
criterion_conformity_s_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.596, 1.0)

# %% [markdown]
# criterion_50(1)

# %%
def criterion_50_vigenere_r1_letter(open_texts, k_empt):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r1_letter(texts_10_10000, 1)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r1_letter(texts_100_10000, 1)
# Out:
# (0.0004, 1.0)

# %%
criterion_50_vigenere_r1_letter(texts_1000_10000, 1)
# Out:
# (0.6834, 0.3493)

# %%
criterion_50_vigenere_r1_letter(texts_10000_1000, 1)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_50(2)

# %%
def criterion_50_vigenere_r5_letter(open_texts, k_empt):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r5_letter(texts_10_10000, 2)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r5_letter(texts_100_10000, 2)
# Out:
# (0.371, 0.9979)

# %%
criterion_50_vigenere_r5_letter(texts_1000_10000, 2)
# Out:
# (1.0, 0.0194)

# %%
criterion_50_vigenere_r5_letter(texts_10000_1000, 2)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_50(3)

# %%
def criterion_50_vigenere_r10_letter(open_texts, k_empt):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r10_letter(texts_10_10000, 2)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r10_letter(texts_100_10000, 2)
# Out:
# (0.5122, 0.9979)

# %%
criterion_50_vigenere_r10_letter(texts_1000_10000, 2)
# Out:
# (1.0, 0.0194)

# %%
criterion_50_vigenere_r10_letter(texts_10000_1000, 2)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_50(4)

# %%
def criterion_50_afine_letter(open_texts, k_empt):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_afine_letter(texts_10_10000, 2)
# Out:
# (0.0, 1.0)

# %%
criterion_50_afine_letter(texts_100_10000, 2)
# Out:
# (0.0026, 0.9979)

# %%
criterion_50_afine_letter(texts_1000_10000, 2)
# Out:
# (0.4902, 0.0194)

# %%
criterion_50_afine_letter(texts_10000_1000, 2)
# Out:
# (0.522, 0.0)

# %% [markdown]
# criterion_50(5)

# %%
def criterion_50_uniform_letter(open_texts, k_empt, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_uniform_letter(texts_10_10000, 1, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_50_uniform_letter(texts_100_10000, 1, 100)
# Out:
# (0.2763, 1.0)

# %%
criterion_50_uniform_letter(texts_1000_10000, 1, 1000)
# Out:
# (1.0, 0.3493)

# %%
criterion_50_uniform_letter(texts_10000_1000, 1, 10000)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_50(s_letter)

# %%
def criterion_50_s_letter(open_texts, k_empt, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[2:] # j = 2
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_s_letter(texts_10_10000, 1, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_50_s_letter(texts_100_10000, 1, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_50_s_letter(texts_1000_10000, 1, 1000)
# Out:
# (0.0, 0.3493)

# %%
criterion_50_s_letter(texts_10000_1000, 1, 10000)
# Out:
# (0.0, 0.0)

# %% [markdown]
# criterion_structural(1)

# %%
def structural(text):
    n = sys.getsizeof(text)
    compressed_l_bytes = sys.getsizeof(b64encode(gzip.compress(text.encode('utf-8'))).decode('utf-8'))
    
    return abs(n - compressed_l_bytes) / n

# %%
def criterion_structural_vigenere_r1_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_vigenere_r1_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0001, 0.9999)

# %%
criterion_structural_vigenere_r1_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r1_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r1_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(2)

# %%
def criterion_structural_vigenere_r5_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_vigenere_r5_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0001, 1.0)

# %%
criterion_structural_vigenere_r5_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r5_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r5_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(3)

# %%
def criterion_structural_vigenere_r10_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_vigenere_r10_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r10_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r10_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r10_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(4)

# %%
def criterion_structural_afine_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_afine_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.028, 0.9999)

# %%
criterion_structural_afine_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_afine_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_afine_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(5)

# %%
def criterion_structural_uniform_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_uniform_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0001, 1.0)

# %%
criterion_structural_uniform_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_uniform_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_uniform_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(6)

# %%
def criterion_structural_s_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_s_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0012, 1.0)

# %%
criterion_structural_s_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_s_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_s_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# 2) l = 2

# %% [markdown]
# - criterion_20:
# > 1. criterion_20_vigenere_r1_bigram +
# > 2. criterion_20_vigenere_r5_bigram +
# > 3. criterion_20_vigenere_r10_bigram +
# > 4. criterion_20_afine_bigram +
# > 5. criterion_20_uniform_bigram +
# > 6. criterion_20_s_bigram +
#
# - criterion_21:
# > 1. criterion_21_vigenere_r1_bigram +
# > 2. criterion_21_vigenere_r5_bigram +
# > 3. criterion_21_vigenere_r10_bigram +
# > 4. criterion_21_afine_bigram +
# > 5. criterion_21_uniform_bigram +
# > 6. criterion_21_s_bigram +
#
# - criterion_22:
# > 1. criterion_22_vigenere_r1_bigram
# > 2. criterion_22_vigenere_r5_bigram
# > 3. criterion_22_vigenere_r10_bigram
# > 4. criterion_22_afine_bigram
# > 5. criterion_22_uniform_bigram
# > 6. criterion_22_s_bigram
#
# - criterion_23:
# > 1. criterion_23_vigenere_r1_bigram
# > 2. criterion_23_vigenere_r5_bigram
# > 3. criterion_23_vigenere_r10_bigram
# > 4. criterion_23_afine_bigram
# > 5. criterion_23_uniform_bigram
# > 6. criterion_23_s_bigram
#
# - criterion_conformity
# > 1. criterion_conformity_vigenere_r1_bigram
# > 2. criterion_conformity_vigenere_r5_bigram
# > 3. criterion_conformity_vigenere_r10_bigram
# > 4. criterion_conformity_afine_bigram
# > 5. criterion_conformity_uniform_bigram
# > 6. criterion_conformity_s_bigram
#
# - criterion_50
# > 1. criterion_50_vigenere_r1_bigram
# > 2. criterion_50_vigenere_r5_bigram
# > 3. criterion_50_vigenere_r10_bigram
# > 4. criterion_50_afine_bigram
# > 5. criterion_50_uniform_bigram
# > 6. criterion_50_s_bigram
#
#
# - criterion_structural
# > 1. criterion_structural_vigenere_r1_bigram
# > 2. criterion_structural_vigenere_r5_bigram
# > 3. criterion_structural_vigenere_r10_bigram
# > 4. criterion_structural_afine_bigram
# > 5. criterion_structural_uniform_bigram
# > 6. criterion_structural_s_bigram

# %%
B = ['на', 'ов', 'ві', 'не', 'ти', 'по', 'ро', 'ав', 'го', 'ер', 'ст', 'ог', 'ла', 'ли', 'та', 'ін', 'ви', 'он', 'во', 'ом']

# %% [markdown]
# criterion_20(1)

# %%
def criterion_20_vigenere_r1_bigram(open_texts, B_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r1_bigram(texts_10_10000, 9)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r1_bigram(texts_100_10000, 9)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_vigenere_r1_bigram(texts_1000_10000, 9)
# Out:
# (0.922, 0.9721)

# %%
criterion_20_vigenere_r1_bigram(texts_10000_1000, 9)
# Out:
# (1.0, 0.959)

# %% [markdown]
# criterion_20(2)

# %%
def criterion_20_vigenere_r5_bigram(open_texts, B_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r5_bigram(texts_10_10000, 9)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r5_bigram(texts_100_10000, 9)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_vigenere_r5_bigram(texts_1000_10000, 9)
# Out:
# (0.922, 0.9992)

# %%
criterion_20_vigenere_r5_bigram(texts_10000_1000, 9)
# Out:
# (1.0, 0.707)

# %% [markdown]
# criterion_20(3)

# %%
def criterion_20_vigenere_r10_bigram(open_texts, B_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r10_bigram(texts_10_10000, 9)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r10_bigram(texts_100_10000, 9)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_vigenere_r10_bigram(texts_1000_10000, 9)
# Out:
# (0.922, 0.9996)

# %%
criterion_20_vigenere_r10_bigram(texts_10000_1000, 9)
# Out:
# (1.0, 0.731)

# %% [markdown]
# criterion_20(4)

# %%
def criterion_20_afine_bigram(open_texts, B_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_afine_bigram(texts_10_10000, 9)
# Out:
# (0.0, 1.0)

# %%
criterion_20_afine_bigram(texts_100_10000, 9)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_afine_bigram(texts_1000_10000, 9)
# Out:
# (0.922, 1.0)

# %%
criterion_20_afine_bigram(texts_10000_1000, 9)
# Out:
# (1.0, 0.999)

# %% [markdown]
# criterion_20(5)

# %%
def criterion_20_uniform_bigram(open_texts, B_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_uniform_bigram(texts_10_10000, 9, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_20_uniform_bigram(texts_100_10000, 9, 100)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_uniform_bigram(texts_1000_10000, 9, 1000)
# Out:
# (0.922, 0.9998)

# %%
criterion_20_uniform_bigram(texts_10000_1000, 9, 10000)
# Out:
# (1.0, 0.073)

# %%
def criterion_20_s_bigram(open_texts, B_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_s_bigram(texts_10_10000, 9, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_20_s_bigram(texts_100_10000, 9, 100)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_s_bigram(texts_1000_10000, 9, 1000)
# Out:
# (0.922, 1.0)

# %%
criterion_20_s_bigram(texts_10000_1000, 15, 10000)
# Out:
# (1.0, 1.0)

# %% [markdown]
# criterion_21(1)

# %%
def criterion_21_vigenere_r1_bigram(open_texts, B_frq_size, kf):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r1_bigram(texts_10_10000, 9, 2)
# Out:
# (0.9941, 0.0005)

# %%
criterion_21_vigenere_r1_bigram(texts_100_10000, 9, 2)
# Out:
# (0.2015, 0.0311)

# %%
criterion_21_vigenere_r1_bigram(texts_1000_10000, 9, 2)
# Out:
# (0.0, 0.3463)

# %%
criterion_21_vigenere_r1_bigram(texts_10000_1000, 9, 2)
# Out:
# (0.0, 0.925)

# %% [markdown]
# criterion_21(2)

# %%
def criterion_21_vigenere_r5_bigram(open_texts, B_frq_size, kf):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r5_bigram(texts_10_10000, 9, 2)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_vigenere_r5_bigram(texts_100_10000, 9, 2)
# Out:
# (0.2015, 0.0072)

# %%
criterion_21_vigenere_r5_bigram(texts_1000_10000, 9, 2)
# Out:
# (0.0, 0.6326)

# %%
criterion_21_vigenere_r5_bigram(texts_10000_1000, 9, 2)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_21(3)

# %%
def criterion_21_vigenere_r10_bigram(open_texts, B_frq_size, kf):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r10_bigram(texts_10_10000, 9, 2)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_vigenere_r10_bigram(texts_100_10000, 9, 2)
# Out:
# (0.2015, 0.008)

# %%
criterion_21_vigenere_r10_bigram(texts_1000_10000, 9, 2)
# Out:
# (0.0, 0.6294)

# %%
criterion_21_vigenere_r10_bigram(texts_10000_1000, 9, 2)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_21(4)

# %%
def criterion_21_afine_bigram(open_texts, B_frq_size, kf):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_afine_bigram(texts_10_10000, 9, 2)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_afine_bigram(texts_100_10000, 9, 2)
# Out:
# (0.2015, 0.0066)

# %%
criterion_21_afine_bigram(texts_1000_10000, 9, 2)
# Out:
# (0.0, 0.2948)

# %%
criterion_21_afine_bigram(texts_10000_1000, 9, 2)
# Out:
# (0.0, 0.768)

# %% [markdown]
# criterion_21(5)

# %%
def criterion_21_uniform_bigram(open_texts, B_frq_size, kf, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_uniform_bigram(texts_10_10000, 9, 2, 10)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_uniform_bigram(texts_100_10000, 9, 2, 100)
# Out:
# (0.2015, 0.0072)

# %%
criterion_21_uniform_bigram(texts_1000_10000, 9, 2, 1000)
# Out:
# (0.0, 0.7486)

# %%
criterion_21_uniform_bigram(texts_10000_1000, 9, 2, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_21(6)

# %%
def criterion_21_s_bigram(open_texts, B_frq_size, kf, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_s_bigram(texts_10_10000, 9, 2, 10)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_s_bigram(texts_100_10000, 9, 2, 100)
# Out:
# (0.2015, 0.0093)

# %%
criterion_21_s_bigram(texts_1000_10000, 9, 2, 1000)
# Out:
# (0.0, 0.5876)

# %%
criterion_21_s_bigram(texts_10000_1000, 9, 2, 10000)
# Out:
# (0.0, 0.949)

# %%
tmp = bigrams_counter(TEXT)

# %%
B_new = []
for i in range(len(tmp)):
    B_new.append(tmp[i][0])

B_new[:10]
# Out:
# [('н', 'а'),
#  ('о', 'в'),
#  ('в', 'і'),
#  ('н', 'е'),
#  ('т', 'и'),
#  ('п', 'о'),
#  ('р', 'о'),
#  ('а', 'в'),
#  ('г', 'о'),
#  ('е', 'р')]

# %% [markdown]
# criterion_22(1) !!!!!!

# %%
def criterion_22_vigenere_r1_bigram(open_texts, B_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = disjoint_bigrams(text_corrupt[i][0])
        for t, v in tmp.items():
            if tmp[t] in B_frq and tmp[v] < disjoint_bigrams(TEXT)[0][tmp[t]][1]:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = disjoint_bigrams(open_texts[i])
        for t, v in tmp.items():
            if tmp[t] in B_frq and tmp[v] < disjoint_bigrams(TEXT)[0][tmp[t]][1]:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r1_bigram(texts_10_10000, 9)
# Out:
# (0.0, 0.0)

# %%
criterion_22_vigenere_r1_bigram(texts_100_10000, 9)
# Out:
# (0.0, 0.0)

# %%
criterion_22_vigenere_r1_bigram(texts_1000_10000, 9)
# Out:
# (0.0, 0.0)

# %% [markdown]
# criterion_23(1)

# %%
def criterion_23_vigenere_r1_bigram(open_texts, B_frq_size):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r1_bigram(texts_10_10000, 10)
# Out:
# (0.9062, 0.6339)

# %%
criterion_23_vigenere_r1_bigram(texts_100_10000, 10)
# Out:
# (0.9852, 0.4678)

# %%
criterion_23_vigenere_r1_bigram(texts_1000_10000, 10)
# Out:
# (0.9835, 0.4655)

# %%
criterion_23_vigenere_r1_bigram(texts_10000_1000, 10)
# Out:
# (0.978, 0.481)

# %% [markdown]
# criterion_23(2)

# %%
def criterion_23_vigenere_r5_bigram(open_texts, B_frq_size):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r5_bigram(texts_10_10000, 10)
# Out:
# (0.9131, 0.6339)

# %%
criterion_23_vigenere_r5_bigram(texts_100_10000, 10)
# Out:
# (0.9999, 0.4678)

# %%
criterion_23_vigenere_r5_bigram(texts_1000_10000, 10)
# Out:
# (1.0, 0.4655)

# %%
criterion_23_vigenere_r5_bigram(texts_10000_1000, 10)
# Out:
# (1.0, 0.481)

# %% [markdown]
# criterion_23(3)

# %%
def criterion_23_vigenere_r10_bigram(open_texts, B_frq_size):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r10_bigram(texts_10_10000, 10)
# Out:
# (0.9181, 0.6339)

# %%
criterion_23_vigenere_r10_bigram(texts_100_10000, 10)
# Out:
# (1.0, 0.4678)

# %%
criterion_23_vigenere_r10_bigram(texts_1000_10000, 10)
# Out:
# (1.0, 0.4655)

# %%
criterion_23_vigenere_r10_bigram(texts_10000_1000, 10)
# Out:
# (1.0, 0.481)

# %% [markdown]
# criterion_23(4)

# %%
def criterion_23_afine_bigram(open_texts, B_frq_size):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_afine_bigram(texts_10_10000, 10)
# Out:
# (0.9203, 0.6339)

# %%
criterion_23_afine_bigram(texts_100_10000, 10)
# Out:
# (0.9999, 0.4678)

# %%
criterion_23_afine_bigram(texts_1000_10000, 10)
# Out:
# (0.9997, 0.4655)

# %%
criterion_23_afine_bigram(texts_10000_1000, 10)
# Out:
# (0.999, 0.481)

# %% [markdown]
# criterion_23(5)

# %%
def criterion_23_uniform_bigram(open_texts, B_frq_size, L):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_uniform_bigram(texts_10_10000, 10, 10)
# Out:
# (0.9175, 0.6339)

# %%
criterion_23_uniform_bigram(texts_100_10000, 10, 100)
# Out:
# (1.0, 0.4678)

# %%
criterion_23_uniform_bigram(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 0.4655)

# %%
criterion_23_uniform_bigram(texts_10000_1000, 10, 10000)
# Out:
# (1.0, 0.481)

# %% [markdown]
# criterion_23(6)

# %%
def criterion_23_s_bigram(open_texts, B_frq_size, L):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_s_bigram(texts_10_10000, 10, 10)
# Out:
# (0.9127, 0.6339)

# %%
criterion_23_s_bigram(texts_100_10000, 10, 100)
# Out:
# (1.0, 0.4678)

# %%
criterion_23_s_bigram(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 0.4655)

# %%
criterion_23_s_bigram(texts_10000_1000, 10, 10000)
# Out:
# (1.0, 0.481)

# %% [markdown]
# criterion_conformity(1)

# %%
def criterion_conformity_vigenere_r1_bigram(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I2 = 0.004381493632890787
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
        
    for i in text_corrupt:
        if abs(conformity_index_bigrams(i[0]) - I2) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_bigrams(i) - I2) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r1_bigram(texts_10_10000, 0.02)
# Out:
# (0.0106, 0.9894)

# %%
criterion_conformity_vigenere_r1_bigram(texts_100_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r1_bigram(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r1_bigram(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %% [markdown]
# conformity_criterion(2)

# %%
def criterion_conformity_vigenere_r5_bigram(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I2 = 0.004381493632890787
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
        
    for i in text_corrupt:
        if abs(conformity_index_bigrams(i[0]) - I2) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_bigrams(i) - I2) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r5_bigram(texts_10_10000, 0.02)
# Out:
# (0.0027, 0.9894)

# %%
criterion_conformity_vigenere_r5_bigram(texts_100_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r5_bigram(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r5_bigram(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %%
def criterion_conformity_vigenere_r10_bigram(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I2 = 0.004381493632890787
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
        
    for i in text_corrupt:
        if abs(conformity_index_bigrams(i[0]) - I2) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_bigrams(i) - I2) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r10_bigram(texts_10_10000, 0.02)
# Out:
# (0.0012, 0.9894)

# %%
criterion_conformity_vigenere_r10_bigram(texts_100_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r10_bigram(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r10_bigram(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(1)

# %%
def criterion_50_vigenere_r1_bigram(open_texts, k_empt, B_prh_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r1_bigram(texts_10_10000, 1, 50)
# Out:
# (0.28, 0.9782)

# %%
criterion_50_vigenere_r1_bigram(texts_100_10000, 1, 50)
# Out:
# (0.0001, 1.0)

# %%
criterion_50_vigenere_r1_bigram(texts_1000_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r1_bigram(texts_10000_1000, 1, 50)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(2)

# %%
def criterion_50_vigenere_r5_bigram(open_texts, k_empt, B_prh_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r5_bigram(texts_10_10000, 1, 50)
# Out:
# (0.2847, 0.9782)

# %%
criterion_50_vigenere_r5_bigram(texts_100_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r5_bigram(texts_1000_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r5_bigram(texts_10000_1000, 1, 50)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(3)

# %%
def criterion_50_vigenere_r10_bigram(open_texts, k_empt, B_prh_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r10_bigram(texts_10_10000, 1, 50)
# Out:
# (0.2839, 0.9782)

# %%
criterion_50_vigenere_r10_bigram(texts_100_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r10_bigram(texts_1000_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r10_bigram(texts_10000_1000, 1, 50)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(4)

# %%
def criterion_50_afine_bigram(open_texts, k_empt, B_prh_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_afine_bigram(texts_10_10000, 1, 50)
# Out:
# (0.3101, 0.9782)

# %%
criterion_50_afine_bigram(texts_100_10000, 1, 50)
# Out:
# (0.0033, 1.0)

# %%
criterion_50_afine_bigram(texts_1000_10000, 1, 50)
# Out:
# (0.0029, 1.0)

# %%
criterion_50_afine_bigram(texts_10000_1000, 1, 50)
# Out:
# (0.004, 1.0)

# %% [markdown]
# criterion_50(5)

# %%
def criterion_50_uniform_bigram(open_texts, k_empt, B_prh_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_uniform_bigram(texts_10_10000, 1, 50, 10)
# Out:
# (0.2803, 0.9782)

# %%
criterion_50_uniform_bigram(texts_100_10000, 1, 50, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_50_uniform_bigram(texts_1000_10000, 1, 50, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_50_uniform_bigram(texts_10000_1000, 1, 50, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(6)

# %%
def criterion_50_s_bigram(open_texts, k_empt, B_prh_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_s_bigram(texts_10_10000, 1, 50, 10)
# Out:
# (0.2885, 0.9782)

# %%
criterion_50_s_bigram(texts_100_10000, 1, 50, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_50_s_bigram(texts_1000_10000, 1, 50, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_50_s_bigram(texts_10000_1000, 1, 50, 10000)
# Out:
# (0.0, 1.0)

# %%
ttt = 'апроглсд'
s = bigrams_counter(ttt)
s
# Out:
# [(('а', 'п'), 1),
#  (('п', 'р'), 1),
#  (('р', 'о'), 1),
#  (('о', 'г'), 1),
#  (('г', 'л'), 1),
#  (('л', 'с'), 1),
#  (('с', 'д'), 1)]

# %%
ll = []
for i in range(len(s)):
    ll.append(s[i][0])
ll
# Out:
# [('а', 'п'),
#  ('п', 'р'),
#  ('р', 'о'),
#  ('о', 'г'),
#  ('г', 'л'),
#  ('л', 'с'),
#  ('с', 'д')]

# %%
t = 'авблагоу'

# %%
print(list(t))
# Out:
# ['а', 'в', 'б', 'л', 'а', 'г', 'о', 'у']

# %%
l = []
for i in range(len(t) // 2):
    l.append(t[2*i:2*i + 2])

print(l)
# Out:
# ['ав', 'бл', 'аг', 'оу']
