# %%
import numpy as np
import re, textwrap
import math as m
import random

from collections import Counter
import nltk

import sys
import gzip
from base64 import b64encode, b64decode

# %% [markdown]
# **1. Предварительная обработка текста**

# %%
with open("Dreiser.txt", 'rb') as file: 
    TEXT = file.read().decode('utf-8')
    
pattern_1 = r'ґ'
pattern_2 = r'[^абвгдеєжзиіїйклмнопрстуфхцчшщьюя]'

TEXT = re.sub(pattern_1, 'г', TEXT.lower())
TEXT = re.sub(pattern_2, '', TEXT)

# %% [markdown]
# **2. Расчёт статистических данных текста**

# %%
ukr_clean_alphabet = 'абвгдеєжзиіїйклмнопрстуфхцчшщьюя'

# %%
def letter_counter(text):
    alphabet = dict.fromkeys(list(ukr_clean_alphabet), 0)
    
    for letter in text:
        alphabet[letter] += 1
    
    return alphabet

# %%
letter_counter(TEXT)
# Out:
# {'а': 115516,
#  'б': 28941,
#  'в': 84841,
#  'г': 24462,
#  'д': 52838,
#  'е': 74034,
#  'є': 5133,
#  'ж': 15228,
#  'з': 33899,
#  'и': 87619,
#  'і': 84161,
#  'ї': 10210,
#  'й': 23372,
#  'к': 45594,
#  'л': 52192,
#  'м': 43822,
#  'н': 90412,
#  'о': 137885,
#  'п': 39320,
#  'р': 57405,
#  'с': 56137,
#  'т': 70682,
#  'у': 48930,
#  'ф': 2513,
#  'х': 13910,
#  'ц': 10704,
#  'ч': 20649,
#  'ш': 11445,
#  'щ': 10298,
#  'ь': 21038,
#  'ю': 11669,
#  'я': 32091}

# %%
N = 1416950

# %% [markdown]
# 1) Частота букв в тексте

# %%
def dictionary_sorting(dictionary):
    return [(i, round(dictionary[i]/N, 5)) for i in sorted(dictionary.keys(), key=dictionary.get, reverse=True)]

dictionary_sorting(letter_counter(TEXT))
# Out:
# [('о', 0.09731),
#  ('а', 0.08152),
#  ('н', 0.06381),
#  ('и', 0.06184),
#  ('в', 0.05988),
#  ('і', 0.0594),
#  ('е', 0.05225),
#  ('т', 0.04988),
#  ('р', 0.04051),
#  ('с', 0.03962),
#  ('д', 0.03729),
#  ('л', 0.03683),
#  ('у', 0.03453),
#  ('к', 0.03218),
#  ('м', 0.03093),
#  ('п', 0.02775),
#  ('з', 0.02392),
#  ('я', 0.02265),
#  ('б', 0.02042),
#  ('г', 0.01726),
#  ('й', 0.01649),
#  ('ь', 0.01485),
#  ('ч', 0.01457),
#  ('ж', 0.01075),
#  ('х', 0.00982),
#  ('ю', 0.00824),
#  ('ш', 0.00808),
#  ('ц', 0.00755),
#  ('щ', 0.00727),
#  ('ї', 0.00721),
#  ('є', 0.00362),
#  ('ф', 0.00177)]

# %%
def letter_frequency(dictionary):
    return [(i, round(dictionary[i]/N, 5)) for i in dictionary.keys()]

letter_frequency(letter_counter(TEXT))
# Out:
# [('а', 0.08152),
#  ('б', 0.02042),
#  ('в', 0.05988),
#  ('г', 0.01726),
#  ('д', 0.03729),
#  ('е', 0.05225),
#  ('є', 0.00362),
#  ('ж', 0.01075),
#  ('з', 0.02392),
#  ('и', 0.06184),
#  ('і', 0.0594),
#  ('ї', 0.00721),
#  ('й', 0.01649),
#  ('к', 0.03218),
#  ('л', 0.03683),
#  ('м', 0.03093),
#  ('н', 0.06381),
#  ('о', 0.09731),
#  ('п', 0.02775),
#  ('р', 0.04051),
#  ('с', 0.03962),
#  ('т', 0.04988),
#  ('у', 0.03453),
#  ('ф', 0.00177),
#  ('х', 0.00982),
#  ('ц', 0.00755),
#  ('ч', 0.01457),
#  ('ш', 0.00808),
#  ('щ', 0.00727),
#  ('ь', 0.01485),
#  ('ю', 0.00824),
#  ('я', 0.02265)]

# %% [markdown]
# 2) Частоты биграмм в тексте

# %%
def bigrams_counter(text):
    cnt = Counter(list(nltk.ngrams(text, n=2)))
    sort_dict = sorted(dict(cnt).items(), key = lambda x: x[1], reverse = True)
    
    return sort_dict

bigrams_counter(TEXT)
# Out:
# [(('н', 'а'), 19855),
#  (('о', 'в'), 16670),
#  (('в', 'і'), 15719),
#  (('н', 'е'), 15150),
#  (('т', 'и'), 15028),
#  (('п', 'о'), 14106),
#  (('р', 'о'), 13916),
#  (('а', 'в'), 13369),
#  (('г', 'о'), 12906),
#  (('е', 'р'), 12255),
#  (('с', 'т'), 12069),
#  (('о', 'г'), 12050),
#  (('л', 'а'), 11945),
#  (('л', 'и'), 11648),
#  (('т', 'а'), 11432),
#  (('і', 'н'), 11229),
#  (('в', 'и'), 10998),
#  (('о', 'н'), 10875),
#  (('в', 'о'), 10742),
#  (('о', 'м'), 10737),
#  (('и', 'в'), 10702),
#  (('в', 'а'), 10571),
#  (('п', 'р'), 10526),
#  (('а', 'т'), 10353),
#  (('а', 'л'), 10295),
#  (('н', 'о'), 10004),
#  (('н', 'і'), 9966),
#  (('р', 'а'), 9660),
#  (('е', 'н'), 9624),
#  (('о', 'д'), 9594),
#  (('о', 'б'), 9551),
#  (('і', 'д'), 9465),
#  (('д', 'о'), 9339),
#  (('і', 'в'), 8883),
#  (('к', 'о'), 8864),
#  (('о', 'с'), 8803),
#  (('и', 'н'), 8754),
#  (('н', 'и'), 8679),
#  (('з', 'а'), 8646),
#  (('а', 'н'), 8513),
#  (('и', 'т'), 8497),
#  (('т', 'о'), 8434),
#  (('с', 'я'), 8251),
#  (('щ', 'о'), 7913),
#  (('у', 'в'), 7758),
#  (('и', 'с'), 7744),
#  (('я', 'к'), 7687),
#  (('к', 'а'), 7409),
#  (('а', 'й'), 7354),
#  (('р', 'и'), 7145),
#  (('т', 'ь'), 7074),
#  (('а', 'с'), 7063),
#  (('м', 'о'), 6777),
#  (('л', 'о'), 6776),
#  (('и', 'й'), 6737),
#  (('а', 'к'), 6562),
#  (('б', 'у'), 6490),
#  (('к', 'и'), 6488),
#  (('и', 'м'), 6347),
#  (('р', 'е'), 6275),
#  (('о', 'т'), 6269),
#  (('о', 'з'), 6258),
#  (('і', 'л'), 6130),
#  (('о', 'р'), 6088),
#  (('т', 'е'), 6060),
#  (('в', 'с'), 6053),
#  (('м', 'і'), 6033),
#  (('о', 'л'), 5959),
#  (('т', 'і'), 5932),
#  (('м', 'у'), 5915),
#  (('м', 'а'), 5869),
#  (('ч', 'и'), 5850),
#  (('а', 'м'), 5811),
#  (('і', 'с'), 5763),
#  (('д', 'а'), 5708),
#  (('а', 'д'), 5512),
#  (('а', 'з'), 5439),
#  (('е', 'в'), 5307),
#  (('і', 'т'), 5226),
#  (('р', 'і'), 5216),
#  (('ж', 'е'), 5160),
#  (('а', 'п'), 4996),
#  (('д', 'и'), 4941),
#  (('з', 'н'), 4904),
#  (('н', 'у'), 4898),
#  (('о', 'п'), 4889),
#  (('а', 'р'), 4750),
#  (('у', 'т'), 4720),
#  (('о', 'к'), 4652),
#  (('л', 'е'), 4638),
#  (('й', 'о'), 4621),
#  (('д', 'у'), 4617),
#  (('е', 'з'), 4457),
#  (('к', 'л'), 4455),
#  (('и', 'л'), 4454),
#  (('п', 'е'), 4451),
#  (('й', 'д'), 4447),
#  (('е', 'п'), 4382),
#  (('л', 'ь'), 4360),
#  (('д', 'і'), 4337),
#  (('н', 'н'), 4298),
#  (('т', 'р'), 4291),
#  (('о', 'ч'), 4239),
#  (('б', 'е'), 4227),
#  (('у', 'д'), 4076),
#  (('с', 'ь'), 4067),
#  (('в', 'е'), 3992),
#  (('м', 'и'), 3992),
#  (('д', 'н'), 3972),
#  (('е', 'с'), 3855),
#  (('у', 'м'), 3801),
#  (('ц', 'е'), 3763),
#  (('ч', 'а'), 3759),
#  (('к', 'у'), 3743),
#  (('е', 'м'), 3736),
#  (('к', 'і'), 3731),
#  (('і', 'м'), 3705),
#  (('е', 'т'), 3678),
#  (('л', 'і'), 3652),
#  (('с', 'е'), 3650),
#  (('о', 'ж'), 3607),
#  (('д', 'е'), 3602),
#  (('е', 'б'), 3583),
#  (('в', 'н'), 3569),
#  (('ь', 'к'), 3554),
#  (('л', 'я'), 3551),
#  (('у', 'л'), 3534),
#  (('у', 'с'), 3514),
#  (('с', 'п'), 3505),
#  (('б', 'а'), 3482),
#  (('х', 'о'), 3470),
#  (('и', 'п'), 3461),
#  (('и', 'к'), 3409),
#  (('п', 'і'), 3408),
#  (('и', 'х'), 3404),
#  (('е', 'д'), 3402),
#  (('ь', 'о'), 3399),
#  (('т', 'у'), 3386),
#  (('і', 'к'), 3376),
#  (('с', 'і'), 3331),
#  (('н', 'я'), 3330),
#  (('а', 'б'), 3312),
#  (('г', 'а'), 3293),
#  (('м', 'е'), 3283),
#  (('і', 'п'), 3190),
#  (('я', 'т'), 3168),
#  (('р', 'у'), 3147),
#  (('я', 'в'), 3105),
#  (('с', 'о'), 3079),
#  (('і', 'з'), 3076),
#  (('и', 'з'), 3071),
#  (('ч', 'е'), 3068),
#  (('б', 'о'), 2996),
#  (('б', 'і'), 2961),
#  (('р', 'т'), 2959),
#  (('о', 'ю'), 2951),
#  (('ц', 'і'), 2943),
#  (('о', 'ї'), 2889),
#  (('е', 'л'), 2825),
#  (('а', 'г'), 2813),
#  (('і', 'й'), 2798),
#  (('и', 'д'), 2792),
#  (('а', 'ч'), 2631),
#  (('ш', 'и'), 2611),
#  (('с', 'к'), 2562),
#  (('н', 'ь'), 2492),
#  (('з', 'в'), 2491),
#  (('б', 'и'), 2483),
#  (('з', 'у'), 2414),
#  (('с', 'в'), 2385),
#  (('я', 'н'), 2383),
#  (('і', 'р'), 2353),
#  (('е', 'й'), 2351),
#  (('к', 'р'), 2326),
#  (('у', 'ж'), 2308),
#  (('в', 'у'), 2298),
#  (('ш', 'е'), 2295),
#  (('м', 'н'), 2295),
#  (('и', 'ч'), 2294),
#  (('й', 'н'), 2280),
#  (('у', 'п'), 2262),
#  (('і', 'ш'), 2257),
#  (('а', 'є'), 2185),
#  (('с', 'а'), 2164),
#  (('а', 'ж'), 2143),
#  (('ь', 'н'), 2130),
#  (('ь', 'с'), 2085),
#  (('ч', 'о'), 2066),
#  (('и', 'р'), 2040),
#  (('в', 'д'), 2020),
#  (('с', 'и'), 2001),
#  (('с', 'у'), 2001),
#  (('д', 'р'), 1997),
#  (('с', 'л'), 1988),
#  (('л', 'ю'), 1974),
#  (('а', 'х'), 1972),
#  (('я', 'д'), 1967),
#  (('і', 'б'), 1964),
#  (('я', 'з'), 1962),
#  (('з', 'д'), 1956),
#  (('ї', 'ї'), 1913),
#  (('е', 'к'), 1866),
#  (('г', 'р'), 1849),
#  (('у', 'к'), 1846),
#  (('а', 'ю'), 1840),
#  (('і', 'я'), 1839),
#  (('п', 'а'), 1837),
#  (('у', 'н'), 1826),
#  (('п', 'и'), 1822),
#  (('д', 'в'), 1813),
#  (('в', 'т'), 1807),
#  (('і', 'г'), 1786),
#  (('ж', 'н'), 1780),
#  (('у', 'р'), 1758),
#  (('б', 'л'), 1750),
#  (('ч', 'у'), 1747),
#  (('о', 'я'), 1744),
#  (('р', 'н'), 1738),
#  (('и', 'щ'), 1697),
#  (('и', 'б'), 1691),
#  (('й', 'с'), 1687),
#  (('с', 'н'), 1669),
#  (('о', 'х'), 1661),
#  (('г', 'л'), 1629),
#  (('в', 'п'), 1624),
#  (('х', 'а'), 1624),
#  (('и', 'і'), 1608),
#  (('і', 'ч'), 1601),
#  (('ж', 'а'), 1560),
#  (('ю', 'ч'), 1550),
#  (('б', 'р'), 1531),
#  (('ж', 'и'), 1512),
#  (('з', 'р'), 1506),
#  (('е', 'ч'), 1467),
#  (('а', 'і'), 1459),
#  (('и', 'ц'), 1457),
#  (('щ', 'е'), 1455),
#  (('в', 'л'), 1411),
#  (('ю', 'в'), 1401),
#  (('у', 'з'), 1397),
#  (('т', 'н'), 1395),
#  (('ц', 'ь'), 1381),
#  (('ч', 'н'), 1372),
#  (('е', 'ж'), 1347),
#  (('я', 'м'), 1340),
#  (('д', 'ж'), 1335),
#  (('в', 'ч'), 1333),
#  (('о', 'і'), 1328),
#  (('н', 'д'), 1319),
#  (('ц', 'я'), 1314),
#  (('в', 'к'), 1307),
#  (('я', 'п'), 1297),
#  (('в', 'ж'), 1293),
#  (('л', 'у'), 1289),
#  (('и', 'г'), 1289),
#  (('т', 'я'), 1286),
#  (('и', 'ї'), 1282),
#  (('в', 'в'), 1277),
#  (('т', 'в'), 1276),
#  (('з', 'і'), 1263),
#  (('д', 'ь'), 1262),
#  (('ї', 'х'), 1261),
#  (('у', 'б'), 1257),
#  (('а', 'щ'), 1231),
#  (('о', 'й'), 1228),
#  (('о', 'ц'), 1221),
#  (('н', 'з'), 1218),
#  (('у', 'ч'), 1208),
#  (('з', 'о'), 1205),
#  (('я', 'с'), 1199),
#  (('є', 'т'), 1196),
#  (('п', 'л'), 1196),
#  (('н', 'т'), 1184),
#  (('е', 'г'), 1181),
#  (('і', 'і'), 1177),
#  (('х', 'в'), 1169),
#  (('и', 'я'), 1164),
#  (('ш', 'о'), 1159),
#  (('і', 'х'), 1157),
#  (('д', 'п'), 1148),
#  (('д', 'к'), 1140),
#  (('а', 'я'), 1136),
#  (('з', 'м'), 1122),
#  (('д', 'л'), 1120),
#  (('м', 'п'), 1114),
#  (('ю', 'т'), 1111),
#  (('й', 'т'), 1100),
#  (('у', 'і'), 1097),
#  (('ю', 'д'), 1096),
#  (('к', 'н'), 1095),
#  (('ж', 'у'), 1095),
#  (('н', 'п'), 1091),
#  (('в', 'з'), 1091),
#  (('н', 'к'), 1079),
#  (('е', 'щ'), 1067),
#  (('г', 'у'), 1037),
#  (('в', 'я'), 1026),
#  (('в', 'ш'), 1011),
#  (('а', 'ш'), 1010),
#  (('а', 'ц'), 1005),
#  (('ч', 'і'), 999),
#  (('е', 'ц'), 981),
#  (('г', 'і'), 979),
#  (('к', 'в'), 976),
#  (('е', 'я'), 967),
#  (('з', 'п'), 966),
#  (('ь', 'п'), 961),
#  (('в', 'р'), 954),
#  (('х', 'і'), 937),
#  (('ф', 'і'), 935),
#  (('м', 'с'), 932),
#  (('к', 'е'), 920),
#  (('о', 'щ'), 920),
#  (('р', 'я'), 919),
#  (('я', 'і'), 919),
#  (('и', 'ш'), 918),
#  (('й', 'п'), 917),
#  (('і', 'о'), 908),
#  (('с', 'м'), 907),
#  (('о', 'о'), 905),
#  (('х', 'т'), 904),
#  (('о', 'ш'), 900),
#  (('м', 'в'), 895),
#  (('т', 'с'), 892),
#  (('н', 'ш'), 890),
#  (('й', 'в'), 878),
#  (('і', 'є'), 878),
#  (('е', 'о'), 876),
#  (('ї', 'й'), 866),
#  (('м', 'к'), 864),
#  (('а', 'о'), 862),
#  (('ь', 'в'), 857),
#  (('к', 'щ'), 841),
#  (('д', 'я'), 840),
#  (('т', 'т'), 834),
#  (('е', 'ї'), 823),
#  (('е', 'х'), 822),
#  (('у', 'г'), 818),
#  (('і', 'ж'), 817),
#  (('і', 'ф'), 816),
#  (('з', 'е'), 813),
#  (('н', 'с'), 811),
#  (('і', 'щ'), 807),
#  (('ь', 'д'), 806),
#  (('в', 'щ'), 802),
#  (('й', 'ш'), 798),
#  (('ш', 'у'), 795),
#  (('н', 'ц'), 793),
#  (('к', 'т'), 791),
#  (('у', 'х'), 790),
#  (('ш', 'т'), 784),
#  (('и', 'а'), 781),
#  (('т', 'к'), 776),
#  (('в', 'б'), 771),
#  (('м', 'я'), 763),
#  (('х', 'и'), 755),
#  (('д', 'с'), 754),
#  (('б', 'н'), 750),
#  (('і', 'ц'), 743),
#  (('я', 'г'), 742),
#  (('д', 'т'), 737),
#  (('й', 'м'), 734),
#  (('і', 'а'), 733),
#  (('ь', 'т'), 730),
#  (('х', 'н'), 728),
#  (('м', 'з'), 726),
#  (('р', 'к'), 724),
#  (('з', 'г'), 722),
#  (('й', 'б'), 722),
#  (('е', 'ш'), 718),
#  (('д', 'ч'), 717),
#  (('з', 'б'), 711),
#  (('я', 'л'), 707),
#  (('н', 'в'), 702),
#  (('ь', 'з'), 701),
#  (('в', 'г'), 697),
#  (('е', 'і'), 696),
#  (('к', 'с'), 695),
#  (('з', 'с'), 691),
#  (('з', 'л'), 690),
#  (('в', 'м'), 688),
#  (('ь', 'і'), 687),
#  (('і', 'ї'), 683),
#  (('ь', 'ш'), 682),
#  (('и', 'о'), 676),
#  (('ц', 'ю'), 675),
#  (('з', 'к'), 675),
#  (('у', 'ш'), 672),
#  (('є', 'м'), 671),
#  (('й', 'з'), 664),
#  (('о', 'є'), 662),
#  (('м', 'т'), 658),
#  (('ш', 'н'), 657),
#  (('й', 'і'), 656),
#  (('в', 'ц'), 655),
#  (('ж', 'д'), 653),
#  (('ю', 'н'), 649),
#  (('а', 'а'), 637),
#  (('ї', 'з'), 636),
#  (('р', 'в'), 633),
#  (('у', 'я'), 629),
#  (('д', 'ц'), 623),
#  (('у', 'а'), 619),
#  (('т', 'ю'), 616),
#  (('ю', 'с'), 616),
#  (('е', 'ю'), 613),
#  (('д', 'з'), 612),
#  (('я', 'ч'), 608),
#  (('и', 'ж'), 608),
#  (('ш', 'і'), 606),
#  (('я', 'б'), 602),
#  (('ш', 'а'), 601),
#  (('з', 'я'), 601),
#  (('м', 'р'), 596),
#  (('ш', 'л'), 594),
#  (('п', 'у'), 593),
#  (('г', 'н'), 590),
#  (('о', 'а'), 586),
#  (('я', 'щ'), 581),
#  (('й', 'к'), 573),
#  (('ї', 'в'), 571),
#  (('ю', 'б'), 568),
#  (('р', 'ш'), 563),
#  (('ю', 'п'), 562),
#  (('у', 'щ'), 561),
#  (('ь', 'м'), 559),
#  (('л', 'л'), 557),
#  (('ї', 'м'), 555),
#  (('р', 'д'), 554),
#  (('х', 'л'), 550),
#  (('ь', 'у'), 546),
#  (('р', 'с'), 542),
#  (('ю', 'і'), 536),
#  (('з', 'и'), 535),
#  (('д', 'д'), 531),
#  (('ї', 'п'), 527),
#  (('з', 'т'), 518),
#  (('с', 'х'), 514),
#  (('ї', 'д'), 513),
#  (('щ', 'а'), 509),
#  (('р', 'г'), 497),
#  (('в', 'ї'), 497),
#  (('м', 'д'), 495),
#  (('у', 'ю'), 491),
#  (('б', 'в'), 491),
#  (('н', 'б'), 490),
#  (('ш', 'к'), 487),
#  (('і', 'ю'), 478),
#  (('д', 'б'), 475),
#  (('є', 'ї'), 474),
#  (('й', 'ч'), 473),
#  (('г', 'и'), 470),
#  (('у', 'о'), 461),
#  (('у', 'є'), 459),
#  (('к', 'б'), 455),
#  (('к', 'п'), 454),
#  (('ж', 'і'), 451),
#  (('ї', 'с'), 451),
#  (('с', 'с'), 449),
#  (('с', 'ц'), 449),
#  (('я', 'х'), 445),
#  (('я', 'я'), 444),
#  (('а', 'у'), 440),
#  (('я', 'ц'), 436),
#  (('й', 'ж'), 435),
#  (('м', 'б'), 432),
#  (('д', 'м'), 431),
#  (('н', 'ч'), 429),
#  (('ю', 'р'), 428),
#  (('х', 'у'), 428),
#  (('ж', 'л'), 419),
#  (('ч', 'к'), 418),
#  (('к', 'з'), 417),
#  (('х', 'п'), 415),
#  (('ц', 'и'), 407),
#  (('н', 'ю'), 404),
#  (('ї', 'н'), 404),
#  (('я', 'р'), 396),
#  (('е', 'а'), 395),
#  (('е', 'ф'), 395),
#  (('ф', 'а'), 391),
#  (('ж', 'к'), 391),
#  (('р', 'м'), 389),
#  (('ь', 'я'), 388),
#  (('а', 'ї'), 386),
#  (('у', 'ц'), 384),
#  (('р', 'з'), 382),
#  (('й', 'р'), 380),
#  (('о', 'у'), 378),
#  (('н', 'м'), 378),
#  (('ж', 'о'), 372),
#  (('х', 'м'), 362),
#  (('ф', 'о'), 358),
#  (('ь', 'щ'), 357),
#  (('т', 'л'), 356),
#  (('я', 'а'), 356),
#  (('ь', 'б'), 356),
#  (('в', 'й'), 356),
#  (('п', 'я'), 354),
#  (('к', 'м'), 353),
#  (('з', 'ь'), 351),
#  (('м', 'ч'), 350),
#  (('а', 'ф'), 350),
#  (('ь', 'ц'), 346),
#  (('л', 'к'), 337),
#  (('ї', 'і'), 334),
#  (('ю', 'м'), 333),
#  (('х', 'д'), 332),
#  (('и', 'у'), 330),
#  (('ю', 'а'), 324),
#  (('ж', 'в'), 323),
#  (('я', 'о'), 321),
#  (('м', 'л'), 320),
#  (('ю', 'з'), 320),
#  (('р', 'п'), 318),
#  (('ш', 'в'), 314),
#  (('л', 'б'), 313),
#  (('х', 'с'), 312),
#  (('я', 'ж'), 312),
#  (('г', 'б'), 311),
#  (('я', 'й'), 309),
#  (('ь', 'ч'), 307),
#  (('є', 'ю'), 304),
#  (('ї', 'т'), 296),
#  (('є', 'в'), 290),
#  (('л', 'н'), 289),
#  (('ч', 'ч'), 288),
#  (('м', 'м'), 287),
#  (('з', 'ц'), 285),
#  (('р', 'л'), 285),
#  (('л', 'д'), 285),
#  (('ч', 'я'), 284),
#  (('п', 'н'), 282),
#  (('є', 'н'), 281),
#  (('у', 'й'), 280),
#  (('е', 'у'), 280),
#  (('с', 'ю'), 279),
#  (('к', 'я'), 278),
#  (('г', 'е'), 272),
#  (('х', 'е'), 272),
#  (('ж', 'б'), 272),
#  (('г', 'т'), 272),
#  (('ф', 'с'), 272),
#  (('к', 'д'), 271),
#  (('п', 'т'), 271),
#  (('х', 'з'), 269),
#  (('й', 'у'), 268),
#  (('й', 'а'), 266),
#  (('і', 'у'), 256),
#  (('ю', 'к'), 256),
#  (('й', 'г'), 252),
#  (('р', 'б'), 252),
#  (('ь', 'а'), 252),
#  (('б', 'с'), 251),
#  (('ь', 'й'), 251),
#  (('х', 'р'), 244),
#  (('б', 'п'), 244),
#  (('и', 'є'), 241),
#  (('р', 'ц'), 240),
#  (('ж', 'ч'), 238),
#  (('м', 'щ'), 237),
#  (('ь', 'р'), 236),
#  (('ю', 'х'), 235),
#  (('й', 'х'), 235),
#  (('є', 'п'), 233),
#  (('т', 'п'), 230),
#  (('г', 'к'), 230),
#  (('щ', 'и'), 228),
#  (('о', 'ф'), 223),
#  (('х', 'к'), 217),
#  (('й', 'л'), 216),
#  (('ю', 'я'), 216),
#  (('я', 'ї'), 216),
#  (('в', 'х'), 214),
#  (('з', 'з'), 211),
#  (('й', 'я'), 208),
#  (('т', 'ж'), 205),
#  (('ї', 'р'), 204),
#  (('д', 'г'), 204),
#  (('ї', 'к'), 203),
#  (('т', 'з'), 202),
#  (('й', 'щ'), 199),
#  (('ї', 'б'), 194),
#  (('ю', 'щ'), 194),
#  (('є', 'д'), 193),
#  (('ж', 'п'), 191),
#  (('б', 'т'), 189),
#  (('к', 'ш'), 189),
#  (('я', 'ю'), 188),
#  (('є', 'с'), 188),
#  (('н', 'р'), 188),
#  (('ч', 'л'), 187),
#  (('ф', 'е'), 185),
#  (('ї', 'о'), 185),
#  (('т', 'д'), 184),
#  (('р', 'ю'), 180),
#  (('б', 'м'), 179),
#  (('х', 'б'), 177),
#  (('є', 'ш'), 177),
#  (('ї', 'г'), 176),
#  (('р', 'х'), 176),
#  (('р', 'ж'), 176),
#  (('м', 'ц'), 170),
#  (('ю', 'ю'), 170),
#  (('я', 'є'), 169),
#  (('ї', 'ж'), 168),
#  (('к', 'ц'), 165),
#  (('д', 'ш'), 160),
#  (('ь', 'ї'), 160),
#  (('ь', 'г'), 157),
#  (('с', 'г'), 155),
#  (('к', 'к'), 155),
#  (('ю', 'г'), 153),
#  (('ї', 'а'), 153),
#  (('щ', 'і'), 153),
#  (('д', 'х'), 151),
#  (('й', 'ц'), 148),
#  (('ф', 'р'), 147),
#  (('у', 'ї'), 146),
#  (('п', 'ч'), 145),
#  (('с', 'з'), 145),
#  (('н', 'є'), 144),
#  (('з', 'ч'), 144),
#  (('н', 'г'), 142),
#  (('ь', 'л'), 140),
#  (('ж', 'з'), 138),
#  (('є', 'щ'), 138),
#  (('м', 'х'), 136),
#  (('ь', 'ю'), 136),
#  (('р', 'р'), 136),
#  (('ю', 'о'), 134),
#  (('я', 'у'), 134),
#  (('ї', 'л'), 133),
#  (('р', 'й'), 133),
#  (('м', 'г'), 133),
#  (('т', 'м'), 133),
#  (('ч', 'в'), 132),
#  (('с', 'б'), 129),
#  (('б', 'з'), 129),
#  (('є', 'з'), 129),
#  (('з', 'ї'), 129),
#  (('ь', 'х'), 128),
#  (('м', 'ю'), 128),
#  (('ж', 'т'), 128),
#  (('б', 'д'), 127),
#  (('б', 'я'), 126),
#  (('с', 'д'), 123),
#  (('н', 'л'), 122),
#  (('м', 'ї'), 122),
#  (('к', 'ч'), 121),
#  (('н', 'щ'), 121),
#  (('х', 'г'), 120),
#  (('ю', 'є'), 119),
#  (('у', 'ф'), 119),
#  (('ю', 'е'), 116),
#  (('т', 'щ'), 114),
#  (('л', 'с'), 113),
#  (('т', 'б'), 113),
#  (('є', 'і'), 112),
#  (('ї', 'ч'), 112),
#  (('ю', 'й'), 111),
#  (('г', 'п'), 110),
#  (('б', 'к'), 109),
#  (('н', 'х'), 108),
#  (('ю', 'л'), 108),
#  (('х', 'я'), 106),
#  (('м', 'ш'), 105),
#  (('и', 'ф'), 104),
#  (('ж', 'с'), 104),
#  (('д', 'ї'), 103),
#  (('ю', 'ц'), 102),
#  (('х', 'х'), 100),
#  (('ф', 'у'), 99),
#  (('б', 'х'), 99),
#  (('г', 'с'), 97),
#  (('є', 'й'), 96),
#  (('к', 'г'), 95),
#  (('ї', 'я'), 92),
#  (('ч', 'б'), 92),
#  (('т', 'ч'), 91),
#  (('ш', 'п'), 90),
#  (('х', 'ч'), 90),
#  (('у', 'у'), 90),
#  (('з', 'ш'), 90),
#  (('г', 'в'), 89),
#  (('є', 'р'), 87),
#  (('а', 'е'), 86),
#  (('г', 'з'), 86),
#  (('ж', 'я'), 86),
#  (('п', 'с'), 85),
#  (('р', 'ч'), 84),
#  (('ж', 'м'), 83),
#  (('є', 'к'), 83),
#  (('х', 'щ'), 82),
#  (('ц', 'н'), 79),
#  (('т', 'ц'), 79),
#  (('к', 'х'), 78),
#  (('л', 'п'), 78),
#  (('ч', 'т'), 77),
#  (('ю', 'у'), 77),
#  (('к', 'й'), 76),
#  (('л', 'г'), 76),
#  (('л', 'т'), 76),
#  (('к', 'ж'), 74),
#  (('ї', 'у'), 74),
#  (('т', 'х'), 74),
#  (('ш', 'с'), 72),
#  (('ш', 'м'), 70),
#  (('д', 'щ'), 69),
#  (('ї', 'щ'), 68),
#  (('з', 'й'), 67),
#  (('і', 'е'), 67),
#  (('є', 'я'), 67),
#  (('ш', 'з'), 67),
#  (('п', 'ц'), 67),
#  (('м', 'й'), 66),
#  (('є', 'б'), 65),
#  (('г', 'ш'), 65),
#  (('є', 'а'), 65),
#  (('з', 'ж'), 63),
#  (('х', 'ц'), 63),
#  (('й', 'ф'), 62),
#  (('ю', 'ш'), 61),
#  (('т', 'г'), 60),
#  (('ш', 'я'), 59),
#  (('ж', 'ц'), 58),
#  (('ь', 'ф'), 58),
#  (('к', 'ї'), 58),
#  (('е', 'є'), 57),
#  (('ї', 'ц'), 56),
#  (('ц', 'т'), 56),
#  (('с', 'р'), 56),
#  (('з', 'х'), 54),
#  (('л', 'м'), 53),
#  (('г', 'д'), 53),
#  (('ч', 'з'), 53),
#  (('м', 'ж'), 52),
#  (('б', 'б'), 52),
#  (('д', 'й'), 52),
#  (('с', 'ф'), 52),
#  (('р', 'щ'), 52),
#  (('й', 'й'), 52),
#  (('ю', 'ж'), 52),
#  (('р', 'ь'), 51),
#  (('я', 'ш'), 50),
#  (('є', 'о'), 50),
#  (('л', 'ц'), 49),
#  (('у', 'е'), 49),
#  (('о', 'е'), 48),
#  (('ю', 'ї'), 48),
#  (('п', 'к'), 47),
#  (('ь', 'ж'), 47),
#  (('є', 'ч'), 46),
#  (('л', 'в'), 46),
#  (('н', 'ї'), 46),
#  (('м', 'ф'), 43),
#  (('н', 'ж'), 43),
#  (('с', 'щ'), 42),
#  (('й', 'ї'), 42),
#  (('х', 'ж'), 41),
#  (('ч', 'с'), 41),
#  (('є', 'ж'), 41),
#  (('б', 'й'), 40),
#  (('ф', 'л'), 40),
#  (('є', 'ц'), 40),
#  (('ж', 'р'), 39),
#  (('щ', 'у'), 39),
#  (('б', 'ї'), 39),
#  (('є', 'г'), 39),
#  (('д', 'ю'), 38),
#  (('в', 'ф'), 38),
#  (('с', 'ч'), 38),
#  (('т', 'є'), 38),
#  (('ш', 'д'), 35),
#  (('т', 'ф'), 35),
#  (('м', 'є'), 34),
#  (('и', 'е'), 34),
#  (('ц', 'а'), 34),
#  (('б', 'ц'), 34),
#  (('б', 'ю'), 33),
#  (('ч', 'п'), 33),
#  (('и', 'ю'), 32),
#  (('ч', 'ц'), 31),
#  (('б', 'г'), 31),
#  (('х', 'ї'), 30),
#  (('б', 'є'), 29),
#  (('ж', 'х'), 29),
#  (('л', 'з'), 28),
#  (('х', 'ю'), 28),
#  (('ч', 'м'), 28),
#  (('ж', 'ї'), 28),
#  (('й', 'ю'), 28),
#  (('ж', 'г'), 28),
#  (('є', 'х'), 27),
#  (('х', 'ш'), 27),
#  (('х', 'ф'), 27),
#  (('е', 'е'), 27),
#  (('п', 'п'), 27),
#  (('я', 'ф'), 26),
#  (('з', 'ф'), 26),
#  (('р', 'є'), 26),
#  (('ж', 'й'), 25),
#  (('ч', 'д'), 25),
#  (('с', 'й'), 25),
#  (('ж', 'ж'), 24),
#  (('ш', 'щ'), 24),
#  (('ф', 'и'), 24),
#  (('й', 'е'), 23),
#  (('ф', 'т'), 23),
#  (('ї', 'ш'), 23),
#  (('х', 'й'), 23),
#  (('ю', 'ф'), 23),
#  (('ш', 'б'), 22),
#  (('є', 'л'), 22),
#  (('я', 'е'), 22),
#  (('т', 'й'), 22),
#  (('б', 'ш'), 22),
#  (('п', 'в'), 22),
#  (('ш', 'р'), 21),
#  (('н', 'й'), 21),
#  (('с', 'ї'), 21),
#  (('ч', 'г'), 21),
#  (('г', 'я'), 21),
#  (('г', 'м'), 20),
#  (('з', 'ю'), 20),
#  (('ш', 'ч'), 19),
#  (('в', 'ю'), 19),
#  (('р', 'ф'), 19),
#  (('б', 'щ'), 19),
#  (('ж', 'щ'), 18),
#  (('р', 'ї'), 18),
#  (('т', 'ї'), 18),
#  (('з', 'щ'), 17),
#  (('н', 'ф'), 17),
#  (('т', 'ш'), 16),
#  (('ч', 'ю'), 16),
#  (('ї', 'е'), 15),
#  (('ф', 'ф'), 15),
#  (('п', 'ш'), 15),
#  (('п', 'з'), 15),
#  (('с', 'є'), 14),
#  (('ц', 'в'), 14),
#  (('ш', 'ц'), 14),
#  (('ц', 'у'), 14),
#  (('б', 'ж'), 13),
#  (('г', 'ї'), 13),
#  (('г', 'щ'), 13),
#  (('к', 'ф'), 13),
#  (('б', 'ч'), 13),
#  (('ч', 'й'), 13),
#  (('ч', 'р'), 13),
#  (('з', 'є'), 13),
#  (('л', 'щ'), 12),
#  (('ь', 'е'), 12),
#  (('ч', 'ї'), 12),
#  (('є', 'у'), 12),
#  (('ї', 'ф'), 12),
#  (('ш', 'ш'), 11),
#  (('г', 'х'), 11),
#  (('л', 'х'), 11),
#  (('г', 'ч'), 10),
#  (('ї', 'є'), 10),
#  (('г', 'г'), 10),
#  (('ь', 'є'), 10),
#  (('д', 'ф'), 10),
#  (('г', 'ц'), 10),
#  (('л', 'ф'), 10),
#  (('с', 'ш'), 9),
#  (('с', 'ж'), 8),
#  (('п', 'ю'), 8),
#  (('ч', 'щ'), 8),
#  (('й', 'є'), 8),
#  (('г', 'й'), 8),
#  (('ф', 'к'), 8),
#  (('ч', 'х'), 8),
#  (('л', 'р'), 8),
#  (('ш', 'г'), 8),
#  (('х', 'є'), 8),
#  (('в', 'є'), 8),
#  (('п', 'д'), 7),
#  (('к', 'є'), 7),
#  (('ж', 'ю'), 7),
#  (('ж', 'ф'), 7),
#  (('ш', 'ї'), 7),
#  (('л', 'ї'), 6),
#  (('ч', 'ж'), 5),
#  (('п', 'м'), 5),
#  (('ї', 'ю'), 5),
#  (('ш', 'х'), 5),
#  (('ш', 'ж'), 5),
#  (('ц', 'о'), 5),
#  (('п', 'є'), 5),
#  (('п', 'г'), 5),
#  (('ж', 'є'), 5),
#  (('ш', 'й'), 5),
#  (('п', 'щ'), 5),
#  (('п', 'х'), 5),
#  (('п', 'б'), 5),
#  (('ц', 'м'), 4),
#  (('ш', 'ю'), 4),
#  (('ш', 'ф'), 4),
#  (('є', 'е'), 4),
#  (('ф', 'п'), 4),
#  (('ж', 'ш'), 4),
#  (('л', 'й'), 4),
#  (('є', 'ф'), 3),
#  (('ф', 'д'), 3),
#  (('л', 'ж'), 3),
#  (('ц', 'с'), 3),
#  (('п', 'й'), 3),
#  (('г', 'ю'), 3),
#  (('г', 'є'), 2),
#  (('ч', 'ф'), 2),
#  (('б', 'ф'), 2),
#  (('ф', 'в'), 2),
#  (('ц', 'р'), 2),
#  (('ц', 'щ'), 2),
#  (('л', 'є'), 2),
#  (('ц', 'д'), 2),
#  (('ф', 'б'), 2),
#  (('л', 'ч'), 2),
#  (('г', 'ж'), 2),
#  (('ц', 'б'), 2),
#  (('ф', 'я'), 2),
#  (('ф', 'н'), 1),
#  (('ф', 'г'), 1),
#  (('ц', 'к'), 1),
#  (('е', 'и'), 1),
#  (('п', 'ф'), 1),
#  (('ф', 'м'), 1),
#  (('щ', 'н'), 1),
#  (('ч', 'ш'), 1),
#  (('ц', 'ч'), 1),
#  (('л', 'ш'), 1),
#  (('ц', 'г'), 1),
#  (('ц', 'п'), 1),
#  (('п', 'ж'), 1),
#  (('и', 'и'), 1),
#  (('п', 'ї'), 1),
#  (('к', 'ю'), 1),
#  (('г', 'ф'), 1)]

# %% [markdown]
# 3) H1, H2

# %%
def entropy_letter(text):
    x = len(letter_frequency(letter_counter(text)))
    H1 = 0
    for i in range(x):
        H1 += (letter_frequency(letter_counter(text))[i][1] * m.log2(letter_frequency(letter_counter(text))[i][1])) * (-1)
    
    return H1
        
def entropy_bigrams(text):
    l = []
    for i in range(941):
        l.append(bigrams_counter(text)[i][1])
    
    x = 941 
    N_bigrams = 1416949
    
    H2 = 0
    for i in range(x):
        H2 += (((l[i]) / N_bigrams) * m.log2(((l[i]) / N_bigrams))) * (-1)
    
    return H2 * 0.5

# %%
entropy_letter(TEXT)
# Out:
# 4.592872413230112

# %%
entropy_bigrams(TEXT)
# Out:
# 4.216828505470758

# %% [markdown]
# 4) I1, I2

# %%
def conformity_index_letter(text):
    L = len(text)
    return (1/(L * (L-1))) * sum(letter_counter(text)[i] * (letter_counter(text)[i] - 1) for i in ukr_clean_alphabet)

def conformity_index_bigrams(text):
    L = len(text)
    
    l = []
    for i in range(941):
        l.append(bigrams_counter(text)[i][1])
    
    I2 = 0
    for i in range(941):
        I2 += l[i] * (l[i] - 1)
    
    return I2 / (L * (L - 1))

# %%
conformity_index_letter(TEXT)
# Out:
# 0.04928235830845431

# %%
conformity_index_bigrams(TEXT)
# Out:
# 0.004381493632890787

# %% [markdown]
# **3. Вспомогательные функции**

# %%
#char ---> int
def text_to_array_of_num(text):
    return [ukr_clean_alphabet.find(i) for i in text]

#int ---> char
def array_of_numbers_to_text(num):
    return ''.join([ukr_clean_alphabet[i] for i in num])

# %% [markdown]
# **4. Генерирование текстов**

# %%
def generate_text_samples(text, L, N):
    X = []
    end_of_random_number = len(text) - L - 1
    
    for i in range(N):
        pos_l = []
        position = np.random.randint(end_of_random_number)
        pos_l.append(position)
        pos_l.append(position + L)
        X.append(pos_l)
    
    text_list = []
    for i in range(len(X)):
        text_list.append(text[X[i][0]:X[i][1]])
    
    return text_list

# %%
texts_10_10000 = []
texts_10_10000  = generate_text_samples(TEXT, 10, 10000)
print(texts_10_10000)
# Out:
# ['екатиймучи', 'раднимтоно', 'ібіляберег', 'ьзякоюпред', 'апотімодин', 'простомовб', 'пибілоїтка', 'елеюбулоте', 'аподуматищ', 'шпоменедот', 'мвикреслит', 'віскігукну', 'естищонебу', 'ермайжебла', 'ценебулопо', 'оказавйому', 'епізнішеде', 'перешіптую', 'ахіосьвона', 'хиколивона', 'иввідчувце', 'звичайнові', 'лайдовінал', 'днакнезваж', 'мужчиниіже', 'оніпершаза', 'ічогопрямо', 'зсвоїмибат', 'ноювесьвіл', 'епізноавта', 'номулужкущ', 'райдлячовн', 'будинкутом', 'щовінбільш', 'охазяїнові', 'омпізнішей', 'езароботуп', 'ятелініувс', 'таючипрорі', 'сернаскіль', 'нноюсвоєрі', 'приякихвон', 'мутьсящожт', 'акізеленіі', 'ломуцьогоб', 'евінтакийс', 'ізавісикро', 'йнасправді', 'итьвульгар', 'апечатаних', 'зуміюкажуі', 'урзіповерн', 'рдомаджекі', 'карямитуту', 'таестиітеп', 'відалисяпр', 'устрівтамд', 'протиемері', 'атйомунепо', 'датковихро', 'аведливобу', 'глароберта', 'іхаючисьзп', 'афабрицієс', 'щедрістьсл', 'тенумабуть', 'дклайділюс', 'потімбувви', 'осебедодом', 'забуватипр', 'сявкожнійр', 'ращевсероз', 'тиладивнус', 'обистівраж', 'утоймомент', 'сянанихякр', 'весьчасвін', 'провадитит', 'апитаннями', 'ізнішегрен', 'щенебувуна', 'нетуввійшо', 'цеягадаюви', 'ащосьсказа', 'дчовенабон', 'тьстюартув', 'лиїїдійшов', 'ейпланбуло', 'уланогоюко', 'оюівсежпро', 'удьякогохл', 'уігемгілбе', 'дріподороз', 'огоботакаб', 'нвибулитак', 'кучатитобі', 'вавщовоназ', 'еріхтознає', 'мдужевдячн', 'дочитавшил', 'стоїтьцетв', 'уадівчиназ', 'инадеякуви', 'аболітніжі', 'томущовгор', 'ленийайзле', 'напевнопов', 'амоякібелн', 'ямвінчасом', 'веселозгом', 'аланічабок', 'речалисяпр', 'деаламивін', 'жерадавона', 'еріназвору', 'аданнятазо', 'нижцідовел', 'єтьсявньог', 'исилаютьав', 'бувцьогопе', 'узчорнимфо', 'енадванадц', 'оясестраге', 'цятьаботим', 'отакпросто', 'повівклайд', 'вклайдусво', 'асондрасон', 'личезнимпо', 'юпровинуві', 'їатеперівс', 'являвїйосо', 'датинатаке', 'ичайноянап', 'фабрикипри', 'дбутисяніч', 'мисумління', 'цецілкомвл', 'жинічогоні', 'йоговінмяв', 'сяблагопол', 'цебуласвоє', 'сязнеминуч', 'азнихпопсо', 'одінатридц', 'кезнайомст', 'уладайтеме', 'істилигазе', 'огоатиякви', 'тепертакне', 'ечасякщояв', 'ябачуввашо', 'гоякізгодо', 'зумілащовс', 'будьінакше', 'слівсондра', 'ковихчерев', 'івусіхвасс', 'тутстільки', 'ибуливготе', 'бмежитисеб', 'аівеселаро', 'їсправиіре', 'свідчилипр', 'исочіликуп', 'акивсерйоз', 'кийвінбувп', 'вінподумав', 'теколивамв', 'шливоподан', 'иклайдмавд', 'ожеповерну', 'арфбільшуч', 'азіназавжд', 'иіотжейому', 'ябачитивго', 'юракеткоюв', 'ейпершийпо', 'ретерерхіг', 'гілбертові', 'їчинетакпр', 'итивцеалея', 'бохтактраг', 'сецечистіс', 'хлюдейзвиш', 'ларіванамо', 'ігидотніре', 'бразливуне', 'чидвідецеб', 'кіядавтобі', 'инейомувін', 'цьомунадто', 'одноюпідпр', 'азвіндобре', 'віпристави', 'есличовент', 'атидодалав', 'утрішньоро', 'гоунасжезн', 'гилуклайдс', 'кийхудийпр', 'ертаючисьд', 'знаємощови', 'утьтутйого', 'ивонирушил', 'ритулкуівт', 'віврозпаду', 'ідобухтитр', 'ьусецехочн', 'ипадковоза', 'ютонівгрей', 'ервнядодру', 'менеітодім', 'вінусебехо', 'титількита', 'лапланиімр', 'рившисьвон', 'іализякими', 'якнайкраще', 'імнетакцік', 'кінецькінц', 'іоскадепро', 'кахбоягузо', 'рогулянокн', 'сиділанапо', 'ожніхтонер', 'невідмісфі', 'бадоосеніщ', 'чнимтактеп', 'ясноюпричи', 'укипитання', 'перзвернут', 'анадцятьші', 'нетакаогря', 'теліподиви', 'ийпомиливс', 'тезвідсиві', 'натодругаз', 'исправдіви', 'ивостівінп', 'ксказаликл', 'ішістнадця', 'умоюалемий', 'еподумалая', 'мивимогами', 'лантерейни', 'всіхдівчат', 'відповісти', 'ертитеперя', 'авгамувати', 'ючиможливі', 'орськоїроб', 'ільногоікр', 'аяканебіль', 'нприємнопр', 'имчитанням', 'ймаленькій', 'ервовомупо', 'окостюмлеж', 'ешвонаопус', 'немаєзнайо', 'одитьунена', 'наніколине', 'рожченіжна', 'очклайдтак', 'отжевінпок', 'гріфітсиоч', 'казаларобе', 'зарозуміли', 'хтирадивме', 'йднедоторк', 'зуватицьом', 'почнезапер', 'аначальник', 'нучезагрож', 'одванадцят', 'ддійшоввис', 'дважкоїбід', 'вдііцеспов', 'кутакбудез', 'очимжертву', 'ільшепісля', 'изькихтаха', 'саклайдзра', 'сятдоларів', 'етахалед ...

# %%
texts_100_10000 = []
texts_100_10000  = generate_text_samples(TEXT, 100, 10000)

# %%
texts_1000_10000 = []
texts_1000_10000 = generate_text_samples(TEXT, 1000, 10000)

# %%
texts_10000_1000 = []
texts_10000_1000  = generate_text_samples(TEXT, 10000, 1000)

# %% [markdown]
# **5. Изменение текста**

# %% [markdown]
# 1) l = 1 (функции для монограмм)

# %% [markdown]
# - VIGENERE_encryption_letter (r = 1, 5, 10) +
# - Afine_encryption_letter +
# - uniform_letter +
# - s_letter +

# %%
def mod(x, y, z):
    return (x + y) % z

def random_key(length):
    letters = 'абвгдеєжзиіїйклмнопрстуфхцчшщьюя'
    rand_string = ''.join(random.choice(letters) for i in range(length))
    
    return rand_string

def key_initialization():
    temp = []
    
    k1 = random_key(1)
    k5 = random_key(5)
    k10 = random_key(10)
    
    temp.append(text_to_array_of_num(k1))
    temp.append(text_to_array_of_num(k5))
    temp.append(text_to_array_of_num(k10))
                
    return temp

# %%
key_initialization()
# Out:
# [[9], [11, 20, 24, 11, 6], [21, 19, 4, 1, 9, 2, 20, 24, 6, 13]]

# %%
def VIGENERE_encryption_letter(text, key):
    text = text_to_array_of_num(text)
    cipher = []
    
    for i in range(len(text)):
        cipher.append(mod(text[i], key[i % len(key)], 32))
    
    return array_of_numbers_to_text(cipher)

# %%
VIGENERE_encryption_letter(texts_100_10000[0], key_initialization()[0])
# Out:
# 'кужзаькьлбдеяжбпєялкємлзбрпчьяплюролйблюжаюжпвнкрьояжифвйлбькяжкяжечйвеолюлшяжкмнлоплоіьдвілйрквюрбч'

# %%
def Afine_letter(text):
    encrypt_text = []
    a = np.random.randint(32)
    b = np.random.randint(32)
    
    new_text = text_to_array_of_num(text)
    
    for i in new_text:
        encrypt_text.append(mod(a * i, b, 32))
   
    return array_of_numbers_to_text(encrypt_text)

# %%
Afine_letter('апрлвлг')
# Out:
# 'ахсзхзс'

# %%
def uniform_letter(L):
    list_of_rand = []
    for i in range(L):
        list_of_rand.append(np.random.randint(32))
    
    return array_of_numbers_to_text(list_of_rand)

# %%
uniform_letter(100)
# Out:
# 'ьрубтсещхуіффахнньтиаіфрмюеурїїнчжчиившьіивжвоумюяикгбикптощмяййьянечтцлкиечлєфеоміофуьжнвеьвілифйдї'

# %%
def s_letter(L):
    m = 32
    s0 = np.random.randint(32)
    s1 = np.random.randint(32)
    
    Y = [s0, s1] + [0] * (L - 2)
    
    for i in range(2, L):
        Y[i] = (Y[i-1] + Y[i-2]) % m 
    
    return array_of_numbers_to_text(Y)

# %%
s_letter(100)
# Out:
# 'фхмжуьрнгруиязжмуешашшуожхяфукгнргуцмзфяутїаїїубфхмжуьрнгруиязжмуешашшуожхяфукгнргуцмзфяутїаїїубфхмж'

# %% [markdown]
# 2) l = 2 (функции для биграмм)

# %% [markdown]
# - VIGENERE_encryption_bigram (r = 1, 5, 10)
# - Afine_bigram
# - uniform_bigram
# - s_bigram

# %% [markdown]
# **6. Реализация критериев (частые l-граммы)**

# %% [markdown]
# 1) l = 1

# %% [markdown]
# - criterion_20:
# > 1. criterion_20_vigenere_r1_letter +
# > 2. criterion_20_vigenere_r5_letter +
# > 3. criterion_20_vigenere_r10_letter +
# > 4. criterion_20_afine_letter
# > 5. criterion_20_uniform_letter
# > 6. criterion_20_s_letter
#
# - criterion_21:
# > 1. criterion_21_vigenere_r1_letter
# > 2. criterion_21_vigenere_r5_letter
# > 3. criterion_21_vigenere_r10_letter
# > 4. criterion_21_afine_letter
# > 5. criterion_21_uniform_letter
# > 6. criterion_21_s_letter
#
# - criterion_22:
# > 1. criterion_22_vigenere_r1_letter
# > 2. criterion_22_vigenere_r5_letter
# > 3. criterion_22_vigenere_r10_letter
# > 4. criterion_22_afine_letter
# > 5. criterion_22_uniform_letter
# > 6. criterion_22_s_letter
#
# - criterion_23:
# > 1. criterion_23_vigenere_r1_letter
# > 2. criterion_23_vigenere_r5_letter
# > 3. criterion_23_vigenere_r10_letter
# > 4. criterion_23_afine_letter
# > 5. criterion_23_uniform_letter
# > 6. criterion_23_s_letter
#
# - criterion_conformity
# > 1. criterion_conformity_vigenere_r1_letter
# > 2. criterion_conformity_vigenere_r5_letter
# > 3. criterion_conformity_vigenere_r10_letter
# > 4. criterion_conformity_afine_letter
# > 5. criterion_conformity_uniform_letter
# > 6. criterion_conformity_s_letter
#
# - criterion_structural
# > 1. criterion_structural_vigenere_r1_letter
# > 2. criterion_structural_vigenere_r5_letter
# > 3. criterion_structural_vigenere_r10_letter
# > 4. criterion_structural_afine_letter
# > 5. criterion_structural_uniform_letter
# > 6. criterion_structural_s_letter

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %%
A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']

# %% [markdown]
# criterion_20(1)

# %%
def criterion_20_vigenere_r1_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r1_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0009)

# %%
criterion_20_vigenere_r1_letter(texts_100_10000, 15)
# Out:
# (1.0, 0.8131)

# %%
criterion_20_vigenere_r1_letter(texts_1000_10000, 7)
# Out:
# (1.0, 1.0)

# %%
criterion_20_vigenere_r1_letter(texts_10000_1000, 30)
# Out:
# (1.0, 1.0)

# %% [markdown]
# criterion_20(2)

# %%
def criterion_20_vigenere_r5_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r5_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0009)

# %%
criterion_20_vigenere_r5_letter(texts_100_10000, 7)
# Out:
# (1.0, 0.9852)

# %%
criterion_20_vigenere_r5_letter(texts_1000_10000, 31)
# Out:
# (1.0, 0.9279)

# %%
criterion_20_vigenere_r5_letter(texts_10000_1000, 31)
# Out:
# (1.0, 1.0)

# %% [markdown]
# criterion_20(3)

# %%
def criterion_20_vigenere_r10_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r10_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0009)

# %%
criterion_20_vigenere_r10_letter(texts_100_10000, 16)
# Out:
# (1.0, 0.7709)

# %%
criterion_20_vigenere_r10_letter(texts_1000_10000, 20)
# Out:
# (1.0, 1.0)

# %%
criterion_20_vigenere_r10_letter(texts_10000_1000, 30)
# Out:
# (1.0, 1.0)

# %% [markdown]
# criterion_20(4)

# %%
def criterion_20_afine_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_afine_letter(texts_10_10000, 6)
# Out:
# (1.0, 0.0079)

# %%
criterion_20_afine_letter(texts_100_10000, 9)
# Out:
# (1.0, 0.9684)

# %%
criterion_20_afine_letter(texts_1000_10000, 25)
# Out:
# (1.0, 0.999)

# %%
criterion_20_afine_letter(texts_10000_1000, 25)
# Out:
# (1.0, 1.0)
