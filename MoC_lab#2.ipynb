# %%
import numpy as np
import re, textwrap
import math as m
import random

from collections import Counter
import nltk


# fix github
import sys
import gzip
from base64 import b64encode, b64decode

# %% [markdown]
# **1. Предварительная обработка текста**

# %%
with open("Dreiser.txt", 'rb') as file: 
    TEXT = file.read().decode('utf-8')
    
pattern_1 = r'ґ'
pattern_2 = r'[^абвгдеєжзиіїйклмнопрстуфхцчшщьюя]'

TEXT = re.sub(pattern_1, 'г', TEXT.lower())
TEXT = re.sub(pattern_2, '', TEXT)

# %% [markdown]
# **2. Расчёт статистических данных текста**

# %%
ukr_clean_alphabet = 'абвгдеєжзиіїйклмнопрстуфхцчшщьюя'

# %%
def letter_counter(text):
    alphabet = dict.fromkeys(list(ukr_clean_alphabet), 0)
    
    for letter in text:
        alphabet[letter] += 1
    
    return alphabet

# %%
letter_counter(TEXT)
# Out:
# {'а': 115516,
#  'б': 28941,
#  'в': 84841,
#  'г': 24462,
#  'д': 52838,
#  'е': 74034,
#  'є': 5133,
#  'ж': 15228,
#  'з': 33899,
#  'и': 87619,
#  'і': 84161,
#  'ї': 10210,
#  'й': 23372,
#  'к': 45594,
#  'л': 52192,
#  'м': 43822,
#  'н': 90412,
#  'о': 137885,
#  'п': 39320,
#  'р': 57405,
#  'с': 56137,
#  'т': 70682,
#  'у': 48930,
#  'ф': 2513,
#  'х': 13910,
#  'ц': 10704,
#  'ч': 20649,
#  'ш': 11445,
#  'щ': 10298,
#  'ь': 21038,
#  'ю': 11669,
#  'я': 32091}

# %%
N = 1416950

# %% [markdown]
# 1) Частота букв в тексте

# %%
def dictionary_sorting(dictionary):
    return [(i, round(dictionary[i]/N, 5)) for i in sorted(dictionary.keys(), key=dictionary.get, reverse=True)]

dictionary_sorting(letter_counter(TEXT))
# Out:
# [('о', 0.09731),
#  ('а', 0.08152),
#  ('н', 0.06381),
#  ('и', 0.06184),
#  ('в', 0.05988),
#  ('і', 0.0594),
#  ('е', 0.05225),
#  ('т', 0.04988),
#  ('р', 0.04051),
#  ('с', 0.03962),
#  ('д', 0.03729),
#  ('л', 0.03683),
#  ('у', 0.03453),
#  ('к', 0.03218),
#  ('м', 0.03093),
#  ('п', 0.02775),
#  ('з', 0.02392),
#  ('я', 0.02265),
#  ('б', 0.02042),
#  ('г', 0.01726),
#  ('й', 0.01649),
#  ('ь', 0.01485),
#  ('ч', 0.01457),
#  ('ж', 0.01075),
#  ('х', 0.00982),
#  ('ю', 0.00824),
#  ('ш', 0.00808),
#  ('ц', 0.00755),
#  ('щ', 0.00727),
#  ('ї', 0.00721),
#  ('є', 0.00362),
#  ('ф', 0.00177)]

# %%
def letter_frequency(dictionary):
    return [(i, round(dictionary[i]/N, 5)) for i in dictionary.keys()]

letter_frequency(letter_counter(TEXT))
# Out:
# [('а', 0.08152),
#  ('б', 0.02042),
#  ('в', 0.05988),
#  ('г', 0.01726),
#  ('д', 0.03729),
#  ('е', 0.05225),
#  ('є', 0.00362),
#  ('ж', 0.01075),
#  ('з', 0.02392),
#  ('и', 0.06184),
#  ('і', 0.0594),
#  ('ї', 0.00721),
#  ('й', 0.01649),
#  ('к', 0.03218),
#  ('л', 0.03683),
#  ('м', 0.03093),
#  ('н', 0.06381),
#  ('о', 0.09731),
#  ('п', 0.02775),
#  ('р', 0.04051),
#  ('с', 0.03962),
#  ('т', 0.04988),
#  ('у', 0.03453),
#  ('ф', 0.00177),
#  ('х', 0.00982),
#  ('ц', 0.00755),
#  ('ч', 0.01457),
#  ('ш', 0.00808),
#  ('щ', 0.00727),
#  ('ь', 0.01485),
#  ('ю', 0.00824),
#  ('я', 0.02265)]

# %% [markdown]
# 2) Частоты биграмм в тексте

# %%
def bigrams_counter(text):
    cnt = Counter(list(nltk.ngrams(text, n=2)))
    sort_dict = sorted(dict(cnt).items(), key = lambda x: x[1], reverse = True)
    
    return sort_dict

bigrams_counter(TEXT)
# Out:
# [(('н', 'а'), 19855),
#  (('о', 'в'), 16670),
#  (('в', 'і'), 15719),
#  (('н', 'е'), 15150),
#  (('т', 'и'), 15028),
#  (('п', 'о'), 14106),
#  (('р', 'о'), 13916),
#  (('а', 'в'), 13369),
#  (('г', 'о'), 12906),
#  (('е', 'р'), 12255),
#  (('с', 'т'), 12069),
#  (('о', 'г'), 12050),
#  (('л', 'а'), 11945),
#  (('л', 'и'), 11648),
#  (('т', 'а'), 11432),
#  (('і', 'н'), 11229),
#  (('в', 'и'), 10998),
#  (('о', 'н'), 10875),
#  (('в', 'о'), 10742),
#  (('о', 'м'), 10737),
#  (('и', 'в'), 10702),
#  (('в', 'а'), 10571),
#  (('п', 'р'), 10526),
#  (('а', 'т'), 10353),
#  (('а', 'л'), 10295),
#  (('н', 'о'), 10004),
#  (('н', 'і'), 9966),
#  (('р', 'а'), 9660),
#  (('е', 'н'), 9624),
#  (('о', 'д'), 9594),
#  (('о', 'б'), 9551),
#  (('і', 'д'), 9465),
#  (('д', 'о'), 9339),
#  (('і', 'в'), 8883),
#  (('к', 'о'), 8864),
#  (('о', 'с'), 8803),
#  (('и', 'н'), 8754),
#  (('н', 'и'), 8679),
#  (('з', 'а'), 8646),
#  (('а', 'н'), 8513),
#  (('и', 'т'), 8497),
#  (('т', 'о'), 8434),
#  (('с', 'я'), 8251),
#  (('щ', 'о'), 7913),
#  (('у', 'в'), 7758),
#  (('и', 'с'), 7744),
#  (('я', 'к'), 7687),
#  (('к', 'а'), 7409),
#  (('а', 'й'), 7354),
#  (('р', 'и'), 7145),
#  (('т', 'ь'), 7074),
#  (('а', 'с'), 7063),
#  (('м', 'о'), 6777),
#  (('л', 'о'), 6776),
#  (('и', 'й'), 6737),
#  (('а', 'к'), 6562),
#  (('б', 'у'), 6490),
#  (('к', 'и'), 6488),
#  (('и', 'м'), 6347),
#  (('р', 'е'), 6275),
#  (('о', 'т'), 6269),
#  (('о', 'з'), 6258),
#  (('і', 'л'), 6130),
#  (('о', 'р'), 6088),
#  (('т', 'е'), 6060),
#  (('в', 'с'), 6053),
#  (('м', 'і'), 6033),
#  (('о', 'л'), 5959),
#  (('т', 'і'), 5932),
#  (('м', 'у'), 5915),
#  (('м', 'а'), 5869),
#  (('ч', 'и'), 5850),
#  (('а', 'м'), 5811),
#  (('і', 'с'), 5763),
#  (('д', 'а'), 5708),
#  (('а', 'д'), 5512),
#  (('а', 'з'), 5439),
#  (('е', 'в'), 5307),
#  (('і', 'т'), 5226),
#  (('р', 'і'), 5216),
#  (('ж', 'е'), 5160),
#  (('а', 'п'), 4996),
#  (('д', 'и'), 4941),
#  (('з', 'н'), 4904),
#  (('н', 'у'), 4898),
#  (('о', 'п'), 4889),
#  (('а', 'р'), 4750),
#  (('у', 'т'), 4720),
#  (('о', 'к'), 4652),
#  (('л', 'е'), 4638),
#  (('й', 'о'), 4621),
#  (('д', 'у'), 4617),
#  (('е', 'з'), 4457),
#  (('к', 'л'), 4455),
#  (('и', 'л'), 4454),
#  (('п', 'е'), 4451),
#  (('й', 'д'), 4447),
#  (('е', 'п'), 4382),
#  (('л', 'ь'), 4360),
#  (('д', 'і'), 4337),
#  (('н', 'н'), 4298),
#  (('т', 'р'), 4291),
#  (('о', 'ч'), 4239),
#  (('б', 'е'), 4227),
#  (('у', 'д'), 4076),
#  (('с', 'ь'), 4067),
#  (('в', 'е'), 3992),
#  (('м', 'и'), 3992),
#  (('д', 'н'), 3972),
#  (('е', 'с'), 3855),
#  (('у', 'м'), 3801),
#  (('ц', 'е'), 3763),
#  (('ч', 'а'), 3759),
#  (('к', 'у'), 3743),
#  (('е', 'м'), 3736),
#  (('к', 'і'), 3731),
#  (('і', 'м'), 3705),
#  (('е', 'т'), 3678),
#  (('л', 'і'), 3652),
#  (('с', 'е'), 3650),
#  (('о', 'ж'), 3607),
#  (('д', 'е'), 3602),
#  (('е', 'б'), 3583),
#  (('в', 'н'), 3569),
#  (('ь', 'к'), 3554),
#  (('л', 'я'), 3551),
#  (('у', 'л'), 3534),
#  (('у', 'с'), 3514),
#  (('с', 'п'), 3505),
#  (('б', 'а'), 3482),
#  (('х', 'о'), 3470),
#  (('и', 'п'), 3461),
#  (('и', 'к'), 3409),
#  (('п', 'і'), 3408),
#  (('и', 'х'), 3404),
#  (('е', 'д'), 3402),
#  (('ь', 'о'), 3399),
#  (('т', 'у'), 3386),
#  (('і', 'к'), 3376),
#  (('с', 'і'), 3331),
#  (('н', 'я'), 3330),
#  (('а', 'б'), 3312),
#  (('г', 'а'), 3293),
#  (('м', 'е'), 3283),
#  (('і', 'п'), 3190),
#  (('я', 'т'), 3168),
#  (('р', 'у'), 3147),
#  (('я', 'в'), 3105),
#  (('с', 'о'), 3079),
#  (('і', 'з'), 3076),
#  (('и', 'з'), 3071),
#  (('ч', 'е'), 3068),
#  (('б', 'о'), 2996),
#  (('б', 'і'), 2961),
#  (('р', 'т'), 2959),
#  (('о', 'ю'), 2951),
#  (('ц', 'і'), 2943),
#  (('о', 'ї'), 2889),
#  (('е', 'л'), 2825),
#  (('а', 'г'), 2813),
#  (('і', 'й'), 2798),
#  (('и', 'д'), 2792),
#  (('а', 'ч'), 2631),
#  (('ш', 'и'), 2611),
#  (('с', 'к'), 2562),
#  (('н', 'ь'), 2492),
#  (('з', 'в'), 2491),
#  (('б', 'и'), 2483),
#  (('з', 'у'), 2414),
#  (('с', 'в'), 2385),
#  (('я', 'н'), 2383),
#  (('і', 'р'), 2353),
#  (('е', 'й'), 2351),
#  (('к', 'р'), 2326),
#  (('у', 'ж'), 2308),
#  (('в', 'у'), 2298),
#  (('ш', 'е'), 2295),
#  (('м', 'н'), 2295),
#  (('и', 'ч'), 2294),
#  (('й', 'н'), 2280),
#  (('у', 'п'), 2262),
#  (('і', 'ш'), 2257),
#  (('а', 'є'), 2185),
#  (('с', 'а'), 2164),
#  (('а', 'ж'), 2143),
#  (('ь', 'н'), 2130),
#  (('ь', 'с'), 2085),
#  (('ч', 'о'), 2066),
#  (('и', 'р'), 2040),
#  (('в', 'д'), 2020),
#  (('с', 'и'), 2001),
#  (('с', 'у'), 2001),
#  (('д', 'р'), 1997),
#  (('с', 'л'), 1988),
#  (('л', 'ю'), 1974),
#  (('а', 'х'), 1972),
#  (('я', 'д'), 1967),
#  (('і', 'б'), 1964),
#  (('я', 'з'), 1962),
#  (('з', 'д'), 1956),
#  (('ї', 'ї'), 1913),
#  (('е', 'к'), 1866),
#  (('г', 'р'), 1849),
#  (('у', 'к'), 1846),
#  (('а', 'ю'), 1840),
#  (('і', 'я'), 1839),
#  (('п', 'а'), 1837),
#  (('у', 'н'), 1826),
#  (('п', 'и'), 1822),
#  (('д', 'в'), 1813),
#  (('в', 'т'), 1807),
#  (('і', 'г'), 1786),
#  (('ж', 'н'), 1780),
#  (('у', 'р'), 1758),
#  (('б', 'л'), 1750),
#  (('ч', 'у'), 1747),
#  (('о', 'я'), 1744),
#  (('р', 'н'), 1738),
#  (('и', 'щ'), 1697),
#  (('и', 'б'), 1691),
#  (('й', 'с'), 1687),
#  (('с', 'н'), 1669),
#  (('о', 'х'), 1661),
#  (('г', 'л'), 1629),
#  (('в', 'п'), 1624),
#  (('х', 'а'), 1624),
#  (('и', 'і'), 1608),
#  (('і', 'ч'), 1601),
#  (('ж', 'а'), 1560),
#  (('ю', 'ч'), 1550),
#  (('б', 'р'), 1531),
#  (('ж', 'и'), 1512),
#  (('з', 'р'), 1506),
#  (('е', 'ч'), 1467),
#  (('а', 'і'), 1459),
#  (('и', 'ц'), 1457),
#  (('щ', 'е'), 1455),
#  (('в', 'л'), 1411),
#  (('ю', 'в'), 1401),
#  (('у', 'з'), 1397),
#  (('т', 'н'), 1395),
#  (('ц', 'ь'), 1381),
#  (('ч', 'н'), 1372),
#  (('е', 'ж'), 1347),
#  (('я', 'м'), 1340),
#  (('д', 'ж'), 1335),
#  (('в', 'ч'), 1333),
#  (('о', 'і'), 1328),
#  (('н', 'д'), 1319),
#  (('ц', 'я'), 1314),
#  (('в', 'к'), 1307),
#  (('я', 'п'), 1297),
#  (('в', 'ж'), 1293),
#  (('л', 'у'), 1289),
#  (('и', 'г'), 1289),
#  (('т', 'я'), 1286),
#  (('и', 'ї'), 1282),
#  (('в', 'в'), 1277),
#  (('т', 'в'), 1276),
#  (('з', 'і'), 1263),
#  (('д', 'ь'), 1262),
#  (('ї', 'х'), 1261),
#  (('у', 'б'), 1257),
#  (('а', 'щ'), 1231),
#  (('о', 'й'), 1228),
#  (('о', 'ц'), 1221),
#  (('н', 'з'), 1218),
#  (('у', 'ч'), 1208),
#  (('з', 'о'), 1205),
#  (('я', 'с'), 1199),
#  (('є', 'т'), 1196),
#  (('п', 'л'), 1196),
#  (('н', 'т'), 1184),
#  (('е', 'г'), 1181),
#  (('і', 'і'), 1177),
#  (('х', 'в'), 1169),
#  (('и', 'я'), 1164),
#  (('ш', 'о'), 1159),
#  (('і', 'х'), 1157),
#  (('д', 'п'), 1148),
#  (('д', 'к'), 1140),
#  (('а', 'я'), 1136),
#  (('з', 'м'), 1122),
#  (('д', 'л'), 1120),
#  (('м', 'п'), 1114),
#  (('ю', 'т'), 1111),
#  (('й', 'т'), 1100),
#  (('у', 'і'), 1097),
#  (('ю', 'д'), 1096),
#  (('к', 'н'), 1095),
#  (('ж', 'у'), 1095),
#  (('н', 'п'), 1091),
#  (('в', 'з'), 1091),
#  (('н', 'к'), 1079),
#  (('е', 'щ'), 1067),
#  (('г', 'у'), 1037),
#  (('в', 'я'), 1026),
#  (('в', 'ш'), 1011),
#  (('а', 'ш'), 1010),
#  (('а', 'ц'), 1005),
#  (('ч', 'і'), 999),
#  (('е', 'ц'), 981),
#  (('г', 'і'), 979),
#  (('к', 'в'), 976),
#  (('е', 'я'), 967),
#  (('з', 'п'), 966),
#  (('ь', 'п'), 961),
#  (('в', 'р'), 954),
#  (('х', 'і'), 937),
#  (('ф', 'і'), 935),
#  (('м', 'с'), 932),
#  (('к', 'е'), 920),
#  (('о', 'щ'), 920),
#  (('р', 'я'), 919),
#  (('я', 'і'), 919),
#  (('и', 'ш'), 918),
#  (('й', 'п'), 917),
#  (('і', 'о'), 908),
#  (('с', 'м'), 907),
#  (('о', 'о'), 905),
#  (('х', 'т'), 904),
#  (('о', 'ш'), 900),
#  (('м', 'в'), 895),
#  (('т', 'с'), 892),
#  (('н', 'ш'), 890),
#  (('й', 'в'), 878),
#  (('і', 'є'), 878),
#  (('е', 'о'), 876),
#  (('ї', 'й'), 866),
#  (('м', 'к'), 864),
#  (('а', 'о'), 862),
#  (('ь', 'в'), 857),
#  (('к', 'щ'), 841),
#  (('д', 'я'), 840),
#  (('т', 'т'), 834),
#  (('е', 'ї'), 823),
#  (('е', 'х'), 822),
#  (('у', 'г'), 818),
#  (('і', 'ж'), 817),
#  (('і', 'ф'), 816),
#  (('з', 'е'), 813),
#  (('н', 'с'), 811),
#  (('і', 'щ'), 807),
#  (('ь', 'д'), 806),
#  (('в', 'щ'), 802),
#  (('й', 'ш'), 798),
#  (('ш', 'у'), 795),
#  (('н', 'ц'), 793),
#  (('к', 'т'), 791),
#  (('у', 'х'), 790),
#  (('ш', 'т'), 784),
#  (('и', 'а'), 781),
#  (('т', 'к'), 776),
#  (('в', 'б'), 771),
#  (('м', 'я'), 763),
#  (('х', 'и'), 755),
#  (('д', 'с'), 754),
#  (('б', 'н'), 750),
#  (('і', 'ц'), 743),
#  (('я', 'г'), 742),
#  (('д', 'т'), 737),
#  (('й', 'м'), 734),
#  (('і', 'а'), 733),
#  (('ь', 'т'), 730),
#  (('х', 'н'), 728),
#  (('м', 'з'), 726),
#  (('р', 'к'), 724),
#  (('з', 'г'), 722),
#  (('й', 'б'), 722),
#  (('е', 'ш'), 718),
#  (('д', 'ч'), 717),
#  (('з', 'б'), 711),
#  (('я', 'л'), 707),
#  (('н', 'в'), 702),
#  (('ь', 'з'), 701),
#  (('в', 'г'), 697),
#  (('е', 'і'), 696),
#  (('к', 'с'), 695),
#  (('з', 'с'), 691),
#  (('з', 'л'), 690),
#  (('в', 'м'), 688),
#  (('ь', 'і'), 687),
#  (('і', 'ї'), 683),
#  (('ь', 'ш'), 682),
#  (('и', 'о'), 676),
#  (('ц', 'ю'), 675),
#  (('з', 'к'), 675),
#  (('у', 'ш'), 672),
#  (('є', 'м'), 671),
#  (('й', 'з'), 664),
#  (('о', 'є'), 662),
#  (('м', 'т'), 658),
#  (('ш', 'н'), 657),
#  (('й', 'і'), 656),
#  (('в', 'ц'), 655),
#  (('ж', 'д'), 653),
#  (('ю', 'н'), 649),
#  (('а', 'а'), 637),
#  (('ї', 'з'), 636),
#  (('р', 'в'), 633),
#  (('у', 'я'), 629),
#  (('д', 'ц'), 623),
#  (('у', 'а'), 619),
#  (('т', 'ю'), 616),
#  (('ю', 'с'), 616),
#  (('е', 'ю'), 613),
#  (('д', 'з'), 612),
#  (('я', 'ч'), 608),
#  (('и', 'ж'), 608),
#  (('ш', 'і'), 606),
#  (('я', 'б'), 602),
#  (('ш', 'а'), 601),
#  (('з', 'я'), 601),
#  (('м', 'р'), 596),
#  (('ш', 'л'), 594),
#  (('п', 'у'), 593),
#  (('г', 'н'), 590),
#  (('о', 'а'), 586),
#  (('я', 'щ'), 581),
#  (('й', 'к'), 573),
#  (('ї', 'в'), 571),
#  (('ю', 'б'), 568),
#  (('р', 'ш'), 563),
#  (('ю', 'п'), 562),
#  (('у', 'щ'), 561),
#  (('ь', 'м'), 559),
#  (('л', 'л'), 557),
#  (('ї', 'м'), 555),
#  (('р', 'д'), 554),
#  (('х', 'л'), 550),
#  (('ь', 'у'), 546),
#  (('р', 'с'), 542),
#  (('ю', 'і'), 536),
#  (('з', 'и'), 535),
#  (('д', 'д'), 531),
#  (('ї', 'п'), 527),
#  (('з', 'т'), 518),
#  (('с', 'х'), 514),
#  (('ї', 'д'), 513),
#  (('щ', 'а'), 509),
#  (('р', 'г'), 497),
#  (('в', 'ї'), 497),
#  (('м', 'д'), 495),
#  (('у', 'ю'), 491),
#  (('б', 'в'), 491),
#  (('н', 'б'), 490),
#  (('ш', 'к'), 487),
#  (('і', 'ю'), 478),
#  (('д', 'б'), 475),
#  (('є', 'ї'), 474),
#  (('й', 'ч'), 473),
#  (('г', 'и'), 470),
#  (('у', 'о'), 461),
#  (('у', 'є'), 459),
#  (('к', 'б'), 455),
#  (('к', 'п'), 454),
#  (('ж', 'і'), 451),
#  (('ї', 'с'), 451),
#  (('с', 'с'), 449),
#  (('с', 'ц'), 449),
#  (('я', 'х'), 445),
#  (('я', 'я'), 444),
#  (('а', 'у'), 440),
#  (('я', 'ц'), 436),
#  (('й', 'ж'), 435),
#  (('м', 'б'), 432),
#  (('д', 'м'), 431),
#  (('н', 'ч'), 429),
#  (('ю', 'р'), 428),
#  (('х', 'у'), 428),
#  (('ж', 'л'), 419),
#  (('ч', 'к'), 418),
#  (('к', 'з'), 417),
#  (('х', 'п'), 415),
#  (('ц', 'и'), 407),
#  (('н', 'ю'), 404),
#  (('ї', 'н'), 404),
#  (('я', 'р'), 396),
#  (('е', 'а'), 395),
#  (('е', 'ф'), 395),
#  (('ф', 'а'), 391),
#  (('ж', 'к'), 391),
#  (('р', 'м'), 389),
#  (('ь', 'я'), 388),
#  (('а', 'ї'), 386),
#  (('у', 'ц'), 384),
#  (('р', 'з'), 382),
#  (('й', 'р'), 380),
#  (('о', 'у'), 378),
#  (('н', 'м'), 378),
#  (('ж', 'о'), 372),
#  (('х', 'м'), 362),
#  (('ф', 'о'), 358),
#  (('ь', 'щ'), 357),
#  (('т', 'л'), 356),
#  (('я', 'а'), 356),
#  (('ь', 'б'), 356),
#  (('в', 'й'), 356),
#  (('п', 'я'), 354),
#  (('к', 'м'), 353),
#  (('з', 'ь'), 351),
#  (('м', 'ч'), 350),
#  (('а', 'ф'), 350),
#  (('ь', 'ц'), 346),
#  (('л', 'к'), 337),
#  (('ї', 'і'), 334),
#  (('ю', 'м'), 333),
#  (('х', 'д'), 332),
#  (('и', 'у'), 330),
#  (('ю', 'а'), 324),
#  (('ж', 'в'), 323),
#  (('я', 'о'), 321),
#  (('м', 'л'), 320),
#  (('ю', 'з'), 320),
#  (('р', 'п'), 318),
#  (('ш', 'в'), 314),
#  (('л', 'б'), 313),
#  (('х', 'с'), 312),
#  (('я', 'ж'), 312),
#  (('г', 'б'), 311),
#  (('я', 'й'), 309),
#  (('ь', 'ч'), 307),
#  (('є', 'ю'), 304),
#  (('ї', 'т'), 296),
#  (('є', 'в'), 290),
#  (('л', 'н'), 289),
#  (('ч', 'ч'), 288),
#  (('м', 'м'), 287),
#  (('з', 'ц'), 285),
#  (('р', 'л'), 285),
#  (('л', 'д'), 285),
#  (('ч', 'я'), 284),
#  (('п', 'н'), 282),
#  (('є', 'н'), 281),
#  (('у', 'й'), 280),
#  (('е', 'у'), 280),
#  (('с', 'ю'), 279),
#  (('к', 'я'), 278),
#  (('г', 'е'), 272),
#  (('х', 'е'), 272),
#  (('ж', 'б'), 272),
#  (('г', 'т'), 272),
#  (('ф', 'с'), 272),
#  (('к', 'д'), 271),
#  (('п', 'т'), 271),
#  (('х', 'з'), 269),
#  (('й', 'у'), 268),
#  (('й', 'а'), 266),
#  (('і', 'у'), 256),
#  (('ю', 'к'), 256),
#  (('й', 'г'), 252),
#  (('р', 'б'), 252),
#  (('ь', 'а'), 252),
#  (('б', 'с'), 251),
#  (('ь', 'й'), 251),
#  (('х', 'р'), 244),
#  (('б', 'п'), 244),
#  (('и', 'є'), 241),
#  (('р', 'ц'), 240),
#  (('ж', 'ч'), 238),
#  (('м', 'щ'), 237),
#  (('ь', 'р'), 236),
#  (('ю', 'х'), 235),
#  (('й', 'х'), 235),
#  (('є', 'п'), 233),
#  (('т', 'п'), 230),
#  (('г', 'к'), 230),
#  (('щ', 'и'), 228),
#  (('о', 'ф'), 223),
#  (('х', 'к'), 217),
#  (('й', 'л'), 216),
#  (('ю', 'я'), 216),
#  (('я', 'ї'), 216),
#  (('в', 'х'), 214),
#  (('з', 'з'), 211),
#  (('й', 'я'), 208),
#  (('т', 'ж'), 205),
#  (('ї', 'р'), 204),
#  (('д', 'г'), 204),
#  (('ї', 'к'), 203),
#  (('т', 'з'), 202),
#  (('й', 'щ'), 199),
#  (('ї', 'б'), 194),
#  (('ю', 'щ'), 194),
#  (('є', 'д'), 193),
#  (('ж', 'п'), 191),
#  (('б', 'т'), 189),
#  (('к', 'ш'), 189),
#  (('я', 'ю'), 188),
#  (('є', 'с'), 188),
#  (('н', 'р'), 188),
#  (('ч', 'л'), 187),
#  (('ф', 'е'), 185),
#  (('ї', 'о'), 185),
#  (('т', 'д'), 184),
#  (('р', 'ю'), 180),
#  (('б', 'м'), 179),
#  (('х', 'б'), 177),
#  (('є', 'ш'), 177),
#  (('ї', 'г'), 176),
#  (('р', 'х'), 176),
#  (('р', 'ж'), 176),
#  (('м', 'ц'), 170),
#  (('ю', 'ю'), 170),
#  (('я', 'є'), 169),
#  (('ї', 'ж'), 168),
#  (('к', 'ц'), 165),
#  (('д', 'ш'), 160),
#  (('ь', 'ї'), 160),
#  (('ь', 'г'), 157),
#  (('с', 'г'), 155),
#  (('к', 'к'), 155),
#  (('ю', 'г'), 153),
#  (('ї', 'а'), 153),
#  (('щ', 'і'), 153),
#  (('д', 'х'), 151),
#  (('й', 'ц'), 148),
#  (('ф', 'р'), 147),
#  (('у', 'ї'), 146),
#  (('п', 'ч'), 145),
#  (('с', 'з'), 145),
#  (('н', 'є'), 144),
#  (('з', 'ч'), 144),
#  (('н', 'г'), 142),
#  (('ь', 'л'), 140),
#  (('ж', 'з'), 138),
#  (('є', 'щ'), 138),
#  (('м', 'х'), 136),
#  (('ь', 'ю'), 136),
#  (('р', 'р'), 136),
#  (('ю', 'о'), 134),
#  (('я', 'у'), 134),
#  (('ї', 'л'), 133),
#  (('р', 'й'), 133),
#  (('м', 'г'), 133),
#  (('т', 'м'), 133),
#  (('ч', 'в'), 132),
#  (('с', 'б'), 129),
#  (('б', 'з'), 129),
#  (('є', 'з'), 129),
#  (('з', 'ї'), 129),
#  (('ь', 'х'), 128),
#  (('м', 'ю'), 128),
#  (('ж', 'т'), 128),
#  (('б', 'д'), 127),
#  (('б', 'я'), 126),
#  (('с', 'д'), 123),
#  (('н', 'л'), 122),
#  (('м', 'ї'), 122),
#  (('к', 'ч'), 121),
#  (('н', 'щ'), 121),
#  (('х', 'г'), 120),
#  (('ю', 'є'), 119),
#  (('у', 'ф'), 119),
#  (('ю', 'е'), 116),
#  (('т', 'щ'), 114),
#  (('л', 'с'), 113),
#  (('т', 'б'), 113),
#  (('є', 'і'), 112),
#  (('ї', 'ч'), 112),
#  (('ю', 'й'), 111),
#  (('г', 'п'), 110),
#  (('б', 'к'), 109),
#  (('н', 'х'), 108),
#  (('ю', 'л'), 108),
#  (('х', 'я'), 106),
#  (('м', 'ш'), 105),
#  (('и', 'ф'), 104),
#  (('ж', 'с'), 104),
#  (('д', 'ї'), 103),
#  (('ю', 'ц'), 102),
#  (('х', 'х'), 100),
#  (('ф', 'у'), 99),
#  (('б', 'х'), 99),
#  (('г', 'с'), 97),
#  (('є', 'й'), 96),
#  (('к', 'г'), 95),
#  (('ї', 'я'), 92),
#  (('ч', 'б'), 92),
#  (('т', 'ч'), 91),
#  (('ш', 'п'), 90),
#  (('х', 'ч'), 90),
#  (('у', 'у'), 90),
#  (('з', 'ш'), 90),
#  (('г', 'в'), 89),
#  (('є', 'р'), 87),
#  (('а', 'е'), 86),
#  (('г', 'з'), 86),
#  (('ж', 'я'), 86),
#  (('п', 'с'), 85),
#  (('р', 'ч'), 84),
#  (('ж', 'м'), 83),
#  (('є', 'к'), 83),
#  (('х', 'щ'), 82),
#  (('ц', 'н'), 79),
#  (('т', 'ц'), 79),
#  (('к', 'х'), 78),
#  (('л', 'п'), 78),
#  (('ч', 'т'), 77),
#  (('ю', 'у'), 77),
#  (('к', 'й'), 76),
#  (('л', 'г'), 76),
#  (('л', 'т'), 76),
#  (('к', 'ж'), 74),
#  (('ї', 'у'), 74),
#  (('т', 'х'), 74),
#  (('ш', 'с'), 72),
#  (('ш', 'м'), 70),
#  (('д', 'щ'), 69),
#  (('ї', 'щ'), 68),
#  (('з', 'й'), 67),
#  (('і', 'е'), 67),
#  (('є', 'я'), 67),
#  (('ш', 'з'), 67),
#  (('п', 'ц'), 67),
#  (('м', 'й'), 66),
#  (('є', 'б'), 65),
#  (('г', 'ш'), 65),
#  (('є', 'а'), 65),
#  (('з', 'ж'), 63),
#  (('х', 'ц'), 63),
#  (('й', 'ф'), 62),
#  (('ю', 'ш'), 61),
#  (('т', 'г'), 60),
#  (('ш', 'я'), 59),
#  (('ж', 'ц'), 58),
#  (('ь', 'ф'), 58),
#  (('к', 'ї'), 58),
#  (('е', 'є'), 57),
#  (('ї', 'ц'), 56),
#  (('ц', 'т'), 56),
#  (('с', 'р'), 56),
#  (('з', 'х'), 54),
#  (('л', 'м'), 53),
#  (('г', 'д'), 53),
#  (('ч', 'з'), 53),
#  (('м', 'ж'), 52),
#  (('б', 'б'), 52),
#  (('д', 'й'), 52),
#  (('с', 'ф'), 52),
#  (('р', 'щ'), 52),
#  (('й', 'й'), 52),
#  (('ю', 'ж'), 52),
#  (('р', 'ь'), 51),
#  (('я', 'ш'), 50),
#  (('є', 'о'), 50),
#  (('л', 'ц'), 49),
#  (('у', 'е'), 49),
#  (('о', 'е'), 48),
#  (('ю', 'ї'), 48),
#  (('п', 'к'), 47),
#  (('ь', 'ж'), 47),
#  (('є', 'ч'), 46),
#  (('л', 'в'), 46),
#  (('н', 'ї'), 46),
#  (('м', 'ф'), 43),
#  (('н', 'ж'), 43),
#  (('с', 'щ'), 42),
#  (('й', 'ї'), 42),
#  (('х', 'ж'), 41),
#  (('ч', 'с'), 41),
#  (('є', 'ж'), 41),
#  (('б', 'й'), 40),
#  (('ф', 'л'), 40),
#  (('є', 'ц'), 40),
#  (('ж', 'р'), 39),
#  (('щ', 'у'), 39),
#  (('б', 'ї'), 39),
#  (('є', 'г'), 39),
#  (('д', 'ю'), 38),
#  (('в', 'ф'), 38),
#  (('с', 'ч'), 38),
#  (('т', 'є'), 38),
#  (('ш', 'д'), 35),
#  (('т', 'ф'), 35),
#  (('м', 'є'), 34),
#  (('и', 'е'), 34),
#  (('ц', 'а'), 34),
#  (('б', 'ц'), 34),
#  (('б', 'ю'), 33),
#  (('ч', 'п'), 33),
#  (('и', 'ю'), 32),
#  (('ч', 'ц'), 31),
#  (('б', 'г'), 31),
#  (('х', 'ї'), 30),
#  (('б', 'є'), 29),
#  (('ж', 'х'), 29),
#  (('л', 'з'), 28),
#  (('х', 'ю'), 28),
#  (('ч', 'м'), 28),
#  (('ж', 'ї'), 28),
#  (('й', 'ю'), 28),
#  (('ж', 'г'), 28),
#  (('є', 'х'), 27),
#  (('х', 'ш'), 27),
#  (('х', 'ф'), 27),
#  (('е', 'е'), 27),
#  (('п', 'п'), 27),
#  (('я', 'ф'), 26),
#  (('з', 'ф'), 26),
#  (('р', 'є'), 26),
#  (('ж', 'й'), 25),
#  (('ч', 'д'), 25),
#  (('с', 'й'), 25),
#  (('ж', 'ж'), 24),
#  (('ш', 'щ'), 24),
#  (('ф', 'и'), 24),
#  (('й', 'е'), 23),
#  (('ф', 'т'), 23),
#  (('ї', 'ш'), 23),
#  (('х', 'й'), 23),
#  (('ю', 'ф'), 23),
#  (('ш', 'б'), 22),
#  (('є', 'л'), 22),
#  (('я', 'е'), 22),
#  (('т', 'й'), 22),
#  (('б', 'ш'), 22),
#  (('п', 'в'), 22),
#  (('ш', 'р'), 21),
#  (('н', 'й'), 21),
#  (('с', 'ї'), 21),
#  (('ч', 'г'), 21),
#  (('г', 'я'), 21),
#  (('г', 'м'), 20),
#  (('з', 'ю'), 20),
#  (('ш', 'ч'), 19),
#  (('в', 'ю'), 19),
#  (('р', 'ф'), 19),
#  (('б', 'щ'), 19),
#  (('ж', 'щ'), 18),
#  (('р', 'ї'), 18),
#  (('т', 'ї'), 18),
#  (('з', 'щ'), 17),
#  (('н', 'ф'), 17),
#  (('т', 'ш'), 16),
#  (('ч', 'ю'), 16),
#  (('ї', 'е'), 15),
#  (('ф', 'ф'), 15),
#  (('п', 'ш'), 15),
#  (('п', 'з'), 15),
#  (('с', 'є'), 14),
#  (('ц', 'в'), 14),
#  (('ш', 'ц'), 14),
#  (('ц', 'у'), 14),
#  (('б', 'ж'), 13),
#  (('г', 'ї'), 13),
#  (('г', 'щ'), 13),
#  (('к', 'ф'), 13),
#  (('б', 'ч'), 13),
#  (('ч', 'й'), 13),
#  (('ч', 'р'), 13),
#  (('з', 'є'), 13),
#  (('л', 'щ'), 12),
#  (('ь', 'е'), 12),
#  (('ч', 'ї'), 12),
#  (('є', 'у'), 12),
#  (('ї', 'ф'), 12),
#  (('ш', 'ш'), 11),
#  (('г', 'х'), 11),
#  (('л', 'х'), 11),
#  (('г', 'ч'), 10),
#  (('ї', 'є'), 10),
#  (('г', 'г'), 10),
#  (('ь', 'є'), 10),
#  (('д', 'ф'), 10),
#  (('г', 'ц'), 10),
#  (('л', 'ф'), 10),
#  (('с', 'ш'), 9),
#  (('с', 'ж'), 8),
#  (('п', 'ю'), 8),
#  (('ч', 'щ'), 8),
#  (('й', 'є'), 8),
#  (('г', 'й'), 8),
#  (('ф', 'к'), 8),
#  (('ч', 'х'), 8),
#  (('л', 'р'), 8),
#  (('ш', 'г'), 8),
#  (('х', 'є'), 8),
#  (('в', 'є'), 8),
#  (('п', 'д'), 7),
#  (('к', 'є'), 7),
#  (('ж', 'ю'), 7),
#  (('ж', 'ф'), 7),
#  (('ш', 'ї'), 7),
#  (('л', 'ї'), 6),
#  (('ч', 'ж'), 5),
#  (('п', 'м'), 5),
#  (('ї', 'ю'), 5),
#  (('ш', 'х'), 5),
#  (('ш', 'ж'), 5),
#  (('ц', 'о'), 5),
#  (('п', 'є'), 5),
#  (('п', 'г'), 5),
#  (('ж', 'є'), 5),
#  (('ш', 'й'), 5),
#  (('п', 'щ'), 5),
#  (('п', 'х'), 5),
#  (('п', 'б'), 5),
#  (('ц', 'м'), 4),
#  (('ш', 'ю'), 4),
#  (('ш', 'ф'), 4),
#  (('є', 'е'), 4),
#  (('ф', 'п'), 4),
#  (('ж', 'ш'), 4),
#  (('л', 'й'), 4),
#  (('є', 'ф'), 3),
#  (('ф', 'д'), 3),
#  (('л', 'ж'), 3),
#  (('ц', 'с'), 3),
#  (('п', 'й'), 3),
#  (('г', 'ю'), 3),
#  (('г', 'є'), 2),
#  (('ч', 'ф'), 2),
#  (('б', 'ф'), 2),
#  (('ф', 'в'), 2),
#  (('ц', 'р'), 2),
#  (('ц', 'щ'), 2),
#  (('л', 'є'), 2),
#  (('ц', 'д'), 2),
#  (('ф', 'б'), 2),
#  (('л', 'ч'), 2),
#  (('г', 'ж'), 2),
#  (('ц', 'б'), 2),
#  (('ф', 'я'), 2),
#  (('ф', 'н'), 1),
#  (('ф', 'г'), 1),
#  (('ц', 'к'), 1),
#  (('е', 'и'), 1),
#  (('п', 'ф'), 1),
#  (('ф', 'м'), 1),
#  (('щ', 'н'), 1),
#  (('ч', 'ш'), 1),
#  (('ц', 'ч'), 1),
#  (('л', 'ш'), 1),
#  (('ц', 'г'), 1),
#  (('ц', 'п'), 1),
#  (('п', 'ж'), 1),
#  (('и', 'и'), 1),
#  (('п', 'ї'), 1),
#  (('к', 'ю'), 1),
#  (('г', 'ф'), 1)]

# %% [markdown]
# 3) H1, H2

# %%
def entropy_letter(text):
    x = len(letter_frequency(letter_counter(text)))
    H1 = 0
    for i in range(x):
        H1 += (letter_frequency(letter_counter(text))[i][1] * m.log2(letter_frequency(letter_counter(text))[i][1])) * (-1)
    
    return H1
        
def entropy_bigrams(text):
    l = []
    for i in range(941):
        l.append(bigrams_counter(text)[i][1])
    
    x = 941 
    N_bigrams = 1416949
    
    H2 = 0
    for i in range(x):
        H2 += (((l[i]) / N_bigrams) * m.log2(((l[i]) / N_bigrams))) * (-1)
    
    return H2 * 0.5

# %%
entropy_letter(TEXT)
# Out:
# 4.592872413230112

# %%
entropy_bigrams(TEXT)
# Out:
# 4.216828505470758

# %% [markdown]
# 4) I1, I2

# %%
def conformity_index_letter(text):
    L = len(text)
    return (1/(L * (L-1))) * sum(letter_counter(text)[i] * (letter_counter(text)[i] - 1) for i in ukr_clean_alphabet)

def conformity_index_bigrams(text):
    L = len(text)
    
    l = []
    cnt = Counter(list(nltk.ngrams(text, n = 2)))
    for i in range(len(cnt)):
        l.append(bigrams_counter(text)[i][1])
    
    I2 = 0
    for i in range(len(cnt)):
        I2 += l[i] * (l[i] - 1)
    
    return I2 / (L * (L - 1))

# %%
conformity_index_letter(TEXT)
# Out:
# 0.04928235830845431

# %%
conformity_index_bigrams(TEXT)
# Out:
# 0.004381493632890787

# %% [markdown]
# **3. Вспомогательные функции**

# %%
#char ---> int
def text_to_array_of_num(text):
    return [ukr_clean_alphabet.find(i) for i in text]

#int ---> char
def array_of_numbers_to_text(num):
    return ''.join([ukr_clean_alphabet[i] for i in num])

# %%
def disjoint_bigrams(text):
    bigram = {}
    for i in range(m.ceil((len(text) - 1) / 2)):
        if ''.join(text[2*i : 2*i + 2]) in bigram:
            bigram[''.join(text[2*i : 2*i + 2])] += 1
        else:
            bigram[''.join(text[2*i : 2*i + 2])] = 1
            
    #for i, j in bigram.items():
        #bigram[i] = j / sum(bigram.values())
    
    
    return bigram, sum(bigram.values())

# %%
disjoint_bigrams(TEXT)
# Out:
# ({'те': 3045,
#   'од': 4858,
#   'ор': 3018,
#   'др': 995,
#   'ай': 3656,
#   'зе': 418,
#   'ра': 4735,
#   'ме': 1620,
#   'ри': 3597,
#   'ка': 3694,
#   'нс': 389,
#   'ьк': 1833,
#   'ат': 5238,
#   'ге': 131,
#   'ді': 2136,
#   'ят': 1586,
#   'ео': 414,
#   'до': 4611,
#   'рд': 301,
#   'йз': 355,
#   'ер': 6096,
#   'ам': 2888,
#   'ик': 1630,
#   'ан': 4213,
#   'сь': 2006,
#   'тр': 2199,
#   'аг': 1419,
#   'ед': 1723,
#   'ія': 911,
#   'ро': 6918,
#   'ма': 2933,
#   'нп': 536,
#   'ек': 945,
#   'ла': 5972,
#   'дз': 294,
#   'гл': 798,
#   'ій': 1358,
#   'ко': 4433,
#   'їі': 168,
#   'бу': 3263,
#   'ше': 1125,
#   'лс': 55,
#   'мі': 2960,
#   'ля': 1796,
#   'ий': 3344,
#   'ще': 721,
#   'нк': 538,
#   'оз': 3134,
#   'ав': 6727,
#   'ид': 1436,
#   'ня': 1656,
#   'мт': 333,
#   'дя': 422,
#   'пи': 880,
#   'нн': 2193,
#   'ве': 2036,
#   'рс': 267,
#   'фа': 195,
#   'йл': 93,
#   'уб': 603,
#   'ул': 1744,
#   'зм': 553,
#   'іс': 2931,
#   'тк': 393,
#   'ни': 4280,
#   'га': 1614,
#   'пе': 2232,
#   'рш': 306,
#   'ак': 3248,
#   'уг': 404,
#   'ет': 1773,
#   'як': 3793,
#   'ар': 2409,
#   'лі': 1825,
#   'тн': 739,
#   'чі': 525,
#   'рп': 172,
#   'см': 467,
#   'кт': 389,
#   'го': 6538,
#   'ви': 5487,
#   'йц': 75,
#   'ен': 4812,
#   'ст': 6039,
#   'ад': 2736,
#   'ем': 1916,
#   'шя': 33,
#   'кч': 61,
#   'от': 3192,
#   'ир': 1040,
#   'ис': 3903,
#   'та': 5690,
#   'ти': 7486,
#   'ся': 4060,
#   'чж': 2,
#   'ит': 4346,
#   'ел': 1380,
#   'ів': 4455,
#   'со': 1514,
#   'кі': 1849,
#   'ди': 2425,
#   'ті': 2966,
#   'ли': 5851,
#   'не': 7494,
#   'дь': 619,
#   'мо': 3425,
#   'жл': 226,
#   'ив': 5418,
#   'ос': 4404,
#   'зд': 1014,
#   'ян': 1170,
#   'ей': 1157,
#   'ві': 7922,
#   'рн': 879,
#   'им': 3156,
#   'що': 3887,
#   'ну': 2545,
#   'ва': 5313,
#   'аі': 728,
#   'на': 10006,
#   'ши': 1340,
#   'йв': 435,
#   'иц': 709,
#   'іт': 2592,
#   'еп': 2203,
#   'йж': 234,
#   'ез': 2213,
#   'их': 1696,
#   'йг': 125,
#   'ру': 1621,
#   'па': 897,
#   'оч': 2104,
#   'ол': 3025,
#   'ов': 8342,
#   'ік': 1746,
#   'вп': 789,
#   'де': 1747,
#   'ку': 1928,
#   'це': 1933,
#   'нь': 1206,
#   'ки': 3290,
#   'йт': 531,
#   'зб': 328,
#   'уй': 135,
#   'но': 5020,
#   'юг': 78,
#   'во': 5376,
#   'юв': 657,
#   'би': 1182,
#   'єт': 615,
#   'ьс': 1069,
#   'яз': 968,
#   'пі': 1722,
#   'дк': 546,
#   'ог': 5918,
#   'фе': 88,
#   'ок': 2364,
#   'ап': 2508,
#   'юх': 118,
#   'то': 4178,
#   'по': 7066,
#   'зн': 2461,
#   'ао': 430,
#   'ба': 1722,
#   'ре': 3147,
#   'ні': 5016,
#   'му': 2910,
#   'че': 1583,
#   'зп': 480,
#   'ле': 2318,
#   'чк': 206,
#   'нч': 234,
#   'из': 1550,
#   'ча': 1909,
#   'йн': 1153,
#   'ту': 1688,
#   'ют': 523,
#   'яв': 1561,
#   'ич': 1148,
#   'пр': 5305,
#   'оп': 2390,
#   'ід': 4778,
#   'йс': 841,
#   'жі': 237,
#   'пя': 199,
#   'ть': 3552,
#   'ло': 3342,
#   'дш': 77,
#   'аз': 2797,
#   'ьо': 1725,
#   'ря': 474,
#   'дн': 1964,
#   'аа': 314,
#   'кр': 1134,
#   'яг': 374,
#   'ду': 2262,
#   'же': 2521,
#   'ев': 2676,
#   'дл': 557,
#   'об': 4788,
#   'чч': 138,
#   'ям': 682,
#   'за': 4241,
#   'хл': 260,
#   'чи': 2892,
#   'вс': 3044,
#   'иі': 796,
#   'се': 1811,
#   'бі': 1493,
#   'бл': 885,
#   'ію': 266,
#   'кн': 535,
#   'иж': 300,
#   'еч': 710,
#   'пс': 45,
#   'ал': 5188,
#   'мз': 373,
#   'хи': 364,
#   'дд': 263,
#   'ут': 2354,
#   'ьд': 423,
#   'ця': 670,
#   'кд': 135,
#   'дц': 297,
#   'вч': 656,
#   'ин': 4287,
#   'вд': 1032,
#   'сі': 1649,
#   'сл': 1023,
#   'ух': 391,
#   'да': 2868,
#   'яб': 309,
#   'жа': 767,
#   'яй': 155,
#   'ми': 2022,
#   'сп': 1730,
#   'ає': 1127,
#   'иє': 122,
#   'мн': 1164,
#   'уз': 711,
#   'гу': 533,
#   'ву': 1107,
#   'цю': 312,
#   'ою': 1497,
#   'йш': 378,
#   'дп': 605,
#   'мк': 424,
#   'ом': 5388,
#   'ін': 5633,
#   'ша': 303,
#   'бн': 394,
#   'оу': 196,
#   'юр': 220,
#   'вр': 440,
#   'із': 1556,
#   'бо': 1438,
#   'мв': 446,
#   'аї': 179,
#   'іб': 970,
#   'рв': 306,
#   'юч': 784,
#   'ув': 3872,
#   'ль': 2162,
#   'ці': 1472,
#   'чн': 640,
#   'ум': 1862,
#   'ас': 3531,
#   'яп': 644,
#   'йд': 2247,
#   'уж': 1148,
#   'іл': 3135,
#   'зу': 1208,
#   'рі': 2573,
#   'вм': 373,
#   'аш': 523,
#   'юд': 563,
#   'бв': 246,
#   'он': 5497,
#   'сн': 834,
#   'иї': 671,
#   'їд': 276,
#   'шо': 570,
#   'вш': 498,
#   'уд': 2047,
#   'еш': 363,
#   'хї': 10,
#   'мп': 556,
#   'іш': 1127,
#   'зь': 178,
#   'йп': 482,
#   'хі': 472,
#   'дм': 213,
#   'іж': 395,
#   'дв': 898,
#   'яд': 937,
#   'йч': 231,
#   'жо': 168,
#   'кж': 29,
#   'тя': 641,
#   'чо': 1063,
#   'кп': 222,
#   'рг': 269,
#   'лю': 989,
#   'аж': 1048,
#   'ил': 2216,
#   'пю': 5,
#   'ір': 1167,
#   'иг': 635,
#   'уп': 1075,
#   'са': 1056,
#   'лм': 31,
#   'уч': 617,
#   'оа': 279,
#   'йх': 132,
#   'пч': 81,
#   'мм': 133,
#   'ск': 1275,
#   'ць': 715,
#   'кц': 75,
#   'еб': 1831,
#   'вн': 1756,
#   'тю': 314,
#   'іп': 1604,
#   'си': 1009,
#   'ур': 876,
#   'ьт': 359,
#   'єв': 149,
#   'лу': 668,
#   'ха': 791,
#   'єм': 328,
#   'ох': 836,
#   'гі': 491,
#   'ож': 1810,
#   'хт': 459,
#   'єд': 90,
#   'сг': 78,
#   'ае': 42,
#   'ах': 982,
#   'зо': 614,
#   'ім': 1875,
#   'ої': 1420,
#   'ья': 190,
#   'шб': 8,
#   'йо': 2354,
#   'уо': 238,
#   'рт': 1449,
#   'ес': 1999,
#   'аю': 899,
#   'ая': 592,
#   'йб': 383,
#   'ьз': 359,
#   'хр': 117,
#   'їт': 161,
#   'мл': 152,
#   'хп': 211,
#   'йі': 311,
#   'уі': 532,
#   'пу': 289,
#   'еу': 147,
#   'ню': 204,
#   'її': 954,
#   'ял': 340,
#   'ящ': 298,
#   'єї': 247,
#   'шу': 373,
#   'їя': 45,
#   'кб': 246,
#   'яо': 167,
#   'ип': 1712,
#   'ец': 499,
#   'іа': 363,
#   'зі': 634,
#   'бр': 751,
#   'жу': 563,
#   'мя': 399,
#   'бк': 45,
#   'ьн': 1045,
#   'ке': 447,
#   'зс': 350,
#   'мб': 202,
#   'нш': 456,
#   'зя': 299,
#   'жц': 30,
#   'пк': 25,
#   'иа': 407,
#   'бе': 2131,
#   'зл': 333,
#   'жи': 751,
#   'пд': 5,
#   'ци': 221,
#   'нт': 591,
#   'ац': 521,
#   'яі': 429,
#   'чу': 862,
#   'тт': 415,
#   'їп': 271,
#   'ой': 598,
#   'їб': 100,
#   'іі': 552,
#   'ук': 910,
#   'св': 1201,
#   'ус': 1777,
#   'іє': 430,
#   'їг': 88,
#   'йр': 182,
#   'ия': 595,
#   'кщ': 421,
#   'іх': 587,
#   'ьш': 349,
#   'кл': 2223,
#   'иб': 872,
#   'оя': 930,
#   'бт': 89,
#   'ьх': 66,
#   'вщ': 407,
#   'вт': 906,
#   'вз': 538,
#   'ги': 238,
#   'йа': 128,
#   'іц': 351,
#   'юш': 25,
#   'юі': 259,
#   'сс': 203,
#   'нз': 609,
#   'шс': 32,
#   'еж': 687,
#   'уц': 187,
#   'зр': 746,
#   'ощ': 455,
#   'мс': 468,
#   'жд': 334,
#   'вж': 643,
#   'ех': 430,
#   'лк': 170,
#   'жн': 884,
#   'аб': 1685,
#   'ио': 326,
#   'дч': 363,
#   'уш': 340,
#   'юн': 311,
#   'дт': 366,
#   'бс': 110,
#   'яр': 205,
#   'їв': 289,
#   'еа': 219,
#   'кг': 46,
#   'яч': 316,
#   'їх': 626,
#   'їл': 62,
#   'рб': 132,
#   'сц': 220,
#   'ях': 225,
#   'іг': 916,
#   'мч': 176,
#   'ії': 334,
#   'зв': 1240,
#   'юо': 68,
#   'кв': 494,
#   'гр': 960,
#   'ош': 455,
#   'сх': 274,
#   'оо': 466,
#   'гн': 312,
#   'вл': 676,
#   'хв': 550,
#   'нв': 348,
#   'вв': 632,
#   'їн': 201,
#   'мю': 64,
#   'ач': 1320,
#   'зг': 346,
#   'мг': 63,
#   'дб': 234,
#   'ея': 476,
#   'км': 191,
#   'ші': 307,
#   'вї': 239,
#   'мж': 30,
#   'хо': 1735,
#   'ьв': 440,
#   'іщ': 413,
#   'уу': 35,
#   'ьі': 321,
#   'еі': 340,
#   'зщ': 7,
#   'кй': 41,
#   'зй': 37,
#   'ещ': 544,
#   'вх': 110,
#   'су': 1026,
#   'мр': 303,
#   'іф': 425,
#   'дх': 81,
#   'іо': 439,
#   'нд': 676,
#   'уа': 305,
#   'ащ': 628,
#   'єх': 18,
#   'уя': 325,
#   'хщ': 49,
#   'іч': 795,
#   'дс': 371,
#   'йм': 370,
#   'єю': 152,
#   'шт': 374,
#   'мц': 82,
#   'ху': 214,
#   'зк': 353,
#   'гч': 4,
#   'ьп': 478,
#   'иш': 450,
#   'ую': 246,
#   'оі': 643,
#   'ун': 910,
#   'оц': 599,
#   'тз': 100,
#   'ьщ': 171,
#   'ег': 614,
#   'ьм': 272,
#   'еї': 404,
#   'тв': 618,
#   'оє': 327,
#   'ьу': 282,
#   'хс': 163,
#   'щи': 125,
#   'шн': 315,
#   'жт': 61,
#   'юп': 316,
#   'жк': 202,
#   'шп': 44,
#   'хд': 163,
#   'їз': 300,
#   'вб': 398,
#   'ищ': 865,
#   'їч': 58,
#   'чц': 16,
#   'сб': 65,
#   'йу': 150,
#   'зи': 274,
#   'їс': 230,
#   'чт': 34,
#   'юс': 292,
#   'кс': 364,
#   'юй': 57,
#   'йк': 298,
#   'нг': 73,
#   'хю': 15,
#   'дж': 704,
#   'нц': 397,
#   'фі': 448,
#   'тс': 426,
#   'юя': 108,
#   'рк': 350,
#   'юм': 170,
#   'пл': 612,
#   'дг': 89,
#   'мщ': 117,
#   'гп': 62,
#   'ьй': 133,
#   'жб': 141,
#   'гб': 159,
#   'хз': 139,
#   'мї': 64,
#   'їм': 262,
#   'жз': 72,
#   'ау': 210,
#   'вг': 313,
#   'ьл': 70,
#   'кз': 211,
#   'юб': 308,
#   'ує': 236,
#   'хн': 363,
#   'шл': 303,
#   'иу': 169,
#   'юз': 156,
#   'рх': 92,
#   'вя': 491,
#   'гє': 1,
#   'жч': 114,
#   'яя': 251,
#   'тл': 179,
#   'єй': 45,
#   'яц': 208,
#   'жя': 45,
#   'яї': 119,
#   'мд': 241,
#   'шв': 174,
#   'бй': 24,
#   'бб': 30,
#   'ущ': 282,
#   'хм': 177,
#   'ьї': 75,
#   'їж': 97,
#   'нб': 234,
#   'нє': 74,
#   'оф': 102,
#   'мє': 16,
#   'шк': 251,
#   'їр': 92,
#   'ое': 20,
#   'юю': 84,
#   'кє': 2,
#   'ие': 18,
#   'пт': 142,
#   'цт': 32,
#   'їю': 3,
#   'лщ': 8,
#   'рц': 128,
#   'ьц': 167,
#   'ьф': 23,
#   'тб': 58,
#   'аф': 165,
#   'нщ': 52,
#   'йя': 106,
#   'єя': 38,
#   'тч': 43,
#   'ср': 24,
#   'юк': 130,
#   'фу': 53,
#   'яа': 169,
#   'рч': 47,
#   'зз': 111,
#   'сщ': 20,
#   'дю': 20,
#   'хк': 120,
#   'щі': 78,
#   'вк': 644,
#   'бж': 9,
#   'рм': 207,
#   'уе': 19,
#   'їй': 430,
#   'цн': 39,
#   'зч': 68,
#   'їа': 76,
#   'яс': 598,
#   'яу': 71,
#   'юл': 63,
#   'рз': 177,
#   'єч': 23,
#   'ює': 62,
#   'хб': 93,
#   'нй': 15,
#   'ьа': 135,
#   'єз': 73,
#   'шз': 41,
#   'ьг': 78,
#   'нм': 193,
#   'ею': 296,
#   'хг': 60,
#   'сю': 137,
#   'зт': 234,
#   'зц': 129,
#   'хя': 52,
#   'гт': 149,
#   'нх': 49,
#   'вц': 325,
#   'чщ': 6,
#   'мф': 16,
#   'фр': 81,
#   'мй': 36,
#   'бм': 88,
#   'сф': 29,
#   'ьр': 117,
#   'гм': 10,
#   'ща': 259,
#   'гк': 108,
#   'яш': 30,
#   'дї': 57,
#   'ьб': 160,
#   'ию': 17,
#   'рю': 100,
#   'бх': 46,
#   'рж': 88,
#   'юа': 157,
#   'хч': 41,
#   'єщ': 65,
#   'чл': 85,
#   'єп': 112,
#   'уї': 73,
#   'бш': 9,
#   'тш': 10,
#   'юе': 57,
#   'жв': 166,
#   'кш': 86,
#   'чя': 142,
#   'шч': 10,
#   'цм': 2,
#   'жї': 9,
#   'яж': 155,
#   'їо': 102,
#   'гї': 3,
#   'іу': 122,
#   'пн': 131,
#   'єб': 33,
#   'кк': 73,
#   'иф': 56,
#   'хф': 12,
#   'бз': 54,
#   'хж': 18,
#   'їе': 6,
#   'єн': 131,
#   'ьч': 136,
#   'ца': 20,
#   'їц': 28,
#   'ющ': 103,
#   'йї': 26,
#   'мш': 54,
#   'сї': 11,
#   'кх': 33,
#   'ее': 15,
#   'тц': 31,
#   'тж': 101,
#   'яе': 10,
#   'кя': 133,
#   'йе': 14,
#   'гд': 28,
#   'жм': 49,
#   'хц': 35,
#   'жр': 19,
#   'фо': 184,
#   'рл': 135,
#   'гс': 39,
#   'хх': 52,
#   'уф': 64,
#   'кї': 34,
#   'гз': 37,
#   'яє': 67,
#   'сз': 73,
#   'йщ': 104,
#   'жщ': 10,
#   'гй': 4,
#   'зї': 71,
#   'рй': 61,
#   'нл': 62,
#   'єр': 44,
#   'бд': 65,
#   'жп': 95,
#   'шд': 13,
#   'сє': 7,
#   'чю': 11,
#   'шш': 7,
#   'зш': 41,
#   'зх': 32,
#   'бю': 20,
#   'юї': 28,
#   'єц': 19,
#   'сч': 14,
#   'рь': 28,
#   'зж': 29,
#   'чв': 71,
#   'вю': 6,
#   'еф': 206,
#   'фт': 14,
#   'тм': 62,
#   'мх': 70,
#   'лл': 263,
#   'бц': 17,
#   'їу': 42,
#   'лт': 32,
#   'юц': 48,
#   'бє': 13,
#   'нр': 103,
#   'їк': 98,
#   'нж': 23,
#   'йф': 26,
#   'пц': 32,
#   'рр': 63,
#   'жх': 13,
#   'єс': 89,
#   'гв': 44,
#   'сд': 64,
#   'йю': 21,
#   'фф': 7,
#   'чс': 24,
#   'хе': 133,
#   'рщ': 25,
#   'їш': 7,
#   'вй': 167,
#   'вф': 20,
#   'фк': 5,
#   'чб': 50,
#   'зю': 9,
#   'іе': 29,
#   'хй': 11,
#   'тх': 32,
#   'тщ': 56,
#   'тд': 92,
#   'єл': 13,
#   'тп': 107,
#   'бя': 57,
#   'жж': 15,
#   'бп': 122,
#   'пш': 7,
#   'ью': 61,
#   'шю': 2,
#   'єж': 25,
#   'чх': 4,
#   'шж': 3,
#   'єш': 91,
#   'жс': 44,
#   'еє': 27,
#   'шм': 38,
#   'єі': 52,
#   'лб': 156,
#   'щу': 25,
#   'дщ': 38,
#   'тє': 18,
#   'гщ': 6,
#   'гш': 28,
#   'єк': 39,
#   'лд': 139,
#   'єо': 20,
#   'тї': 7,
#   'єа': 28,
#   'фс': 133,
#   'рф': 11,
#   'лн': 145,
#   'юу': 36,
#   'лп': 30,
#   'лв': 21,
#   'лз': 12,
#   'яю': 96,
#   'ьє': 6,
#   'сж': 6,
#   'чї': 5,
#   'ьж': 25,
#   'жй': 10,
#   'чп': 19,
#   'фл': 18,
#   'жг': 17,
#   'пг': 4,
#   'тг': 27,
#   'їщ': 34,
#   'бг': 21,
#   'кф': 12,
#   'їє': 4,
#   'тф': 17,
#   'цв': 4,
#   'бч': 7,
#   'пє': 1,
#   'гц': 8,
#   'шр': 14,
#   'нї': 20,
#   'дй': 19,
#   'чй': 6,
#   'фн': 1,
#   'йє': 4,
#   'чд': 10,
#   'хш': 11,
#   'фг': 1,
#   'чг': 9,
#   'шц': 7,
#   'лг': 39,
#   'бї': 21,
#   'йй': 25,
#   'гх': 9,
#   'жф': 5,
#   'чм': 11,
#   'жє': 3,
#   'пп': 14,
#   'пв': 12,
#   'цу': 10,
#   'цк': 1,
#   'фд': 3,
#   'юж': 29,
#   'фи': 14,
#   'яф': 11,
#   'лх': 10,
#   'дф': 3,
#   'зф': 16,
#   'гг': 6,
#   'шй': 4,
#   'тй': 14,
#   'зє': 6,
#   'єе': 3,
#   'єф': 1,
#   'шщ': 9,
#   'єу': 4,
#   'сй': 12,
#   'еи': 1,
#   'пщ': 3,
#   'юф': 10,
#   'вє': 3,
#   'сш': 6,
#   'рє': 9,
#   'чз': 18,
#   'бф': 1,
#   'фв': 2,
#   'єг': 17,
#   'чр': 5,
#   'лц': 20,
#   'гя': 10,
#   'цр': 2,
#   'їф': 5,
#   'пф': 1,
#   'цщ': 2,
#   'лф': 7,
#   'лє': 1,
#   'бщ': 5,
#   'лї': 2,
#   'лй': 2,
#   'рї': 8,
#   'лр': 3,
#   'цд': 2,
#   'шї': 3,
#   'фп': 2,
#   'ье': 4,
#   'фм': 1,
#   'шг': 3,
#   'лч': 2,
#   'цч': 1,
#   'лш': 1,
#   'цс': 3,
#   'шф': 1,
#   'хє': 3,
#   'фб': 1,
#   'цо': 1,
#   'нф': 8,
#   'цб': 2,
#   'жш': 2,
#   'пм': 2,
#   'жю': 1,
#   'пб': 4,
#   'пз': 8,
#   'пй': 2,
#   'пї': 1,
#   'гю': 2,
#   'пх': 2,
#   'лж': 1,
#   'фя': 1,
#   'шх': 1,
#   'чф': 1},
#  708475)

# %%
def find_index(bigram):
    return ukr_clean_alphabet.find(bigram[0]) * len(ukr_clean_alphabet) + ukr_clean_alphabet.find(bigram[1])

# %%
find_index('до')
# Out:
# 145

# %%
def bigram(index):
    return ''.join([ukr_clean_alphabet[index // 32], ukr_clean_alphabet[index % 32]])

# %%
bigram(145)
# Out:
# 'до'

# %%
def conc(it, n):
    return zip(*([iter(it)] * n))

# %%
def text_coding_by_bigram(text):
    encode_text = []
    
    for bigram in conc(text, 2):
        encode_text.append(find_index(bigram))
    
    return encode_text

# %%
text_coding_by_bigram('арполдун')
# Out:
# [19, 593, 452, 720]

# %%
def text_decoding_by_bigram(text):
    decoding_text = ''
    
    for i in text:
        decoding_text += bigram(i)
    
    return decoding_text

# %%
text_decoding_by_bigram([12, 34, 456, 23])
# Out:
# 'айбвлзаф'

# %% [markdown]
# **4. Генерирование текстов**

# %%
def generate_text_samples(text, L, N):
    X = []
    end_of_random_number = len(text) - L - 1
    
    for i in range(N):
        pos_l = []
        position = np.random.randint(end_of_random_number)
        pos_l.append(position)
        pos_l.append(position + L)
        X.append(pos_l)
    
    text_list = []
    for i in range(len(X)):
        text_list.append(text[X[i][0]:X[i][1]])
    
    return text_list

# %%
texts_10_10000 = []
texts_10_10000  = generate_text_samples(TEXT, 10, 10000)
print(texts_10_10000)
# Out:
# ['думкахніув', 'иуспіхітом', 'упертомовч', 'йнойомуваж', 'йнихіморал', 'евистачаєс', 'тохочаброз', 'ькароберта', 'звонивмужч', 'обернувшис', 'имсобоювну', 'щонеможепо', 'давсявбухт', 'итижнівіна', 'ьоднадумка', 'вкупевнени', 'одалекопоб', 'тензієюкла', 'рноособлив', 'аасамавона', 'тіостогидл', 'щомуситьне', 'ькарозмовт', 'анезважаюч', 'аскавоутіш', 'андаломбул', 'шукатимуть', 'вдорозівін', 'іколинемог', 'орогоювтак', 'авітьзараз', 'вариствімі', 'ибоколикла', 'судрозясни', 'тімвечеряб', 'лоівусіхїї', 'оньоговінз', 'атавлистіз', 'підмашинку', 'узадіронда', 'ючинадіюде', 'тімкинутів', 'урбуватися', 'айдтремтяч', 'увгарнийзс', 'яписатимат', 'васминулог', 'неївбільці', 'дадоведеть', 'лаповесели', 'уштрувалип', 'каїйнадтоп', 'емомпомірк', 'себекажете', 'ньоївечірк', 'оюгріфітсі', 'обезглузді', 'оінемігупі', 'неноготочи', 'сяавінстав', 'етакгаразд', 'ицтвомкомі', 'сноалездру', 'врукууводу', 'чаємодягне', 'ікавістюпр', 'лькипослух', 'ноюсумоюал', 'аможетутіщ', 'ивонинареш', 'нацюсценку', 'юдейнавіть', 'ахопленнян', 'ягтивпості', 'черукуілів', 'цьогодняна', 'ьогочасуал', 'адумкупроз', 'мпереконує', 'ортуякимио', 'озізнатись', 'іщозбилицю', 'алидотелеф', 'ценедопомо', 'небацейділ', 'илищотакне', 'уміюсказат', 'озуміювасв', 'нилойогойо', 'надцятомуо', 'ніозеракла', 'нзіяволіла', 'чаткузаваг', 'тоттількит', 'люднимиліс', 'йогозахопл', 'мякшуючоюм', 'планивсеще', 'жнадобрати', 'ередньосто', 'вякійпотім', 'йомунещаст', 'ннядамідів', 'уватицядів', 'орушнеклай', 'багатозамо', 'інедовіряя', 'тасамажвав', 'іріоштукат', 'стілецьзкі', 'увинагород', 'медопомоги', 'ирствоівик', 'дошколитан', 'енеалебелн', 'опомогийпо', 'питатикрен', 'онапростяг', 'ізавмерлаї', 'міневсегар', 'омубулонак', 'дочогонепр', 'горазуащоя', 'няявляласо', 'мілинатойч', 'йдаподумат', 'остюматежн', 'ідайтемені', 'іншихтайсп', 'ібнобудена', 'заявоюхазя', 'метуватисе', 'поговорити', 'ханийводну', 'якгадаєслі', 'діжінкийді', 'південнуча', 'йсонстаєтр', 'иттябудемо', 'ричинуйого', 'жутьнавіть', 'ящепотанцю', 'нцьогонеро', 'аймнідехто', 'воробливук', 'айдаякогоп', 'піднятоажд', 'ьтерськоюг', 'итьнайогок', 'сяпісляваш', 'дивсяодруж', 'овційсутоз', 'івнетещоун', 'резмістган', 'рамваємвон', 'ствуютькол', 'менамиіпот', 'вилахщоїйр', 'екидається', 'аколимиїзд', 'няєшазаним', 'кнатейлорс', 'атнийнатак', 'тиснутийом', 'изрозуміли', 'улижалібні', 'пливтипятс', 'імясподіва', 'оквідповіс', 'всежкохаєт', 'тиввінсхов', 'еозеровінв', 'ивзовсімне', 'гавсязасві', 'арталіводи', 'еприпинити', 'асобівонан', 'хстраждань', 'кщожиливдо', 'лухативінв', 'унизбіляро', 'іїнапоряту', 'неїбулобіл', 'робулавнеї', 'ікамеривід', 'іджбурзьки', 'взнеюнічву', 'нсказаввін', 'анеюслідом', 'мспособомв', 'хівсежтаки', 'ибувздатни', 'ьмутьраніш', 'чипятницін', 'кбинемаман', 'ууворожому', 'рентпочали', 'цеклайдназ', 'обитисьїїр', 'расаігорді', 'куперенест', 'женнязглад', 'идвідівчат', 'никасередп', 'ївсецеразо', 'ібертінапр', 'овязковопо', 'ахоміболем', 'наводуаско', 'гріфітсомя', 'іпригодилю', 'адзвичайни', 'нийзлочина', 'огостарика', 'робивповто', 'ілагіднезя', 'цюхвилинув', 'наголовівн', 'індевідсон', 'кувонапрок', 'ахворавінз', 'могтийомун', 'шітаклегко', 'оселісмерт', 'йсправіпер', 'овінзастиг', 'завтраабов', 'ньіввечері', 'ившисьзйог', 'нпочуввигу', 'ветілонале', 'капудричиф', 'докінцяїїд', 'щосьробити', 'сядотогомо', 'писалицена', 'нопідетеза', 'цькогочине', 'давалосязб', 'йогомаютьо', 'осявінвідч', 'розглядавї', 'думатипрон', 'ийшлависок', 'ихороберта', 'джетінезва', 'утьйогопри', 'сланнядога', 'івінкупивн', 'кежзапитан', 'сіхсилнама', 'някзвичайн', 'нувпобіжни', 'стрічаєтьс', 'зкитакесув', 'оєбогякийз', 'мовимшляхо', 'газетіпроп', 'язагибельс', 'тещосталос', 'мівчергови', 'ставшисьіп', 'лухаючикла', 'ломайжебез', 'інаіншіозе', 'юбитиїїякр', 'іщонебудьг', 'тоявшвейца', 'нихстравув', 'риблизнодо', 'недужеприх', 'адодатокяк', 'гортензіїт', 'одругамице', 'лакавійого', 'забувспита', 'єйоговробе', 'цемдляпере', 'івчинизнай', 'казавробер', 'ищовонаодр', 'неробивспр', 'улобпідшук', 'авалосьбез', 'вщоябувтам', 'орушнийа ...

# %%
texts_100_10000 = []
texts_100_10000  = generate_text_samples(TEXT, 100, 10000)

# %%
texts_1000_10000 = []
texts_1000_10000 = generate_text_samples(TEXT, 1000, 10000)

# %%
texts_10000_1000 = []
texts_10000_1000  = generate_text_samples(TEXT, 10000, 1000)

# %% [markdown]
# **5. Изменение текста**

# %% [markdown]
# 1) l = 1 (функции для монограмм)

# %% [markdown]
# - VIGENERE_encryption_letter (r = 1, 5, 10) +
# - Afine_encryption_letter +
# - uniform_letter +
# - s_letter +

# %%
def mod(x, y, z):
    return (x + y) % z

def random_key(length):
    letters = 'абвгдеєжзиіїйклмнопрстуфхцчшщьюя'
    rand_string = ''.join(random.choice(letters) for i in range(length))
    
    return rand_string

def key_initialization():
    temp = []
    
    k1 = random_key(1)
    k5 = random_key(5)
    k10 = random_key(10)
    
    temp.append(text_to_array_of_num(k1))
    temp.append(text_to_array_of_num(k5))
    temp.append(text_to_array_of_num(k10))
                
    return temp

# %%
key_initialization()
# Out:
# [[9], [11, 20, 24, 11, 6], [21, 19, 4, 1, 9, 2, 20, 24, 6, 13]]

# %%
def VIGENERE_encryption_letter(text, key):
    text = text_to_array_of_num(text)
    cipher = []
    
    for i in range(len(text)):
        cipher.append(mod(text[i], key[i % len(key)], 32))
    
    return array_of_numbers_to_text(cipher)

# %%
VIGENERE_encryption_letter(texts_100_10000[0], key_initialization()[0])
# Out:
# 'кужзаькьлбдеяжбпєялкємлзбрпчьяплюролйблюжаюжпвнкрьояжифвйлбькяжкяжечйвеолюлшяжкмнлоплоіьдвілйрквюрбч'

# %%
def Afine_letter(text):
    encrypt_text = []
    a = np.random.randint(32)
    b = np.random.randint(32)
    
    new_text = text_to_array_of_num(text)
    
    for i in new_text:
        encrypt_text.append(mod(a * i, b, 32))
   
    return array_of_numbers_to_text(encrypt_text)

# %%
Afine_letter('апрлвлг')
# Out:
# 'ахсзхзс'

# %%
def uniform_letter(L):
    list_of_rand = []
    for i in range(L):
        list_of_rand.append(np.random.randint(32))
    
    return array_of_numbers_to_text(list_of_rand)

# %%
uniform_letter(100)
# Out:
# 'ьрубтсещхуіффахнньтиаіфрмюеурїїнчжчиившьіивжвоумюяикгбикптощмяййьянечтцлкиечлєфеоміофуьжнвеьвілифйдї'

# %%
def s_letter(L):
    m = 32
    s0 = np.random.randint(32)
    s1 = np.random.randint(32)
    
    Y = [s0, s1] + [0] * (L - 2)
    
    for i in range(2, L):
        Y[i] = (Y[i-1] + Y[i-2]) % m 
    
    return array_of_numbers_to_text(Y)

# %%
s_letter(10)
# Out:
# 'аїїубфхмжу'

# %% [markdown]
# 2) l = 2 (функции для биграмм)

# %% [markdown]
# - VIGENERE_encryption_bigram (r = 1, 5, 10)
# - Afine_bigram +
# - uniform_bigram +
# - s_bigram

# %%
def Afine_bigram(text):
    
    l = []
    
    a = np.random.randint(1024)
    b = np.random.randint(1024)
    
    encrypt_text = text_coding_by_bigram(text)
    
    for i in encrypt_text:
        l.append((a * i + b) % 1024)
    
    return text_decoding_by_bigram(l)

# %%
Afine_bigram('аолдукштив')
# Out:
# 'югетцїзшги'

# %%
def uniform_bigram(L):
    l = []
    
    for i in range(L // 2):
        l.append(np.random.randint(1024))
    
    return text_decoding_by_bigram(l)

# %%
uniform_bigram(10)
# Out:
# 'зсьїпляянж'

# %%
def s_bigram(L):
    m = 1024
    
    s0 = np.random.randint(1024)
    s1 = np.random.randint(1024)
    
    Y = [s0, s1] + [0] * (L // 2 - 2)
    
    for i in range(2, L // 2):
        Y[i] = (Y[i-1] + Y[i-2]) % m 
    
    return text_decoding_by_bigram(Y)

# %%
s_bigram(10)
# Out:
# 'длахеєеюїд'

# %% [markdown]
# **6. Реализация критериев (частые l-граммы)**

# %% [markdown]
# 1) l = 1

# %% [markdown]
# - criterion_20:
# > 1. criterion_20_vigenere_r1_letter +
# > 2. criterion_20_vigenere_r5_letter +
# > 3. criterion_20_vigenere_r10_letter +
# > 4. criterion_20_afine_letter +
# > 5. criterion_20_uniform_letter +
# > 6. criterion_20_s_letter +
#
# - criterion_21:
# > 1. criterion_21_vigenere_r1_letter +
# > 2. criterion_21_vigenere_r5_letter +
# > 3. criterion_21_vigenere_r10_letter +
# > 4. criterion_21_afine_letter +
# > 5. criterion_21_uniform_letter +
# > 6. criterion_21_s_letter +
#
# - criterion_22:
# > 1. criterion_22_vigenere_r1_letter +
# > 2. criterion_22_vigenere_r5_letter +
# > 3. criterion_22_vigenere_r10_letter +
# > 4. criterion_22_afine_letter +
# > 5. criterion_22_uniform_letter +
# > 6. criterion_22_s_letter +
#
# - criterion_23:
# > 1. criterion_23_vigenere_r1_letter +
# > 2. criterion_23_vigenere_r5_letter +
# > 3. criterion_23_vigenere_r10_letter +
# > 4. criterion_23_afine_letter +
# > 5. criterion_23_uniform_letter +
# > 6. criterion_23_s_letter +
#
# - criterion_conformity
# > 1. criterion_conformity_vigenere_r1_letter +
# > 2. criterion_conformity_vigenere_r5_letter +
# > 3. criterion_conformity_vigenere_r10_letter +
# > 4. criterion_conformity_afine_letter +
# > 5. criterion_conformity_uniform_letter +
# > 6. criterion_conformity_s_letter +
#
# - criterion_50
# > 1. criterion_50_vigenere_r1_letter +
# > 2. criterion_50_vigenere_r5_letter +
# > 3. criterion_50_vigenere_r10_letter +
# > 4. criterion_50_afine_letter +
# > 5. criterion_50_uniform_letter +
# > 6. criterion_50_s_letter +
#
#
# - criterion_structural
# > 1. criterion_structural_vigenere_r1_letter +
# > 2. criterion_structural_vigenere_r5_letter +
# > 3. criterion_structural_vigenere_r10_letter +
# > 4. criterion_structural_afine_letter +
# > 5. criterion_structural_uniform_letter +
# > 6. criterion_structural_s_letter +

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %%
A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']

# %% [markdown]
# criterion_20(1)

# %%
def criterion_20_vigenere_r1_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r1_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0013)

# %%
criterion_20_vigenere_r1_letter(texts_100_10000, 15)
# Out:
# (0.9422, 0.8131)

# %%
criterion_20_vigenere_r1_letter(texts_1000_10000, 12)
# Out:
# (0.1323, 1.0)

# %%
criterion_20_vigenere_r1_letter(texts_10000_1000, 11)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_20(2)

# %%
def criterion_20_vigenere_r5_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r5_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0013)

# %%
criterion_20_vigenere_r5_letter(texts_100_10000, 7)
# Out:
# (0.4045, 0.9852)

# %%
criterion_20_vigenere_r5_letter(texts_1000_10000, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r5_letter(texts_10000_1000, 11)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_20(3)

# %%
def criterion_20_vigenere_r10_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r10_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0013)

# %%
criterion_20_vigenere_r10_letter(texts_100_10000, 16)
# Out:
# (0.601, 0.7709)

# %%
criterion_20_vigenere_r10_letter(texts_1000_10000, 20)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r10_letter(texts_10000_1000, 30)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_20(4)

# %%
def criterion_20_afine_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_afine_letter(texts_10_10000, 6)
# Out:
# (1.0, 0.0077)

# %%
criterion_20_afine_letter(texts_100_10000, 9)
# Out:
# (0.9352, 0.9684)

# %%
criterion_20_afine_letter(texts_1000_10000, 25)
# Out:
# (0.6366, 0.999)

# %%
criterion_20_afine_letter(texts_10000_1000, 25)
# Out:
# (0.479, 1.0)

# %% [markdown]
# criterion_20(5)

# %%
def criterion_20_uniform_letter(open_texts, A_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_uniform_letter(texts_10_10000, 6, 10)
# Out:
# (0.9998, 0.0077)

# %%
criterion_20_uniform_letter(texts_100_10000, 9, 100)
# Out:
# (0.3236, 0.9684)

# %%
criterion_20_uniform_letter(texts_1000_10000, 9, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_20_uniform_letter(texts_10000_1000, 9, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_20(6)

# %%
def criterion_20_s_letter(open_texts, A_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in range(len(text_corrupt)):
        tmp = list(text_corrupt[i][0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_s_letter(texts_10_10000, 6, 10)
# Out:
# (1.0, 0.0077)

# %%
criterion_20_s_letter(texts_100_10000, 9, 100)
# Out:
# (1.0, 0.9684)

# %%
criterion_20_s_letter(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 1.0)

# %%
criterion_20_s_letter(texts_10000_1000, 25, 10000)
# Out:
# (1.0, 1.0)

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# criterion_21(1)

# %%
def criterion_21_vigenere_r1_letter(open_texts, A_frq_size, kf):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r1_letter(texts_10_10000, 7, 2)
# Out:
# (0.2492, 0.1643)

# %%
criterion_21_vigenere_r1_letter(texts_100_10000, 7, 2)
# Out:
# (0.9983, 0.0)

# %%
criterion_21_vigenere_r1_letter(texts_1000_10000, 7, 2)
# Out:
# (1.0, 0.0)

# %%
criterion_21_vigenere_r1_letter(texts_10000_1000, 7, 2)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_21(2)

# %%
def criterion_21_vigenere_r5_letter(open_texts, A_frq_size, kf):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r5_letter(texts_10_10000, 7, 2)
# Out:
# (0.2808, 0.1643)

# %%
criterion_21_vigenere_r5_letter(texts_100_10000, 6, 5)
# Out:
# (0.6495, 0.0057)

# %%
criterion_21_vigenere_r5_letter(texts_1000_10000, 10, 9)
# Out:
# (1.0, 0.0)

# %%
criterion_21_vigenere_r5_letter(texts_10000_1000, 6, 2)
# Out:
# (1.0, 0.0)

# %%
def criterion_21_vigenere_r10_letter(open_texts, A_frq_size, kf):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r10_letter(texts_10_10000, 7, 2)
# Out:
# (0.2851, 0.1643)

# %%
criterion_21_vigenere_r10_letter(texts_100_10000, 9, 8)
# Out:
# (0.6061, 0.0316)

# %%
criterion_21_vigenere_r10_letter(texts_1000_10000, 9, 8)
# Out:
# (1.0, 0.0)

# %%
criterion_21_vigenere_r10_letter(texts_10000_1000, 9, 8)
# Out:
# (1.0, 0.0)

# %%
def criterion_21_afine_letter(open_texts, A_frq_size, kf):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_afine_letter(texts_10_10000, 7, 2)
# Out:
# (0.177, 0.1643)

# %%
criterion_21_afine_letter(texts_100_10000, 7, 2)
# Out:
# (0.7639, 0.0)

# %%
criterion_21_afine_letter(texts_1000_10000, 10, 2)
# Out:
# (0.8133, 0.0)

# %%
criterion_21_afine_letter(texts_10000_1000, 10, 2)
# Out:
# (0.814, 0.0)

# %%
def criterion_21_uniform_letter(open_texts, A_frq_size, kf, L):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_uniform_letter(texts_10_10000, 7, 2, 10)
# Out:
# (0.2753, 0.1643)

# %%
criterion_21_uniform_letter(texts_100_10000, 10, 1, 100)
# Out:
# (1.0, 0.0)

# %%
criterion_21_uniform_letter(texts_1000_10000, 7, 2, 1000)
# Out:
# (1.0, 0.0)

# %%
criterion_21_uniform_letter(texts_10000_1000, 10, 5, 10000)
# Out:
# (1.0, 0.0)

# %%
def criterion_21_s_letter(open_texts, A_frq_size, kf, L):
    FP = 0
    FN = 0
    
    A = ['о','а', 'н', 'и', 'в', 'і', 'е', 'т', 'р', 'с', 'д', 'л', 'у', 'к', 'м', 'п', 'з', 'я', 'б', 
         'г', 'й', 'ь', 'ч', 'ж', 'х', 'ю', 'ш','ц', 'щ', 'ї', 'є', 'ф']
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
        
    H1 = 0
    H0 = 0
    
    for i in open_texts:
        tmp = list(i)
        if len(list(set(tmp) & set(A_frq))) <= kf:
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) > kf:
            H1 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_s_letter(texts_10_10000, 7, 2, 10)
# Out:
# (0.261, 0.1643)

# %%
criterion_21_s_letter(texts_100_10000, 7, 2, 100)
# Out:
# (0.8433, 0.0)

# %%
criterion_21_s_letter(texts_1000_10000, 7, 2, 1000)
# Out:
# (0.8451, 0.0)

# %%
criterion_21_s_letter(texts_10000_1000, 10, 2, 10000)
# Out:
# (0.853, 0.0)

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# criterion_22(1)

# %%
def criterion_22_vigenere_r1_letter(open_texts, A_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r1_letter(texts_10_10000, 10, 0.03)
# Out:
# (0.7364, 0.0)

# %%
criterion_22_vigenere_r1_letter(texts_100_10000, 10, 0.037)
# Out:
# (0.6487, 0.0)

# %%
criterion_22_vigenere_r1_letter(texts_1000_10000, 10, 0.04)
# Out:
# (0.6221, 0.0)

# %%
criterion_22_vigenere_r1_letter(texts_10000_1000, 10, 0.04)
# Out:
# (0.667, 0.0)

# %% [markdown]
# criterion_22(2)

# %%
def criterion_22_vigenere_r5_letter(open_texts, A_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r5_letter(texts_10_10000, 10, 0.03)
# Out:
# (0.7597, 0.0)

# %%
criterion_22_vigenere_r5_letter(texts_100_10000, 10, 0.03)
# Out:
# (0.666, 0.0)

# %%
criterion_22_vigenere_r5_letter(texts_1000_10000, 10, 0.03)
# Out:
# (0.6346, 0.0)

# %%
criterion_22_vigenere_r5_letter(texts_10000_1000, 10, 0.03)
# Out:
# (0.633, 0.0)

# %% [markdown]
# criterion_22(3)

# %%
def criterion_22_vigenere_r10_letter(open_texts, A_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r10_letter(texts_10_10000, 10, 0.03)
# Out:
# (0.7578, 0.0)

# %%
criterion_22_vigenere_r10_letter(texts_100_10000, 10, 0.03)
# Out:
# (0.673, 0.0)

# %%
criterion_22_vigenere_r10_letter(texts_1000_10000, 10, 0.03)
# Out:
# (0.6438, 0.0)

# %%
criterion_22_vigenere_r10_letter(texts_1000_10000, 10, 0.03)
# Out:
# (0.6403, 0.0)

# %% [markdown]
# criterion_22(4)

# %%
def criterion_22_afine_letter(open_texts, A_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_afine_letter(texts_10_10000, 9, 0.03)
# Out:
# (0.6809, 0.0)

# %%
criterion_22_afine_letter(texts_100_10000, 9, 0.03)
# Out:
# (0.6056, 0.0)

# %%
criterion_22_afine_letter(texts_1000_10000, 9, 0.03)
# Out:
# (0.5842, 0.0)

# %%
criterion_22_afine_letter(texts_10000_1000, 9, 0.03)
# Out:
# (0.595, 0.0)

# %% [markdown]
# criteriin_22(5)

# %%
def criterion_22_uniform_letter(open_texts, A_frq_size, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_uniform_letter(texts_10_10000, 9, 0.03, 10)
# Out:
# (0.7299, 0.0)

# %%
criterion_22_uniform_letter(texts_100_10000, 9, 0.03, 100)
# Out:
# (0.6368, 0.0)

# %%
criterion_22_uniform_letter(texts_1000_10000, 9, 0.03, 1000)
# Out:
# (0.5827, 0.0)

# %%
criterion_22_uniform_letter(texts_10000_1000, 9, 0.03, 10000)
# Out:
# (0.596, 0.0)

# %%
def criterion_22_s_letter(open_texts, A_frq_size, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] < k:
                H1 += 1
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq and tmp[j][1] >= k:
                H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_s_letter(texts_10_10000, 9, 0.03, 10)
# Out:
# (0.6015, 0.0)

# %%
criterion_22_s_letter(texts_100_10000, 9, 0.03, 100)
# Out:
# (0.4781, 0.0)

# %%
criterion_22_s_letter(texts_1000_10000, 9, 0.03, 1000)
# Out:
# (0.4167, 0.0)

# %%
criterion_22_s_letter(texts_10000_1000, 9, 0.03, 10000)
# Out:
# (0.485, 0.0)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# criterion_23(1)

# %%
def criterion_23_vigenere_r1_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(len(A_frq)):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    #Hf_ot = []
    #Hf_ct = []
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        if s < Kf:
            H1 += 1
        
        #Hf_ot.append(s)
    
    #for i in range(len(open_texts)):
        #if Hf_ot[i] < Kf:
            #H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        if s >= Kf:
            H0 += 1
        
        #Hf_ct.append(s)
    
    #for i in range(len(open_texts)):
        #if Hf_ct[i] >= Kf:
            #H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r1_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r1_letter(texts_100_10000, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r1_letter(texts_1000_10000, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r1_letter(texts_10000_1000, 10)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(2)

# %%
def criterion_23_vigenere_r5_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r5_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r5_letter(texts_100_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r5_letter(texts_1000_10000, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r5_letter(texts_10000_1000, 10)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(3)

# %%
def criterion_23_vigenere_r10_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r10_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r10_letter(texts_100_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r10_letter(texts_1000_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_vigenere_r10_letter(texts_10000_1000, 7)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(4)

# %%
def criterion_23_afine_letter(open_texts, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_afine_letter(texts_10_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_afine_letter(texts_100_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_afine_letter(texts_1000_10000, 7)
# Out:
# (1.0, 0.0)

# %%
criterion_23_afine_letter(texts_10000_1000, 7)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(5)

# %%
def criterion_23_uniform_letter(open_texts, A_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_uniform_letter(texts_10_10000, 10, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_uniform_letter(texts_100_10000, 10, 100)
# Out:
# (1.0, 0.0)

# %%
criterion_23_uniform_letter(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 0.0)

# %%
criterion_23_uniform_letter(texts_10000_1000, 10, 10000)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_23(6)

# %%
def criterion_23_s_letter(open_texts, A_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    Kf = 0
    for i in range(10):
        Kf += dictionary_sorting(letter_counter(TEXT))[i][1]
        
    Hf_ot = []
    Hf_ct = []
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = dictionary_sorting(letter_counter(text_corrupt[i][0]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ot.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ot[i] < Kf:
            H1 += 1
        
    
    for i in range(len(open_texts)):
        tmp = dictionary_sorting(letter_counter(open_texts[i]))
        s = 0
        for j in range(len(tmp[0])):
            if tmp[j][0] in A_frq:
                s += tmp[j][1]
        
        Hf_ct.append(s)
    
    for i in range(len(open_texts)):
        if Hf_ct[i] >= Kf:
            H0 += 1
            
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_s_letter(texts_10_10000, 10, 10)
# Out:
# (1.0, 0.0)

# %%
criterion_23_s_letter(texts_100_10000, 10, 100)
# Out:
# (1.0, 0.0)

# %%
criterion_23_s_letter(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 0.0)

# %%
criterion_23_s_letter(texts_10000_1000, 10, 10000)
# Out:
# (1.0, 0.0)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# criterion_conformity(1)

# %%
def criterion_conformity_vigenere_r1_letter(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r1_letter(texts_10_10000, 0.02)
# Out:
# (0.5682, 0.4318)

# %%
criterion_conformity_vigenere_r1_letter(texts_100_10000, 0.02)
# Out:
# (0.0015, 0.9985)

# %%
criterion_conformity_vigenere_r1_letter(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r1_letter(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_conformity(2)

# %%
def criterion_conformity_vigenere_r5_letter(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r5_letter(texts_10_10000, 0.02)
# Out:
# (0.6487, 0.4318)

# %%
criterion_conformity_vigenere_r5_letter(texts_100_10000, 0.02)
# Out:
# (0.0271, 0.9985)

# %%
criterion_conformity_vigenere_r5_letter(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r5_letter(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_conformity(3)

# %%
def criterion_conformity_vigenere_r10_letter(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r10_letter(texts_10_10000, 0.02)
# Out:
# (0.6628, 0.4318)

# %%
criterion_conformity_vigenere_r10_letter(texts_100_10000, 0.02)
# Out:
# (0.0868, 0.9985)

# %%
criterion_conformity_vigenere_r10_letter(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r10_letter(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_conformity(4)

# %%
def criterion_conformity_afine_letter(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_afine_letter(texts_10_10000, 0.02)
# Out:
# (0.659, 0.4318)

# %%
criterion_conformity_afine_letter(texts_100_10000, 0.02)
# Out:
# (0.4991, 0.9985)

# %%
criterion_conformity_afine_letter(texts_1000_10000, 0.02)
# Out:
# (0.5017, 1.0)

# %% [markdown]
# conformity_index(5)

# %%
def criterion_conformity_uniform_letter(open_texts, k_H, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_uniform_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.6707, 0.4318)

# %%
criterion_conformity_uniform_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.2097, 0.9985)

# %%
criterion_conformity_uniform_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_uniform_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_conformity(6)

# %%
def criterion_conformity_s_letter(open_texts, k_H, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I1 = 0.04928235830845431
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if abs(conformity_index_letter(i[0]) - I1) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_letter(i) - I1) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_s_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.699, 0.4318)

# %%
criterion_conformity_s_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.2511, 0.9985)

# %%
criterion_conformity_s_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.2483, 1.0)

# %%
criterion_conformity_s_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.596, 1.0)

# %% [markdown]
# criterion_50(1)

# %%
def criterion_50_vigenere_r1_letter(open_texts, k_empt):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r1_letter(texts_10_10000, 1)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r1_letter(texts_100_10000, 1)
# Out:
# (0.0004, 1.0)

# %%
criterion_50_vigenere_r1_letter(texts_1000_10000, 1)
# Out:
# (0.6834, 0.3493)

# %%
criterion_50_vigenere_r1_letter(texts_10000_1000, 1)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_50(2)

# %%
def criterion_50_vigenere_r5_letter(open_texts, k_empt):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r5_letter(texts_10_10000, 2)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r5_letter(texts_100_10000, 2)
# Out:
# (0.371, 0.9979)

# %%
criterion_50_vigenere_r5_letter(texts_1000_10000, 2)
# Out:
# (1.0, 0.0194)

# %%
criterion_50_vigenere_r5_letter(texts_10000_1000, 2)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_50(3)

# %%
def criterion_50_vigenere_r10_letter(open_texts, k_empt):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r10_letter(texts_10_10000, 2)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r10_letter(texts_100_10000, 2)
# Out:
# (0.5122, 0.9979)

# %%
criterion_50_vigenere_r10_letter(texts_1000_10000, 2)
# Out:
# (1.0, 0.0194)

# %%
criterion_50_vigenere_r10_letter(texts_10000_1000, 2)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_50(4)

# %%
def criterion_50_afine_letter(open_texts, k_empt):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_afine_letter(texts_10_10000, 2)
# Out:
# (0.0, 1.0)

# %%
criterion_50_afine_letter(texts_100_10000, 2)
# Out:
# (0.0026, 0.9979)

# %%
criterion_50_afine_letter(texts_1000_10000, 2)
# Out:
# (0.4902, 0.0194)

# %%
criterion_50_afine_letter(texts_10000_1000, 2)
# Out:
# (0.522, 0.0)

# %% [markdown]
# criterion_50(5)

# %%
def criterion_50_uniform_letter(open_texts, k_empt, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[3:] # j = 2
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_uniform_letter(texts_10_10000, 1, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_50_uniform_letter(texts_100_10000, 1, 100)
# Out:
# (0.2763, 1.0)

# %%
criterion_50_uniform_letter(texts_1000_10000, 1, 1000)
# Out:
# (1.0, 0.3493)

# %%
criterion_50_uniform_letter(texts_10000_1000, 1, 10000)
# Out:
# (1.0, 0.0)

# %% [markdown]
# criterion_50(s_letter)

# %%
def criterion_50_s_letter(open_texts, k_empt, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    

    B_prh = A[2:] # j = 2
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        tmp = set(text_corrupt[i][0])
        if len(set(B_prh) - tmp) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        tmp = set(open_texts[i])
        if len(set(B_prh) - tmp) >= k_empt:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_s_letter(texts_10_10000, 1, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_50_s_letter(texts_100_10000, 1, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_50_s_letter(texts_1000_10000, 1, 1000)
# Out:
# (0.0, 0.3493)

# %%
criterion_50_s_letter(texts_10000_1000, 1, 10000)
# Out:
# (0.0, 0.0)

# %% [markdown]
# criterion_structural(1)

# %%
def structural(text):
    n = sys.getsizeof(text)
    compressed_l_bytes = sys.getsizeof(b64encode(gzip.compress(text.encode('utf-8'))).decode('utf-8'))
    
    return abs(n - compressed_l_bytes) / n

# %%
def criterion_structural_vigenere_r1_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_vigenere_r1_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0001, 0.9999)

# %%
criterion_structural_vigenere_r1_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r1_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r1_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(2)

# %%
def criterion_structural_vigenere_r5_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_vigenere_r5_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0001, 1.0)

# %%
criterion_structural_vigenere_r5_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r5_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r5_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(3)

# %%
def criterion_structural_vigenere_r10_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_vigenere_r10_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r10_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r10_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_vigenere_r10_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(4)

# %%
def criterion_structural_afine_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_letter(i))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_afine_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.028, 0.9999)

# %%
criterion_structural_afine_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_afine_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_afine_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(5)

# %%
def criterion_structural_uniform_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_letter(L))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_uniform_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0001, 1.0)

# %%
criterion_structural_uniform_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_uniform_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_uniform_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_structural(6)

# %%
def criterion_structural_s_letter(open_texts, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_letter(L))
        text_corrupt.append(l)
    
    for i in text_corrupt:
        if structural(i[0]) < k:
            H1 += 1
    
    for i in range(len(open_texts)):
        if structural(random_key(L)) >= k:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_structural_s_letter(texts_10_10000, 0.02, 10)
# Out:
# (0.0012, 1.0)

# %%
criterion_structural_s_letter(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_s_letter(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_structural_s_letter(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# 2) l = 2

# %% [markdown]
# - criterion_20:
# > 1. criterion_20_vigenere_r1_bigram +
# > 2. criterion_20_vigenere_r5_bigram +
# > 3. criterion_20_vigenere_r10_bigram +
# > 4. criterion_20_afine_bigram +
# > 5. criterion_20_uniform_bigram +
# > 6. criterion_20_s_bigram +
#
# - criterion_21:
# > 1. criterion_21_vigenere_r1_bigram +
# > 2. criterion_21_vigenere_r5_bigram +
# > 3. criterion_21_vigenere_r10_bigram +
# > 4. criterion_21_afine_bigram +
# > 5. criterion_21_uniform_bigram +
# > 6. criterion_21_s_bigram +
#
# - criterion_22:
# > 1. criterion_22_vigenere_r1_bigram
# > 2. criterion_22_vigenere_r5_bigram
# > 3. criterion_22_vigenere_r10_bigram
# > 4. criterion_22_afine_bigram
# > 5. criterion_22_uniform_bigram
# > 6. criterion_22_s_bigram
#
# - criterion_23:
# > 1. criterion_23_vigenere_r1_bigram +
# > 2. criterion_23_vigenere_r5_bigram +
# > 3. criterion_23_vigenere_r10_bigram +
# > 4. criterion_23_afine_bigram +
# > 5. criterion_23_uniform_bigram +
# > 6. criterion_23_s_bigram +
#
# - criterion_conformity
# > 1. criterion_conformity_vigenere_r1_bigram +
# > 2. criterion_conformity_vigenere_r5_bigram +
# > 3. criterion_conformity_vigenere_r10_bigram +
# > 4. criterion_conformity_afine_bigram
# > 5. criterion_conformity_uniform_bigram
# > 6. criterion_conformity_s_bigram
#
# - criterion_50
# > 1. criterion_50_vigenere_r1_bigram +
# > 2. criterion_50_vigenere_r5_bigram +
# > 3. criterion_50_vigenere_r10_bigram +
# > 4. criterion_50_afine_bigram +
# > 5. criterion_50_uniform_bigram +
# > 6. criterion_50_s_bigram +

# %%
B = ['на', 'ов', 'ві', 'не', 'ти', 'по', 'ро', 'ав', 'го', 'ер', 'ст', 'ог', 'ла', 'ли', 'та', 'ін', 'ви', 'он', 'во', 'ом']

# %% [markdown]
# criterion_20(1)

# %%
def criterion_20_vigenere_r1_bigram(open_texts, B_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r1_bigram(texts_10_10000, 9)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r1_bigram(texts_100_10000, 9)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_vigenere_r1_bigram(texts_1000_10000, 9)
# Out:
# (0.922, 0.9721)

# %%
criterion_20_vigenere_r1_bigram(texts_10000_1000, 9)
# Out:
# (1.0, 0.959)

# %% [markdown]
# criterion_20(2)

# %%
def criterion_20_vigenere_r5_bigram(open_texts, B_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r5_bigram(texts_10_10000, 9)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r5_bigram(texts_100_10000, 9)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_vigenere_r5_bigram(texts_1000_10000, 9)
# Out:
# (0.922, 0.9992)

# %%
criterion_20_vigenere_r5_bigram(texts_10000_1000, 9)
# Out:
# (1.0, 0.707)

# %% [markdown]
# criterion_20(3)

# %%
def criterion_20_vigenere_r10_bigram(open_texts, B_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_vigenere_r10_bigram(texts_10_10000, 9)
# Out:
# (0.0, 1.0)

# %%
criterion_20_vigenere_r10_bigram(texts_100_10000, 9)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_vigenere_r10_bigram(texts_1000_10000, 9)
# Out:
# (0.922, 0.9996)

# %%
criterion_20_vigenere_r10_bigram(texts_10000_1000, 9)
# Out:
# (1.0, 0.731)

# %% [markdown]
# criterion_20(4)

# %%
def criterion_20_afine_bigram(open_texts, B_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_afine_bigram(texts_10_10000, 9)
# Out:
# (0.0, 1.0)

# %%
criterion_20_afine_bigram(texts_100_10000, 9)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_afine_bigram(texts_1000_10000, 9)
# Out:
# (0.922, 1.0)

# %%
criterion_20_afine_bigram(texts_10000_1000, 9)
# Out:
# (1.0, 0.999)

# %% [markdown]
# criterion_20(5)

# %%
def criterion_20_uniform_bigram(open_texts, B_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_uniform_bigram(texts_10_10000, 9, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_20_uniform_bigram(texts_100_10000, 9, 100)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_uniform_bigram(texts_1000_10000, 9, 1000)
# Out:
# (0.922, 0.9998)

# %%
criterion_20_uniform_bigram(texts_10000_1000, 9, 10000)
# Out:
# (1.0, 0.073)

# %%
def criterion_20_s_bigram(open_texts, B_frq_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) == len(B_frq):
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) != len(B_frq):
            H0 += 1
        
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_20_s_bigram(texts_10_10000, 9, 10)
# Out:
# (0.0, 1.0)

# %%
criterion_20_s_bigram(texts_100_10000, 9, 100)
# Out:
# (0.0002, 1.0)

# %%
criterion_20_s_bigram(texts_1000_10000, 9, 1000)
# Out:
# (0.922, 1.0)

# %%
criterion_20_s_bigram(texts_10000_1000, 15, 10000)
# Out:
# (1.0, 1.0)

# %% [markdown]
# criterion_21(1)

# %%
def criterion_21_vigenere_r1_bigram(open_texts, B_frq_size, kf):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r1_bigram(texts_10_10000, 9, 2)
# Out:
# (0.9941, 0.0005)

# %%
criterion_21_vigenere_r1_bigram(texts_100_10000, 9, 2)
# Out:
# (0.2015, 0.0311)

# %%
criterion_21_vigenere_r1_bigram(texts_1000_10000, 9, 2)
# Out:
# (0.0, 0.3463)

# %%
criterion_21_vigenere_r1_bigram(texts_10000_1000, 9, 2)
# Out:
# (0.0, 0.925)

# %% [markdown]
# criterion_21(2)

# %%
def criterion_21_vigenere_r5_bigram(open_texts, B_frq_size, kf):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r5_bigram(texts_10_10000, 9, 2)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_vigenere_r5_bigram(texts_100_10000, 9, 2)
# Out:
# (0.2015, 0.0072)

# %%
criterion_21_vigenere_r5_bigram(texts_1000_10000, 9, 2)
# Out:
# (0.0, 0.6326)

# %%
criterion_21_vigenere_r5_bigram(texts_10000_1000, 9, 2)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_21(3)

# %%
def criterion_21_vigenere_r10_bigram(open_texts, B_frq_size, kf):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_vigenere_r10_bigram(texts_10_10000, 9, 2)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_vigenere_r10_bigram(texts_100_10000, 9, 2)
# Out:
# (0.2015, 0.008)

# %%
criterion_21_vigenere_r10_bigram(texts_1000_10000, 9, 2)
# Out:
# (0.0, 0.6294)

# %%
criterion_21_vigenere_r10_bigram(texts_10000_1000, 9, 2)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_21(4)

# %%
def criterion_21_afine_bigram(open_texts, B_frq_size, kf):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_afine_bigram(texts_10_10000, 9, 2)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_afine_bigram(texts_100_10000, 9, 2)
# Out:
# (0.2015, 0.0066)

# %%
criterion_21_afine_bigram(texts_1000_10000, 9, 2)
# Out:
# (0.0, 0.2948)

# %%
criterion_21_afine_bigram(texts_10000_1000, 9, 2)
# Out:
# (0.0, 0.768)

# %% [markdown]
# criterion_21(5)

# %%
def criterion_21_uniform_bigram(open_texts, B_frq_size, kf, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_uniform_bigram(texts_10_10000, 9, 2, 10)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_uniform_bigram(texts_100_10000, 9, 2, 100)
# Out:
# (0.2015, 0.0072)

# %%
criterion_21_uniform_bigram(texts_1000_10000, 9, 2, 1000)
# Out:
# (0.0, 0.7486)

# %%
criterion_21_uniform_bigram(texts_10000_1000, 9, 2, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_21(6)

# %%
def criterion_21_s_bigram(open_texts, B_frq_size, kf, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
    
    for i in open_texts:
        l = []
        for j in range(len(i) // 2):
            l.append(i[2*j:2*j+2])
        
        if len(list(set(l) & set(B_frq))) <= kf:
            H1 += 1
    
    for i in text_corrupt:
        l = []
        for j in range(len(i[0]) // 2):
            l.append(i[0][2*j:2*j+2])
            
        if len(list(set(l) & set(B_frq))) > kf:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_21_s_bigram(texts_10_10000, 9, 2, 10)
# Out:
# (0.9941, 0.0)

# %%
criterion_21_s_bigram(texts_100_10000, 9, 2, 100)
# Out:
# (0.2015, 0.0093)

# %%
criterion_21_s_bigram(texts_1000_10000, 9, 2, 1000)
# Out:
# (0.0, 0.5876)

# %%
criterion_21_s_bigram(texts_10000_1000, 9, 2, 10000)
# Out:
# (0.0, 0.949)

# %%
tmp = bigrams_counter(TEXT)

# %%
B_new = []
for i in range(len(tmp)):
    B_new.append(tmp[i][0])

B_new[:10]
# Out:
# [('н', 'а'),
#  ('о', 'в'),
#  ('в', 'і'),
#  ('н', 'е'),
#  ('т', 'и'),
#  ('п', 'о'),
#  ('р', 'о'),
#  ('а', 'в'),
#  ('г', 'о'),
#  ('е', 'р')]

# %% [markdown]
# criterion_22(1) !!!!!!

# %%
def criterion_22_vigenere_r1_bigram(open_texts, B_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    G = bigrams_counter(TEXT)
    
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
        
  
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[0] in B_frq and tmp[1] / N < k:
                H1 += 1
                
        
        
        
        
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq and tmp[j][1] / N >= k:
                H0 += 1
                
        
       
        
        
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r1_bigram(texts_10_10000, 10, 0.04)
# Out:
# (0.0, 0.9249)

# %%
criterion_22_vigenere_r1_bigram(texts_100_10000, 10, 0.04)
# Out:
# (0.0, 0.2305)

# %%
criterion_22_vigenere_r1_bigram(texts_1000_10000, 10, 0.02)
# Out:
# (0.0, 0.2424)

# %%
criterion_22_vigenere_r1_bigram(texts_10000_1000, 10, 0.02)
# Out:
# (0.0, 0.004)

# %%
def criterion_22_vigenere_r5_bigram(open_texts, B_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    G = bigrams_counter(TEXT)
    
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
        
  
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[0] in B_frq and tmp[1] / N < k:
                H1 += 1
                
        
        
        
        
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq and tmp[j][1] / N >= k:
                H0 += 1
                
        
       
        
        
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r5_bigram(texts_10_10000, 10, 0.04)
# Out:
# (0.0, 0.9249)

# %%
criterion_22_vigenere_r5_bigram(texts_100_10000, 10, 0.04)
# Out:
# (0.0, 0.2305)

# %%
criterion_22_vigenere_r5_bigram(texts_1000_10000, 10, 0.02)
# Out:
# (0.0, 0.2424)

# %%
criterion_22_vigenere_r5_bigram(texts_10000_1000, 10, 0.02)
# Out:
# (0.0, 0.004)

# %%
def criterion_22_vigenere_r10_bigram(open_texts, B_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    G = bigrams_counter(TEXT)
    
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
        
  
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[0] in B_frq and tmp[1] / N < k:
                H1 += 1
                
        
        
        
        
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq and tmp[j][1] / N >= k:
                H0 += 1
                
        
       
        
        
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_vigenere_r10_bigram(texts_10_10000, 10, 0.03)
# Out:
# (0.0, 0.9249)

# %%
criterion_22_vigenere_r10_bigram(texts_100_10000, 10, 0.03)
# Out:
# (0.0, 0.9094)

# %%
criterion_22_vigenere_r10_bigram(texts_1000_10000, 10, 0.03)
# Out:
# (0.0, 0.0023)

# %%
criterion_22_vigenere_r10_bigram(texts_10000_1000, 10, 0.03)
# Out:
# (0.0, 0.0)

# %%
def criterion_22_afine_bigram(open_texts, B_frq_size, k):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    G = bigrams_counter(TEXT)
    
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
        
  
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[0] in B_frq and tmp[1] / N < k:
                H1 += 1
                
        
        
        
        
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq and tmp[j][1] / N >= k:
                H0 += 1
                
        
       
        
        
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_afine_bigram(texts_10_10000, 10, 0.04)
# Out:
# (0.0, 0.9249)

# %%
criterion_22_afine_bigram(texts_100_10000, 10, 0.03)
# Out:
# (0.0, 0.9094)

# %%
criterion_22_afine_bigram(texts_1000_10000, 10, 0.03)
# Out:
# (0.0, 0.0023)

# %%
criterion_22_afine_bigram(texts_10000_1000, 10, 0.02)
# Out:
# (0.0, 0.004)

# %%
def criterion_22_uniform_bigram(open_texts, B_frq_size, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    G = bigrams_counter(TEXT)
    
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
        
  
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[0] in B_frq and tmp[1] / N < k:
                H1 += 1
                
        
        
        
        
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq and tmp[j][1] / N >= k:
                H0 += 1
                
        
       
        
        
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_uniform_bigram(texts_10_10000, 10, 0.03, 10)
# Out:
# (0.0, 0.9249)

# %%
criterion_22_uniform_bigram(texts_100_10000, 10, 0.03, 100)
# Out:
# (0.0, 0.9094)

# %%
criterion_22_uniform_bigram(texts_1000_10000, 10, 0.03, 1000)
# Out:
# (0.0, 0.0023)

# %%
criterion_22_uniform_bigram(texts_10000_1000, 10, 0.03, 10000)
# Out:
# (0.0, 0.0)

# %%
def criterion_22_s_bigram(open_texts, B_frq_size, k, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    G = bigrams_counter(TEXT)
    
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
        
  
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[0] in B_frq and tmp[1] / N < k:
                H1 += 1
                
        
        
        
        
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq and tmp[j][1] / N >= k:
                H0 += 1
                
        
       
        
        
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_22_s_bigram(texts_10_10000, 10, 0.03, 10)
# Out:
# (0.0, 0.9249)

# %%
criterion_22_s_bigram(texts_100_10000, 10, 0.03, 100)
# Out:
# (0.0, 0.9094)

# %%
criterion_22_s_bigram(texts_1000_10000, 10, 0.03, 1000)
# Out:
# (0.0, 0.0023)

# %%
criterion_22_s_bigram(texts_10000_1000, 12, 0.03, 10000)
# Out:
# (0.0, 0.0)

# %% [markdown]
# criterion_23(1)

# %%
def criterion_23_vigenere_r1_bigram(open_texts, B_frq_size):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r1_bigram(texts_10_10000, 10)
# Out:
# (0.9062, 0.6339)

# %%
criterion_23_vigenere_r1_bigram(texts_100_10000, 10)
# Out:
# (0.9852, 0.4678)

# %%
criterion_23_vigenere_r1_bigram(texts_1000_10000, 10)
# Out:
# (0.9835, 0.4655)

# %%
criterion_23_vigenere_r1_bigram(texts_10000_1000, 10)
# Out:
# (0.978, 0.481)

# %% [markdown]
# criterion_23(2)

# %%
def criterion_23_vigenere_r5_bigram(open_texts, B_frq_size):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r5_bigram(texts_10_10000, 10)
# Out:
# (0.9131, 0.6339)

# %%
criterion_23_vigenere_r5_bigram(texts_100_10000, 10)
# Out:
# (0.9999, 0.4678)

# %%
criterion_23_vigenere_r5_bigram(texts_1000_10000, 10)
# Out:
# (1.0, 0.4655)

# %%
criterion_23_vigenere_r5_bigram(texts_10000_1000, 10)
# Out:
# (1.0, 0.481)

# %% [markdown]
# criterion_23(3)

# %%
def criterion_23_vigenere_r10_bigram(open_texts, B_frq_size):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_vigenere_r10_bigram(texts_10_10000, 10)
# Out:
# (0.9181, 0.6339)

# %%
criterion_23_vigenere_r10_bigram(texts_100_10000, 10)
# Out:
# (1.0, 0.4678)

# %%
criterion_23_vigenere_r10_bigram(texts_1000_10000, 10)
# Out:
# (1.0, 0.4655)

# %%
criterion_23_vigenere_r10_bigram(texts_10000_1000, 10)
# Out:
# (1.0, 0.481)

# %% [markdown]
# criterion_23(4)

# %%
def criterion_23_afine_bigram(open_texts, B_frq_size):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_afine_bigram(texts_10_10000, 10)
# Out:
# (0.9203, 0.6339)

# %%
criterion_23_afine_bigram(texts_100_10000, 10)
# Out:
# (0.9999, 0.4678)

# %%
criterion_23_afine_bigram(texts_1000_10000, 10)
# Out:
# (0.9997, 0.4655)

# %%
criterion_23_afine_bigram(texts_10000_1000, 10)
# Out:
# (0.999, 0.481)

# %% [markdown]
# criterion_23(5)

# %%
def criterion_23_uniform_bigram(open_texts, B_frq_size, L):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_uniform_bigram(texts_10_10000, 10, 10)
# Out:
# (0.9175, 0.6339)

# %%
criterion_23_uniform_bigram(texts_100_10000, 10, 100)
# Out:
# (1.0, 0.4678)

# %%
criterion_23_uniform_bigram(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 0.4655)

# %%
criterion_23_uniform_bigram(texts_10000_1000, 10, 10000)
# Out:
# (1.0, 0.481)

# %% [markdown]
# criterion_23(6)

# %%
def criterion_23_s_bigram(open_texts, B_frq_size, L):
    
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_frq = B_new[:B_frq_size]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
    
    K_f = 0
    for i in range(len(B_frq)):
        K_f += bigrams_counter(TEXT)[i][1] / 1416949
    
    for i in range(len(text_corrupt)):
        cnt = Counter(list(nltk.ngrams(text_corrupt[i][0], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(text_corrupt[i][0])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s < K_f:
            H1 += 1
    
    for i in range(len(open_texts)):
        cnt = Counter(list(nltk.ngrams(open_texts[i], n=2)))
        N = sum(cnt.values())
        
        s = 0
        tmp = bigrams_counter(open_texts[i])
        
        for j in range(len(tmp)):
            if tmp[j][0] in B_frq:
                s += tmp[j][1] / N
        
        if s >= K_f:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_23_s_bigram(texts_10_10000, 10, 10)
# Out:
# (0.9127, 0.6339)

# %%
criterion_23_s_bigram(texts_100_10000, 10, 100)
# Out:
# (1.0, 0.4678)

# %%
criterion_23_s_bigram(texts_1000_10000, 10, 1000)
# Out:
# (1.0, 0.4655)

# %%
criterion_23_s_bigram(texts_10000_1000, 10, 10000)
# Out:
# (1.0, 0.481)

# %% [markdown]
# criterion_conformity(1)

# %%
def criterion_conformity_vigenere_r1_bigram(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I2 = 0.004381493632890787
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
        
    for i in text_corrupt:
        if abs(conformity_index_bigrams(i[0]) - I2) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_bigrams(i) - I2) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r1_bigram(texts_10_10000, 0.02)
# Out:
# (0.0106, 0.9894)

# %%
criterion_conformity_vigenere_r1_bigram(texts_100_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r1_bigram(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r1_bigram(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %% [markdown]
# conformity_criterion(2)

# %%
def criterion_conformity_vigenere_r5_bigram(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I2 = 0.004381493632890787
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
        
    for i in text_corrupt:
        if abs(conformity_index_bigrams(i[0]) - I2) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_bigrams(i) - I2) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r5_bigram(texts_10_10000, 0.02)
# Out:
# (0.0027, 0.9894)

# %%
criterion_conformity_vigenere_r5_bigram(texts_100_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r5_bigram(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r5_bigram(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %%
def criterion_conformity_vigenere_r10_bigram(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I2 = 0.004381493632890787
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
        
    for i in text_corrupt:
        if abs(conformity_index_bigrams(i[0]) - I2) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_bigrams(i) - I2) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_vigenere_r10_bigram(texts_10_10000, 0.02)
# Out:
# (0.0012, 0.9894)

# %%
criterion_conformity_vigenere_r10_bigram(texts_100_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r10_bigram(texts_1000_10000, 0.02)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_vigenere_r10_bigram(texts_10000_1000, 0.02)
# Out:
# (0.0, 1.0)

# %%
def criterion_conformity_afine_bigram(open_texts, k_H):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I2 = 0.004381493632890787
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
        
    for i in text_corrupt:
        if abs(conformity_index_bigrams(i[0]) - I2) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_bigrams(i) - I2) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_afine_bigram(texts_10_10000, 0.02)
# Out:
# (0.0281, 0.9894)

# %%
criterion_conformity_afine_bigram(texts_100_10000, 0.02)
# Out:
# (0.0231, 1.0)

# %%
criterion_conformity_afine_bigram(texts_1000_10000, 0.02)
# Out:
# (0.0268, 1.0)

# %%
criterion_conformity_afine_bigram(texts_10000_1000, 0.02)
# Out:
# (0.043, 1.0)

# %%
def criterion_conformity_uniform_bigram(open_texts, k_H, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I2 = 0.004381493632890787
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
        
    for i in text_corrupt:
        if abs(conformity_index_bigrams(i[0]) - I2) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_bigrams(i) - I2) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_uniform_bigram(texts_10_10000, 0.02, 10)
# Out:
# (0.001, 0.9891)

# %%
criterion_conformity_uniform_bigram(texts_100_10000, 0.02, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_uniform_bigram(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_conformity_uniform_bigram(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %%
def criterion_conformity_s_bigram(open_texts, k_H, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    I2 = 0.004381493632890787
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
        
    for i in text_corrupt:
        if abs(conformity_index_bigrams(i[0]) - I2) > k_H:
            H1 += 1
    
    for i in open_texts:
        if abs(conformity_index_bigrams(i) - I2) <= k_H:
            H0 += 1
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_conformity_s_bigram(texts_10_10000, 0.02, 10)
# Out:
# (0.0025, 0.9891)

# %%
criterion_conformity_s_bigram(texts_100_10000, 0.02, 100)
# Out:
# (0.0006, 1.0)

# %%
criterion_conformity_s_bigram(texts_1000_10000, 0.02, 1000)
# Out:
# (0.0008, 1.0)

# %%
criterion_conformity_s_bigram(texts_10000_1000, 0.02, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(1)

# %%
def criterion_50_vigenere_r1_bigram(open_texts, k_empt, B_prh_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[0]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r1_bigram(texts_10_10000, 1, 50)
# Out:
# (0.28, 0.9782)

# %%
criterion_50_vigenere_r1_bigram(texts_100_10000, 1, 50)
# Out:
# (0.0001, 1.0)

# %%
criterion_50_vigenere_r1_bigram(texts_1000_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r1_bigram(texts_10000_1000, 1, 50)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(2)

# %%
def criterion_50_vigenere_r5_bigram(open_texts, k_empt, B_prh_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[1]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r5_bigram(texts_10_10000, 1, 50)
# Out:
# (0.2847, 0.9782)

# %%
criterion_50_vigenere_r5_bigram(texts_100_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r5_bigram(texts_1000_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r5_bigram(texts_10000_1000, 1, 50)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(3)

# %%
def criterion_50_vigenere_r10_bigram(open_texts, k_empt, B_prh_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(VIGENERE_encryption_letter(i, key_initialization()[2]))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_vigenere_r10_bigram(texts_10_10000, 1, 50)
# Out:
# (0.2839, 0.9782)

# %%
criterion_50_vigenere_r10_bigram(texts_100_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r10_bigram(texts_1000_10000, 1, 50)
# Out:
# (0.0, 1.0)

# %%
criterion_50_vigenere_r10_bigram(texts_10000_1000, 1, 50)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(4)

# %%
def criterion_50_afine_bigram(open_texts, k_empt, B_prh_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in open_texts:
        l = []
        l.append(Afine_bigram(i))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_afine_bigram(texts_10_10000, 1, 50)
# Out:
# (0.3101, 0.9782)

# %%
criterion_50_afine_bigram(texts_100_10000, 1, 50)
# Out:
# (0.0033, 1.0)

# %%
criterion_50_afine_bigram(texts_1000_10000, 1, 50)
# Out:
# (0.0029, 1.0)

# %%
criterion_50_afine_bigram(texts_10000_1000, 1, 50)
# Out:
# (0.004, 1.0)

# %% [markdown]
# criterion_50(5)

# %%
def criterion_50_uniform_bigram(open_texts, k_empt, B_prh_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(uniform_bigram(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_uniform_bigram(texts_10_10000, 1, 50, 10)
# Out:
# (0.2803, 0.9782)

# %%
criterion_50_uniform_bigram(texts_100_10000, 1, 50, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_50_uniform_bigram(texts_1000_10000, 1, 50, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_50_uniform_bigram(texts_10000_1000, 1, 50, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# criterion_50(6)

# %%
def criterion_50_s_bigram(open_texts, k_empt, B_prh_size, L):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    B_prh = B_new[B_prh_size:]
    
    text_corrupt = []
    for i in range(len(open_texts)):
        l = []
        l.append(s_bigram(L))
        text_corrupt.append(l)
    
    for i in range(len(text_corrupt)):
        s = bigrams_counter(text_corrupt[i][0])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) < k_empt:
            H1 += 1
    
    for i in range(len(open_texts)):
        s = bigrams_counter(open_texts[i])
        l = []
        for j in range(len(s)):
            l.append(s[j][0])
        
        if len(list(set(l) - set(B_prh))) >= k_empt:
            H0 += 1
    
    
    FP = H1 / len(open_texts)
    FN = H0 / len(open_texts)
    
    return FP, FN

# %%
criterion_50_s_bigram(texts_10_10000, 1, 50, 10)
# Out:
# (0.2885, 0.9782)

# %%
criterion_50_s_bigram(texts_100_10000, 1, 50, 100)
# Out:
# (0.0, 1.0)

# %%
criterion_50_s_bigram(texts_1000_10000, 1, 50, 1000)
# Out:
# (0.0, 1.0)

# %%
criterion_50_s_bigram(texts_10000_1000, 1, 50, 10000)
# Out:
# (0.0, 1.0)

# %% [markdown]
# **Random text**

# %%
Text_1 = random_key(10000)
Text_2 = random_key(10000)
Text_3 = random_key(10000)

# %%
def criterion_20_nontext_afine_letter(text, A_frq_size):
    FP = 0
    FN = 0
    
    H1 = 0
    H0 = 0
    
    A_frq = A[:A_frq_size]
    
    text_corrupt = []
    for i in range(1000):
        l = []
        l.append(Afine_letter(text))
        text_corrupt.append(l)
    
    for i in range(1000):
        tmp = list(text)
        if len(list(set(tmp) & set(A_frq))) == len(A_frq):
            H0 += 1
    
    for i in text_corrupt:
        tmp = list(i[0])
        if len(list(set(tmp) & set(A_frq))) != len(A_frq):
            H1 += 1
            
    FP = H1 / len(text)
    FN = H0 / len(text)
    
    return FP, FN

# %%
criterion_20_nontext_afine_letter(Text_1, 10)
# Out:
# (0.0502, 0.1)

# %%
criterion_20_nontext_afine_letter(Text_2, 10)
# Out:
# (0.0502, 0.1)

# %%
criterion_20_nontext_afine_letter(Text_3, 10)
# Out:
# (0.0514, 0.1)

# %%
ttt = 'апроглсд'
s = bigrams_counter(ttt)
s
# Out:
# [(('а', 'п'), 1),
#  (('п', 'р'), 1),
#  (('р', 'о'), 1),
#  (('о', 'г'), 1),
#  (('г', 'л'), 1),
#  (('л', 'с'), 1),
#  (('с', 'д'), 1)]

# %%
ll = []
for i in range(len(s)):
    ll.append(s[i][0])
ll
# Out:
# [('а', 'п'),
#  ('п', 'р'),
#  ('р', 'о'),
#  ('о', 'г'),
#  ('г', 'л'),
#  ('л', 'с'),
#  ('с', 'д')]

# %%
t = 'авблагоу'

# %%
print(list(t))
# Out:
# ['а', 'в', 'б', 'л', 'а', 'г', 'о', 'у']

# %%
l = []
for i in range(len(t) // 2):
    l.append(t[2*i:2*i + 2])

print(l)
# Out:
# ['ав', 'бл', 'аг', 'оу']
